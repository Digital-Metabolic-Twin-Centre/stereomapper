# %% [markdown]
# This notebook will detail the analysis performed to evaluate stereomappers performance with respect to clustering of identical structures. The details of how this was performed are explained in the relevant sections of the Methods in the stereomapper manuscript.

# %%
import pandas as pd
import sqlite3
import json
from collections import defaultdict, Counter
from typing import Dict, List, Any, Set, Optional
from tqdm import tqdm
import math
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# %%
# load the mnx structures
mnx_structures_with_mappings = '/home/jackmcgoldrick/stereomapper/experiments/analysis/old/mnx_structures_with_maps_reconxkg_filtered_dedup.db'

# create connection
conn = sqlite3.connect(mnx_structures_with_mappings)
cursor = conn.cursor()
# check what tables are present
q = " SELECT * FROM mnx_structures_with_maps"
mnx_strucs = pd.read_sql_query(q, conn)
mnx_strucs.head()
# Out:
#                                  mnx_ref     dedup_label
# 0  https://rdf.metanetx.org/chem/BIOMASS  seedM:cpd11416
# 1   https://rdf.metanetx.org/chem/MNXM02        vmhM:oh1
# 2   https://rdf.metanetx.org/chem/MNXM02     chebi:13365
# 3   https://rdf.metanetx.org/chem/MNXM02     chebi:13419
# 4   https://rdf.metanetx.org/chem/MNXM02     chebi:16234

# %% [markdown]
# Dataset is as clean as possible now without the possibility in introudcing error due to removal of actual needed identifiers. For example, in the case of HMDB and chebi, many of the identifiers are likely to be secondary identifiers / accessions, due to maintaining backwards compatibility between older versions and newer versions of the databases. It is difficult to determine how to filter these out. The best we can do currently, is leave them in for now, and when comparing the two methods later, we can calculate the difference, which can be used as a sort of margin of error of sorts.
#
# Now that cleaning has concluded on the ReconXKG dataset, its time now to import the stereomapper results dataset.

# %%
db_path = "/home/jackmcgoldrick/drive/Recon4IMD/WP5_Reconstruction/T5.1_ReconXKG/results/molDistance/project_results/output_databases/031125_ReconXKG_exp.sqlite"
conn = sqlite3.connect(db_path)

# get vals from cluster table as it is all that is needed for this comparison
query = "SELECT * FROM clusters;"
df_molD = pd.read_sql_query(query, conn)
df_molD.head()
# Out:
#    cluster_id  inchikey_first  \
# 0           1  AAAAGGGRHVKJPW
# 1           2  AAAAGYWRODJXSD
# 2           3  AAAAGYWRODJXSD
# 3           4  AAABALCCAVGCNQ
# 4           5  AAABMNXUOFPYQK
#
#                                  identity_key_strict  is_undef_sru  \
# 0  CCCCC/C=C\C/C=C\C/C=C\C/C=C\CCCCCCCCCCCCCCCC(=...             0
# 1  CCCCC/C=C\C/C=C\C/C=C\C/C=C\C/C=C\CCCCCCCCCCCC...             0
# 2  CCCCC/C=C\C/C=C\C/C=C\C/C=C\C/C=C\CCCCCCCCCCCC...             0
# 3  CC/C=C\C/C=C\C/C=C\C/C=C\C/C=C\C/C=C\CCC(=O)O[...             0
# 4  C=C1C[C@](OC)([C@H](O)C(=O)N[C@H]2OCO[C@H]3[C@...             0
#
#    is_def_sru  sru_repeat_count sru_key  member_count  \
# 0           0               NaN    none             1
# 1           0               NaN    none             1
# 2           0               NaN    none             1
# 3           0               NaN    none             1
# 4           0               NaN    none             3
#
#                                         members_json  \
# 0                                 ["slm:SLM:736507"]
# 1                                 ["slm:SLM:496071"]
# 2                                 ["slm:SLM:491467"]
# 3                                 ["slm:SLM:512033"]
# 4  ["chebi:CHEBI:80858", "kegg.compound:C17009", ...
#
#                                         members_hash
# 0  db55be2239bd2eac03bb254a780c704ee87055d839e77b...
# 1  0830b68b759c58b051c0feb193175c757e5e5a1692ac11...
# 2  36e33cded4fa84438dc10a439001c7566b068adcf29343...
# 3  c995e07bef761cf6d20a89ff3ef8b262b590caf1403226...
# 4  4cbda1ea6824f5b36c0cd005ca63f490be347642181d10...

# %%
# close connection
conn.close()

# %% [markdown]
# In the dataframe, `df_molD`, we have a set of clusters each denoted by a cluster id and also their associated members. If a cluster has one member, it means stereomapper found this structure to be a unique structure in the dataset i.e it was not found to be identical to any other structure in the dataset.
#
# If a cluster has more than one member, stereomapper found the opposite scenario, these structures are deemed to be identical.
#
#
# This dataset also needs a little bit of cleaning to fit to the standard formatting of identifiers we extracted from ReconXKG.

# %%
# extract json list from members_json 
df_molD['members'] = df_molD['members_json'].apply(json.loads)
df_molD = df_molD.drop(columns=['members_json'])
df_molD.head()
# Out:
#    cluster_id  inchikey_first  \
# 0           1  AAAAGGGRHVKJPW
# 1           2  AAAAGYWRODJXSD
# 2           3  AAAAGYWRODJXSD
# 3           4  AAABALCCAVGCNQ
# 4           5  AAABMNXUOFPYQK
#
#                                  identity_key_strict  is_undef_sru  \
# 0  CCCCC/C=C\C/C=C\C/C=C\C/C=C\CCCCCCCCCCCCCCCC(=...             0
# 1  CCCCC/C=C\C/C=C\C/C=C\C/C=C\C/C=C\CCCCCCCCCCCC...             0
# 2  CCCCC/C=C\C/C=C\C/C=C\C/C=C\C/C=C\CCCCCCCCCCCC...             0
# 3  CC/C=C\C/C=C\C/C=C\C/C=C\C/C=C\C/C=C\CCC(=O)O[...             0
# 4  C=C1C[C@](OC)([C@H](O)C(=O)N[C@H]2OCO[C@H]3[C@...             0
#
#    is_def_sru  sru_repeat_count sru_key  member_count  \
# 0           0               NaN    none             1
# 1           0               NaN    none             1
# 2           0               NaN    none             1
# 3           0               NaN    none             1
# 4           0               NaN    none             3
#
#                                         members_hash  \
# 0  db55be2239bd2eac03bb254a780c704ee87055d839e77b...
# 1  0830b68b759c58b051c0feb193175c757e5e5a1692ac11...
# 2  36e33cded4fa84438dc10a439001c7566b068adcf29343...
# 3  c995e07bef761cf6d20a89ff3ef8b262b590caf1403226...
# 4  4cbda1ea6824f5b36c0cd005ca63f490be347642181d10...
#
#                                              members
# 0                                   [slm:SLM:736507]
# 1                                   [slm:SLM:496071]
# 2                                   [slm:SLM:491467]
# 3                                   [slm:SLM:512033]
# 4  [chebi:CHEBI:80858, kegg.compound:C17009, mode...

# %%
# lets clean the members column up a bit
def clean_member_id(member):
    # clean up the prefixes to match the format in ReconXKG
    if member.startswith("slm:SLM:"):
        return member.replace("slm:SLM:", "SLM:")
    elif member.startswith("chebi:CHEBI:"):
        return member.replace("chebi:CHEBI:", "chebi:")
    elif member.startswith("lipidmaps"):
        return member.replace("lipidmaps:", "lipidmapsM:")
    elif member.startswith("kegg.compound"):
        return member.replace("kegg.compound:", "keggC:")
    elif member.startswith("kegg.drug"):
        return member.replace("kegg.drug:", "keggD:")
    elif member.startswith("vmhmetabolite:"):
        return member.replace("vmhmetabolite:", "vmhM:")
    elif member.startswith("sabiork:"):
        return member.replace("sabiork:", "sabiorkM:")
    elif member.startswith("modelseed:"):
        return member.replace("modelseed:", "seedM:")
    else:
        return member
    
df_molD['cleaned_members'] = df_molD['members'].apply(lambda members: [clean_member_id(m) for m in members])
df_molD.head()
# Out:
#    cluster_id  inchikey_first  \
# 0           1  AAAAGGGRHVKJPW
# 1           2  AAAAGYWRODJXSD
# 2           3  AAAAGYWRODJXSD
# 3           4  AAABALCCAVGCNQ
# 4           5  AAABMNXUOFPYQK
#
#                                  identity_key_strict  is_undef_sru  \
# 0  CCCCC/C=C\C/C=C\C/C=C\C/C=C\CCCCCCCCCCCCCCCC(=...             0
# 1  CCCCC/C=C\C/C=C\C/C=C\C/C=C\C/C=C\CCCCCCCCCCCC...             0
# 2  CCCCC/C=C\C/C=C\C/C=C\C/C=C\C/C=C\CCCCCCCCCCCC...             0
# 3  CC/C=C\C/C=C\C/C=C\C/C=C\C/C=C\C/C=C\CCC(=O)O[...             0
# 4  C=C1C[C@](OC)([C@H](O)C(=O)N[C@H]2OCO[C@H]3[C@...             0
#
#    is_def_sru  sru_repeat_count sru_key  member_count  \
# 0           0               NaN    none             1
# 1           0               NaN    none             1
# 2           0               NaN    none             1
# 3           0               NaN    none             1
# 4           0               NaN    none             3
#
#                                         members_hash  \
# 0  db55be2239bd2eac03bb254a780c704ee87055d839e77b...
# 1  0830b68b759c58b051c0feb193175c757e5e5a1692ac11...
# 2  36e33cded4fa84438dc10a439001c7566b068adcf29343...
# 3  c995e07bef761cf6d20a89ff3ef8b262b590caf1403226...
# 4  4cbda1ea6824f5b36c0cd005ca63f490be347642181d10...
#
#                                              members  \
# 0                                   [slm:SLM:736507]
# 1                                   [slm:SLM:496071]
# 2                                   [slm:SLM:491467]
# 3                                   [slm:SLM:512033]
# 4  [chebi:CHEBI:80858, kegg.compound:C17009, mode...
#
#                                cleaned_members
# 0                                 [SLM:736507]
# 1                                 [SLM:496071]
# 2                                 [SLM:491467]
# 3                                 [SLM:512033]
# 4  [chebi:80858, keggC:C17009, seedM:cpd17277]

# %% [markdown]
# Now we have to tackle a seperate issue, in the dataset due to errors introduce by lax naming conventions, both vmh and sabiork compounds have been assigned the prefix 'local:' in the results. This is due to errors in the pipeline related to naming identifiers for the output.
#
# Luckily, sabiork compound identifiers are completely numeric, and therefore easily differentiated from vmh metabolites which use a mixture of numeric and alphabetical characters for accession construction.

# %%
def replace_local_prefix(member):
    if member.startswith("local:"):
        # check if the rest of the id is numeric only
        rest = member.split("local:")[1]
        if rest.startswith("sabiork") or rest.isdigit():
            # remove sabirok_ if it exists
            rest = rest.replace("sabiork_", "")
            return f"sabiorkM:{rest}"
        else:
            return f"vmhM:{rest}"
    return member

# %%
def test_replace_local_prefix():
    assert replace_local_prefix("local:12345") == "sabiorkM:12345"
    assert replace_local_prefix("local:sabiork_123") == "sabiorkM:123"
    assert replace_local_prefix("local:glc_D") == "vmhM:glc_D"
    assert replace_local_prefix("vmhM:HC023457") == "vmhM:HC023457"
    assert replace_local_prefix("sabiorkM:12345") == "sabiorkM:12345"
    assert replace_local_prefix("otherdb:foo") == "otherdb:foo"

# %%
test_replace_local_prefix()

# %%
# now apply this function to the cleaned_members column
df_molD['final_members'] = df_molD['cleaned_members'].apply(lambda members: [replace_local_prefix(m) for m in members])
# drop the members and cleaned_members columns as they are no longer needed
df_molD = df_molD.drop(columns=['members', 'cleaned_members'])
df_molD.head(20)
# Out:
#     cluster_id  inchikey_first  \
# 0            1  AAAAGGGRHVKJPW
# 1            2  AAAAGYWRODJXSD
# 2            3  AAAAGYWRODJXSD
# 3            4  AAABALCCAVGCNQ
# 4            5  AAABMNXUOFPYQK
# 5            6  AAABQAABBQOUMD
# 6            7  AAABYGXUNQSIIU
# 7            8  AAABYGXUNQSIIU
# 8            9  AAABYUBCBRDOIO
# 9           10  AAACMCMFCOTZRQ
# 10          11  AAACNRQLTNWOOW
# 11          12  AAACNRQLTNWOOW
# 12          13  AAADWPNERUXGRG
# 13          14  AAADWPNERUXGRG
# 14          15  AAAFZMYJJHWUPN
# 15          16  AAAFZMYJJHWUPN
# 16          17  AAAFZMYJJHWUPN
# 17          18  AAAFZMYJJHWUPN
# 18          19  AAAFZMYJJHWUPN
# 19          20  AAAFZMYJJHWUPN
#
#                                   identity_key_strict  is_undef_sru  \
# 0   CCCCC/C=C\C/C=C\C/C=C\C/C=C\CCCCCCCCCCCCCCCC(=...             0
# 1   CCCCC/C=C\C/C=C\C/C=C\C/C=C\C/C=C\CCCCCCCCCCCC...             0
# 2   CCCCC/C=C\C/C=C\C/C=C\C/C=C\C/C=C\CCCCCCCCCCCC...             0
# 3   CC/C=C\C/C=C\C/C=C\C/C=C\C/C=C\C/C=C\CCC(=O)O[...             0
# 4   C=C1C[C@](OC)([C@H](O)C(=O)N[C@H]2OCO[C@H]3[C@...             0
# 5   CC/C=C\C/C=C\C/C=C\CCCCCCCCCC(=O)O[C@H](COC(=O...             0
# 6   CCCCCCCCCCCCCC(=O)O[C@H](COC(=O)CCCCCCCCCCCC)C...             0
# 7   CCCCCCCCCCCCCC(=O)O[C@H](COC(=O)CCCCCCCCCCCC)C...             0
# 8   CCCCC/C=C\C/C=C\CCCCCCCC(=O)OC[C@H](COP(=O)([O...             0
# 9   CC/C=C\C/C=C\C/C=C\C/C=C\C/C=C\C/C=C\CCC(=O)O[...             0
# 10  CCC/C=C\C/C=C\CCCCCCCC(=O)OC[C@@H](COC(=O)CCCC...             0
# 11  CCC/C=C\C/C=C\CCCCCCCC(=O)OC[C@H](COC(=O)CCCCC...             0
# 12  CC/C=C\C/C=C\C/C=C\C/C=C\C/C=C\CCCCCCCCCCCCCC(...             0
# 13  CC/C=C\C/C=C\C/C=C\C/C=C\C/C=C\CCCCCCCCCCCCCC(...             0
# 14                 O=P(O)(O)OCC1OC(OP(=O)(O)O)C(O)C1O             0
# 15    O=P(O)(O)OC[C@H]1OC(OP(=O)(O)O)[C@H](O)[C@@H]1O             0
# 16  O=P(O)(O)OC[C@H]1O[C@H](OP(=O)(O)O)[C@H](O)[C@...             0
# 17     O=P([O-])([O-])OCC1OC(OP(=O)([O-])[O-])C(O)C1O             0
# 18  O=P([O-])([O-])OC[C@H]1OC(OP(=O)([O-])[O-])[C@...             0
# 19  O=P([O-])([O-])OC[C@H]1O[C@H](OP(=O)([O-])[O-]...             0
#
#     is_def_sru  sru_repeat_count sru_key  member_count  \
# 0            0               NaN    none             1
# 1            0               NaN    none             1
# 2            0               NaN    none             1
# 3            0               NaN    none             1
# 4            0               NaN    none             3
# 5            0               NaN    none             1
# 6            0               NaN    none             1
# 7            0               NaN    none             1
# 8            0               NaN    none             1
# 9            0               NaN    none             1
# 10           0               NaN    none             1
# 11           0               NaN    none             1
# 12           0               NaN    none             1
# 13           0               NaN    none             1
# 14           0               NaN    none             1
# 15           0               NaN    none             1
# 16           0               NaN    none             3
# 17           0               NaN    none             1
# 18           0               NaN    none             1
# 19           0               NaN    none             2
#
#                                          members_hash  \
# 0   db55be2239bd2eac03bb254a780c704ee87055d839e77b...
# 1   0830b68b759c58b051c0feb193175c757e5e5a1692ac11...
# 2   36e33cded4fa84438dc10a439001c7566b068adcf29343...
# 3   c995e07bef761cf6d20a89ff3ef8b262b590caf1403226...
# 4   4cbda1ea6824f5b36c0cd005ca63f490be347642181d10...
# 5   270cb24208bb1070ca49fcb4faf483082a22ad4eac3201...
# 6   55afd27087d3de920ccdeb22fad7a15acfe3ac335264f6...
# 7   1f529d18d2657d0b2153b4e282e1ffcbaf34d40c1fd683...
# 8   f0844dd398d32ae27993c1a623f038baf31bbc67ef65f0...
# 9   99daebccd352e25165531c0a4d29042e8755f707f23557...
# 10  e320098f3bc773f95d02ef3a93171fafae2a44515a3042...
# 11  c53e17c0c0387242b913b04c3f5807b5315ddb05d40b2e...
# 12  d37738ee8ba14314f3ac6a9c58f776d234b954c40ba187...
# 13  2003dfa60afd9d3e54428a34ad836584adfeb627b0cd82...
# 14  3724ad5bec24bd95166253a209aeaefe7c7c7c6e302550...
# 15  fca851f78181489c955c2a9f97424462edc256cc7eefa6...
# 16  532ba2096d0d90a291a2d3032d5159f31e5787f2f3f7f7...
# 17  f401e4ad3165f1a5064b74762153180129141f3f4e11f6...
# 18  3b1d335bb35112f15673a9ee1bbf6947554778cb9a40d9...
# 19  cd03eb21bb687af66ef792f1ed6021357274c2a00f73cc...
#
#                                     final_members
# 0                                    [SLM:736507]
# 1                                    [SLM:496071]
# 2                                    [SLM:491467]
# 3                                    [SLM:512033]
# 4     [chebi:80858, keggC:C17009, seedM:cpd17277]
# 5                                    [SLM:012662]
# 6                       [lipidmapsM:LMGP04010069]
# 7                                    [SLM:042967]
# 8                                    [SLM:644088]
# 9                                    [SLM:572531]
# 10                                   [SLM:213588]
# 11                                   [SLM:213725]
# 12                                   [SLM:452819]
# 13                                   [SLM:433625]
# 14                                [sabiorkM:1470]
# 15                                  [chebi:17994]
# 16  [chebi:68819, hmdb:HMDB0011688, keggC:C01151]
# 17                                   [vmhM:r15bp]
# 18                                  [chebi:58345]
# 19                  [chebi:68688, seedM:cpd00847]

# %% [markdown]
# Now both datasets are in the same format for comparison, great!

# %% [markdown]
# ## Compare stereomapper clustering to ReconXKG clustering

# %% [markdown]
# To faciliate this, every identifier in each cluster from stereomapper needs to be extracted from `df_molD` and cross-referenced to an identifier in `df_dedup`. This will allow us to compare the stereomapper clustering against the MetaNetX clustering method by comparing clusters directly.

# %%
def fix_slm_id(slm_id):
    if slm_id.startswith("SLM:"):
        parts = slm_id.split(":")
        if len(parts) == 2 and parts[1].isdigit():
            number = parts[1]
            # add three leading zeros to the number
            fixed_number = "000" + number
            return f"SLM:{fixed_number}"
    return slm_id

# %%
# fix slm ids in df_molD
df_molD['final_members'] = df_molD['final_members'].apply(lambda members: [fix_slm_id(m) for m in members])
df_molD.head(20)
# Out:
#     cluster_id  inchikey_first  \
# 0            1  AAAAGGGRHVKJPW
# 1            2  AAAAGYWRODJXSD
# 2            3  AAAAGYWRODJXSD
# 3            4  AAABALCCAVGCNQ
# 4            5  AAABMNXUOFPYQK
# 5            6  AAABQAABBQOUMD
# 6            7  AAABYGXUNQSIIU
# 7            8  AAABYGXUNQSIIU
# 8            9  AAABYUBCBRDOIO
# 9           10  AAACMCMFCOTZRQ
# 10          11  AAACNRQLTNWOOW
# 11          12  AAACNRQLTNWOOW
# 12          13  AAADWPNERUXGRG
# 13          14  AAADWPNERUXGRG
# 14          15  AAAFZMYJJHWUPN
# 15          16  AAAFZMYJJHWUPN
# 16          17  AAAFZMYJJHWUPN
# 17          18  AAAFZMYJJHWUPN
# 18          19  AAAFZMYJJHWUPN
# 19          20  AAAFZMYJJHWUPN
#
#                                   identity_key_strict  is_undef_sru  \
# 0   CCCCC/C=C\C/C=C\C/C=C\C/C=C\CCCCCCCCCCCCCCCC(=...             0
# 1   CCCCC/C=C\C/C=C\C/C=C\C/C=C\C/C=C\CCCCCCCCCCCC...             0
# 2   CCCCC/C=C\C/C=C\C/C=C\C/C=C\C/C=C\CCCCCCCCCCCC...             0
# 3   CC/C=C\C/C=C\C/C=C\C/C=C\C/C=C\C/C=C\CCC(=O)O[...             0
# 4   C=C1C[C@](OC)([C@H](O)C(=O)N[C@H]2OCO[C@H]3[C@...             0
# 5   CC/C=C\C/C=C\C/C=C\CCCCCCCCCC(=O)O[C@H](COC(=O...             0
# 6   CCCCCCCCCCCCCC(=O)O[C@H](COC(=O)CCCCCCCCCCCC)C...             0
# 7   CCCCCCCCCCCCCC(=O)O[C@H](COC(=O)CCCCCCCCCCCC)C...             0
# 8   CCCCC/C=C\C/C=C\CCCCCCCC(=O)OC[C@H](COP(=O)([O...             0
# 9   CC/C=C\C/C=C\C/C=C\C/C=C\C/C=C\C/C=C\CCC(=O)O[...             0
# 10  CCC/C=C\C/C=C\CCCCCCCC(=O)OC[C@@H](COC(=O)CCCC...             0
# 11  CCC/C=C\C/C=C\CCCCCCCC(=O)OC[C@H](COC(=O)CCCCC...             0
# 12  CC/C=C\C/C=C\C/C=C\C/C=C\C/C=C\CCCCCCCCCCCCCC(...             0
# 13  CC/C=C\C/C=C\C/C=C\C/C=C\C/C=C\CCCCCCCCCCCCCC(...             0
# 14                 O=P(O)(O)OCC1OC(OP(=O)(O)O)C(O)C1O             0
# 15    O=P(O)(O)OC[C@H]1OC(OP(=O)(O)O)[C@H](O)[C@@H]1O             0
# 16  O=P(O)(O)OC[C@H]1O[C@H](OP(=O)(O)O)[C@H](O)[C@...             0
# 17     O=P([O-])([O-])OCC1OC(OP(=O)([O-])[O-])C(O)C1O             0
# 18  O=P([O-])([O-])OC[C@H]1OC(OP(=O)([O-])[O-])[C@...             0
# 19  O=P([O-])([O-])OC[C@H]1O[C@H](OP(=O)([O-])[O-]...             0
#
#     is_def_sru  sru_repeat_count sru_key  member_count  \
# 0            0               NaN    none             1
# 1            0               NaN    none             1
# 2            0               NaN    none             1
# 3            0               NaN    none             1
# 4            0               NaN    none             3
# 5            0               NaN    none             1
# 6            0               NaN    none             1
# 7            0               NaN    none             1
# 8            0               NaN    none             1
# 9            0               NaN    none             1
# 10           0               NaN    none             1
# 11           0               NaN    none             1
# 12           0               NaN    none             1
# 13           0               NaN    none             1
# 14           0               NaN    none             1
# 15           0               NaN    none             1
# 16           0               NaN    none             3
# 17           0               NaN    none             1
# 18           0               NaN    none             1
# 19           0               NaN    none             2
#
#                                          members_hash  \
# 0   db55be2239bd2eac03bb254a780c704ee87055d839e77b...
# 1   0830b68b759c58b051c0feb193175c757e5e5a1692ac11...
# 2   36e33cded4fa84438dc10a439001c7566b068adcf29343...
# 3   c995e07bef761cf6d20a89ff3ef8b262b590caf1403226...
# 4   4cbda1ea6824f5b36c0cd005ca63f490be347642181d10...
# 5   270cb24208bb1070ca49fcb4faf483082a22ad4eac3201...
# 6   55afd27087d3de920ccdeb22fad7a15acfe3ac335264f6...
# 7   1f529d18d2657d0b2153b4e282e1ffcbaf34d40c1fd683...
# 8   f0844dd398d32ae27993c1a623f038baf31bbc67ef65f0...
# 9   99daebccd352e25165531c0a4d29042e8755f707f23557...
# 10  e320098f3bc773f95d02ef3a93171fafae2a44515a3042...
# 11  c53e17c0c0387242b913b04c3f5807b5315ddb05d40b2e...
# 12  d37738ee8ba14314f3ac6a9c58f776d234b954c40ba187...
# 13  2003dfa60afd9d3e54428a34ad836584adfeb627b0cd82...
# 14  3724ad5bec24bd95166253a209aeaefe7c7c7c6e302550...
# 15  fca851f78181489c955c2a9f97424462edc256cc7eefa6...
# 16  532ba2096d0d90a291a2d3032d5159f31e5787f2f3f7f7...
# 17  f401e4ad3165f1a5064b74762153180129141f3f4e11f6...
# 18  3b1d335bb35112f15673a9ee1bbf6947554778cb9a40d9...
# 19  cd03eb21bb687af66ef792f1ed6021357274c2a00f73cc...
#
#                                     final_members
# 0                                 [SLM:000736507]
# 1                                 [SLM:000496071]
# 2                                 [SLM:000491467]
# 3                                 [SLM:000512033]
# 4     [chebi:80858, keggC:C17009, seedM:cpd17277]
# 5                                 [SLM:000012662]
# 6                       [lipidmapsM:LMGP04010069]
# 7                                 [SLM:000042967]
# 8                                 [SLM:000644088]
# 9                                 [SLM:000572531]
# 10                                [SLM:000213588]
# 11                                [SLM:000213725]
# 12                                [SLM:000452819]
# 13                                [SLM:000433625]
# 14                                [sabiorkM:1470]
# 15                                  [chebi:17994]
# 16  [chebi:68819, hmdb:HMDB0011688, keggC:C01151]
# 17                                   [vmhM:r15bp]
# 18                                  [chebi:58345]
# 19                  [chebi:68688, seedM:cpd00847]

# %%
# extract all distinct clusters members from identity_clusters
all_members = []
for members in df_molD['final_members']:
    all_members.append(members)

# %%
all_members
# Out:
# [['SLM:000736507'],
#  ['SLM:000496071'],
#  ['SLM:000491467'],
#  ['SLM:000512033'],
#  ['chebi:80858', 'keggC:C17009', 'seedM:cpd17277'],
#  ['SLM:000012662'],
#  ['lipidmapsM:LMGP04010069'],
#  ['SLM:000042967'],
#  ['SLM:000644088'],
#  ['SLM:000572531'],
#  ['SLM:000213588'],
#  ['SLM:000213725'],
#  ['SLM:000452819'],
#  ['SLM:000433625'],
#  ['sabiorkM:1470'],
#  ['chebi:17994'],
#  ['chebi:68819', 'hmdb:HMDB0011688', 'keggC:C01151'],
#  ['vmhM:r15bp'],
#  ['chebi:58345'],
#  ['chebi:68688', 'seedM:cpd00847'],
#  ['SLM:000658062'],
#  ['chebi:220580'],
#  ['SLM:000586824'],
#  ['SLM:000571636'],
#  ['chebi:124608'],
#  ['chebi:124583'],
#  ['chebi:124427'],
#  ['SLM:000006176'],
#  ['hmdb:HMDB0077047'],
#  ['SLM:000198371'],
#  ['hmdb:HMDB0193085'],
#  ['SLM:000044867'],
#  ['chebi:179970', 'lipidmapsM:LMFA07010342'],
#  ['SLM:000195318'],
#  ['SLM:000195436'],
#  ['SLM:000687410'],
#  ['SLM:000650520'],
#  ['chebi:200904'],
#  ['chebi:53110'],
#  ['hmdb:HMDB0188781'],
#  ['SLM:000491033'],
#  ['SLM:000646818'],
#  ['SLM:000396055'],
#  ['SLM:000511466'],
#  ['chebi:175328', 'hmdb:HMDB0034182'],
#  ['SLM:000495730'],
#  ['SLM:000274335'],
#  ['SLM:000022773'],
#  ['SLM:000134999'],
#  ['SLM:000135021'],
#  ['hmdb:HMDB0244491'],
#  ['chebi:95082', 'keggD:D11326'],
#  ['chebi:76212', 'hmdb:HMDB0259264'],
#  ['hmdb:HMDB0293573'],
#  ['lipidmapsM:LMPK12070088'],
#  ['hmdb:HMDB0220063'],
#  ['SLM:000490537'],
#  ['SLM:000232499'],
#  ['hmdb:HMDB0053324', 'SLM:000232367'],
#  ['SLM:000212939'],
#  ['SLM:000212673'],
#  ['SLM:000265761'],
#  ['SLM:000265848'],
#  ['SLM:000772464'],
#  ['chebi:85124', 'lipidmapsM:LMPK12112771'],
#  ['hmdb:HMDB0204518'],
#  ['lipidmapsM:LMGL03012320', 'SLM:000243628'],
#  ['hmdb:HMDB0052723', 'SLM:000243469'],
#  ['SLM:000051304'],
#  ['hmdb:HMDB0054752'],
#  ['SLM:000767278'],
#  ['hmdb:HMDB0107668'],
#  ['hmdb:HMDB0105104'],
#  ['SLM:000706426'],
#  ['SLM:000285973'],
#  ['SLM:000285898'],
#  ['SLM:000125989'],
#  ['SLM:000230067'],
#  ['SLM:000007878'],
#  ['hmdb:HMDB0066581'],
#  ['hmdb:HMDB0102495'],
#  ['SLM:000737349'],
#  ['SLM:000638645'],
#  ['hmdb:HMDB0188331'],
#  ['hmdb:HMDB0286610'],
#  ['SLM:000450458'],
#  ['hmdb:HMDB0272085'],
#  ['SLM:000298530'],
#  ['SLM:000298560'],
#  ['hmdb:HMDB0279652'],
#  ['SLM:000513271'],
#  ['hmdb:HMDB0189624'],
#  ['chebi:69547'],
#  ['chebi:163441'],
#  ['SLM:000724967'],
#  ['SLM:000147950'],
#  ['SLM:000147938'],
#  ['SLM:000006761'],
#  ['SLM:000706078'],
#  ['SLM:000692380'],
#  ['SLM:000584781'],
#  ['keggD:D12686'],
#  ['chebi:174903', 'hmdb:HMDB0061076'],
#  ['SLM:000632221'],
#  ['hmdb:HMDB0228373'],
#  ['hmdb:HMDB0300002'],
#  ['hmdb:HMDB0300001'],
#  ['SLM:000040223'],
#  ['hmdb:HMDB0110381'],
#  ['hmdb:HMDB0072560'],
#  ['lipidmapsM:LMGL03014413'],
#  ['SLM:000469044'],
#  ['SLM:000430655'],
#  ['hmdb:HMDB0123822'],
#  ['SLM:000569792'],
#  ['keggD:D04254'],
#  ['lipidmapsM:LMPR02020086'],
#  ['chebi:89526', 'hmdb:HMDB0032965'],
#  ['hmdb:HMDB0211200'],
#  ['SLM:000217774'],
#  ['SLM:000591063'],
#  ['chebi:205944'],
#  ['hmdb:HMDB0089377'],
#  ['chebi:31480', 'keggD:D01586'],
#  ['chebi:189149'],
#  ['SLM:000724249'],
#  ['SLM:000729855'],
#  ['SLM:000571443'],
#  ['lipidmapsM:LMGL04010016'],
#  ['chebi:199144'],
#  ['SLM:000269821'],
#  ['SLM:000270054'],
#  ['SLM:000579391'],
#  ['SLM:000684462'],
#  ['SLM:000454892'],
#  ['SLM:000435698'],
#  ['SLM:000030400'],
#  ['chebi:92059'],
#  ['SLM:000641550'],
#  ['SLM:000187665'],
#  ['hmdb:HMDB0205732'],
#  ['hmdb:HMDB0106061'],
#  ['hmdb:HMDB0097473'],
#  ['lipidmapsM:LMGL03016742'],
#  ['SLM:000483794'],
#  ['SLM:000155362'],
#  ['SLM:000155684'],
#  ['SLM:000615360'],
#  ['SLM:000663669'],
#  ['chebi:180695', 'keggD:D03115'],
#  ['hmdb:HMDB0232676'],
#  ['SLM:000013652'],
#  ['SLM:000591838'],
#  ['SLM:000254772'],
#  ['SLM:000254709'],
#  ['chebi:109746'],
#  ['hmdb:HMDB0262075'],
#  ['keggD:D11509'],
#  ['chebi:108088'],
#  ['SLM:000163311'],
#  ['SLM:000537446'],
#  ['hmdb:HMDB0074814'],
#  ['SLM:000007298'],
#  ['SLM:000497808'],
#  ['SLM:000623631'],
#  ['SLM:000753804'],
#  ['SLM:000729444'],
#  ['SLM:000180453'],
#  ['hmdb:HMDB0051436', 'SLM:000180336'],
#  ['SLM:000047538'],
#  ['hmdb:HMDB0195048'],
#  ['SLM:000298778'],
#  ['SLM:000298927'],
#  ['SLM:000643745'],
#  ['hmdb:HMDB0247879'],
#  ['chebi:92874'],
#  ['chebi:188152'],
#  ['SLM:000503488'],
#  ['SLM:000451639'],
#  ['SLM:000574590'],
#  ['SLM:000557802'],
#  ['SLM:000718980'],
#  ['hmdb:HMDB0074008'],
#  ['hmdb:HMDB0036297'],
#  ['SLM:000266201'],
#  ['SLM:000752212'],
#  ['hmdb:HMDB0201838'],
#  ['SLM:000485104'],
#  ['SLM:000485103'],
#  ['chebi:37276'],
#  ['SLM:000659682'],
#  ['SLM:000180007'],
#  ['lipidmapsM:LMPK12111054'],
#  ['SLM:000774127'],
#  ['chebi:83359',
#   'hmdb:HMDB0012102',
#   'lipidmapsM:LMSP03010005',
#   'SLM:000395260'],
#  ['vmhM:sphmyln18120_hs'],
#  ['SLM:000151851'],
#  ['SLM:000151691'],
#  ['chebi:188338', 'lipidmapsM:LMPK12120583'],
#  ['SLM:000664072'],
#  ['SLM:000448668'],
#  ['keggD:D05503'],
#  ['chebi:116603'],
#  ['hmdb:HMDB0199840'],
#  ['SLM:000509478'],
#  ['SLM:000163398'],
#  ['hmdb:HMDB0200879'],
#  ['chebi:88567', 'hmdb:HMDB0061810'],
#  ['SLM:000741789'],
#  ['SLM:000006812'],
#  ['SLM:000715815'],
#  ['SLM:000001936'],
#  ['SLM:000283512'],
#  ['SLM:000729180'],
#  ['hmdb:HMDB0123517'],
#  ['SLM:000706774'],
#  ['SLM:000719012'],
#  ['SLM:000398346'],
#  ['SLM:000538549'],
#  ['SLM:000739552'],
#  ['chebi:80700', 'keggC:C16746', 'seedM:cpd17105'],
#  ['SLM:000553782'],
#  ['chebi:97623'],
#  ['chebi:97111'],
#  ['chebi:101373'],
#  ['chebi:98803'],
#  ['chebi:95449'],
#  ['chebi:102941'],
#  ['chebi:35633'],
#  ['SLM:000767959'],
#  ['SLM:000170840'],
#  ['SLM:000171056'],
#  ['SLM:000040581'],
#  ['SLM:000303024'],
#  ['SLM:000039183'],
#  ['SLM:000663090'],
#  ['chebi:169401', 'lipidmapsM:LMFA07010425'],
#  ['hmdb:HMDB0242088'],
#  ['SLM:000047351'],
#  ['SLM:000221944'],
#  ['SLM:000222111'],
#  ['SLM:000542251'],
#  ['SLM:000278096'],
#  ['SLM:000278062'],
#  ['chebi:208836'],
#  ['SLM:000193800'],
#  ['hmdb:HMDB0050309', 'SLM:000193685'],
#  ['SLM:000574135'],
#  ['hmdb:HMDB0071991'],
#  ['hmdb:HMDB0102527'],
#  ['SLM:000736688'],
#  ['SLM:000194898'],
#  ['chebi:228066'],
#  ['SLM:000621850'],
#  ['hmdb:HMDB0113628'],
#  ['hmdb:HMDB0109292'],
#  ['hmdb:HMDB0069142'],
#  ['SLM:000208977'],
#  ['SLM:000209188'],
#  ['SLM:000011307'],
#  ['hmdb:HMDB0112785', 'lipidmapsM:LMGP03010786'],
#  ['SLM:000006777'],
#  ['hmdb:HMDB0076667'],
#  ['hmdb:HMDB0077393'],
#  ['SLM:000720835'],
#  ['SLM:000446065'],
#  ['hmdb:HMDB0121971'],
#  ['hmdb:HMDB0109154'],
#  ['hmdb:HMDB0096258'],
#  ['hmdb:HMDB0292433'],
#  ['hmdb:HMDB0276317'],
#  ['hmdb:HMDB0209180'],
#  ['SLM:000706709'],
#  ['hmdb:HMDB0188773'],
#  ['hmdb:HMDB0224052'],
#  ['SLM:000018916'],
#  ['SLM:000679144'],
#  ['chebi:100737'],
#  ['chebi:98649'],
#  ['chebi:102358'],
#  ['chebi:101809'],
#  ['chebi:98959'],
#  ['chebi:102182'],
#  ['hmdb:HMDB0277767'],
#  ['SLM:000572168'],
#  ['SLM:000560414'],
#  ['SLM:000190755'],
#  ['hmdb:HMDB0224797'],
#  ['chebi:184852', 'lipidmapsM:LMSP01060003'],
#  ['SLM:000566992'],
#  ['chebi:161796'],
#  ['hmdb:HMDB0119381'],
#  ['SLM:000231290'],
#  ['SLM:000230703'],
#  ['SLM:000763911'],
#  ['SLM:000121392'],
#  ['SLM:000121423'],
#  ['SLM:000773575'],
#  ['SLM:000523494'],
#  ['seedM:cpd19806'],
#  ['chebi:26276', 'hmdb:HMDB0256805', 'keggC:C18542'],
#  ['SLM:000215665'],
#  ['SLM:000255930'],
#  ['SLM:000256229'],
#  ['SLM:000649544'],
#  ['SLM:000297403'],
#  ['SLM:000297370'],
#  ['SLM:000282989'],
#  ['SLM:000283112'],
#  ['SLM:000217359'],
#  ['SLM:000217305'],
#  ['hmdb:HMDB0300230'],
#  ['SLM:000577619'],
#  ['hmdb:HMDB0189223'],
#  ['SLM:000776609'],
#  ['lipidmapsM:LMGL02010038'],
#  ['SLM:000776488'],
#  ['SLM:000699792'],
#  ['SLM:000219970'],
#  ['SLM:000197253'],
#  ['SLM:000529401'],
#  ['hmdb:HMDB0082455'],
#  ['chebi:150752'],
#  ['SLM:000612119'],
#  ['hmdb:HMDB0202960'],
#  ['hmdb:HMDB0248316'],
#  ['chebi:232899'],
#  ['vmhM:oddi27coa'],
#  ['hmdb:HMDB0251140'],
#  ['keggD:D10623'],
#  ['SLM:000294715'],
#  ['hmdb:HMDB0077846'],
#  ['SLM:000735719'],
#  ['SLM:000640508'],
#  ['hmdb:HMDB0234925'],
#  ['SLM:000198219'],
#  ['SLM:000768025'],
#  ['SLM:000194476'],
#  ['chebi:137144'],
#  ['chebi:184250', 'lipidmapsM:LMGP01070002', 'SLM:000049345'],
#  ['lipidmapsM:LMGL03010883', 'SLM:000184834'],
#  ['hmdb:HMDB0050177', 'SLM:000184461'],
#  ['SLM:000001368'],
#  ['chebi:202101'],
#  ['SLM:000534386'],
#  ['hmdb:HMDB0218525'],
#  ['SLM:000214003'],
#  ['SLM:000214081'],
#  ['SLM:000039169'],
#  ['SLM:000708737'],
#  ['SLM:000239966'],
#  ['SLM:000770598'],
#  ['SLM:000533031'],
#  ['SLM:000660672'],
#  ['hmdb:HMDB0247903'],
#  ['SLM:000269502'],
#  ['SLM:000629999'],
#  ['SLM:000561669'],
#  ['SLM:000775307'],
#  ['SLM:000136983'],
#  ['SLM:000136991'],
#  ['SLM:000226386'],
#  ['hmdb:HMDB0252007'],
#  ['SLM:000050823'],
#  ['SLM:000747503'],
#  ['hmdb:HMDB0210525'],
#  ['hmdb:HMDB0267753'],
#  ['hmdb:HMDB0282250'],
#  ['SLM:000647800'],
#  ['chebi:218796'],
#  ['SLM:000031940'],
#  ['hmdb:HMDB0280444'],
#  ['hmdb:HMDB0244438'],
#  ['hmdb:HMDB0303466'],
#  ['chebi:132820'],
#  ['keggC:C22583'],
#  ['SLM:000198043'],
#  ['SLM:000197954'],
#  ['hmdb:HMDB0199050'],
#  ['SLM:000776412'],
#  ['hmdb:HMDB0258379'],
#  ['chebi:228910'],
#  ['SLM:000269819'],
#  ['SLM:000270081'],
#  ['chebi:114435'],
#  ['SLM:000496622'],
#  ['SLM:000492018'],
#  ['SLM:000734935'],
#  ['SLM:000005869'],
#  ['SLM:000028554'],
#  ['hmdb:HMDB0043756', 'SLM:000241119'],
#  ['SLM:000240783'],
#  ['SLM:000567151'],
#  ['SLM:000500230'],
#  ['SLM:000246747'],
#  ['hmdb:HMDB0046150', 'SLM:000246899'],
#  ['hmdb:HMDB0237569'],
#  ['SLM:000759554'],
#  ['hmdb:HMDB0271545'],
#  ['SLM:000638009'],
#  ['SLM:000759367'],
#  ['SLM:000472207'],
#  ['SLM:000752812'],
#  ['hmdb:HMDB0251967'],
#  ['SLM:000047698'],
#  ['SLM:000521239'],
#  ['SLM:000649636'],
#  ['chebi:68039'],
#  ['SLM:000546722'],
#  ['SLM:000201672'],
#  ['hmdb:HMDB0196802'],
#  ['SLM:000292008'],
#  ['SLM:000292077'],
#  ['SLM:000617827'],
#  ['SLM:000179677'],
#  ['SLM:000241338'],
#  ['SLM:000594752'],
#  ['SLM:000764410'],
#  ['hmdb:HMDB0118808'],
#  ['SLM:000509587'],
#  ['SLM:000690517'],
#  ['SLM:000628616'],
#  ['SLM:000195810'],
#  ['SLM:000491340'],
#  ['SLM:000712504'],
#  ['SLM:000157118'],
#  ['SLM:000772397'],
#  ['SLM:000661453'],
#  ['hmdb:HMDB0204892'],
#  ['SLM:000754140'],
#  ['hmdb:HMDB0260664'],
#  ['hmdb:HMDB0088238'],
#  ['SLM:000557762'],
#  ['SLM:000129391'],
#  ['SLM:000129390'],
#  ['SLM:000129322'],
#  ['SLM:000129321'],
#  ['SLM:000653375'],
#  ['SLM:000486344'],
#  ['SLM:000024890'],
#  ['hmdb:HMDB0279084'],
#  ['SLM:000738031'],
#  ['SLM:000523488'],
#  ['hmdb:HMDB0113278'],
#  ['SLM:000219962'],
#  ['chebi:186188'],
#  ['lipidmapsM:LMPK12020253'],
#  ['lipidmapsM:LMSP0601FD01'],
#  ['chebi:220526'],
#  ['SLM:000020343'],
#  ['hmdb:HMDB0048176', 'SLM:000182820'],
#  ['SLM:000182773'],
#  ['chebi:219051'],
#  ['chebi:163766'],
#  ['SLM:000288643'],
#  ['SLM:000288695'],
#  ['SLM:000303762'],
#  ['SLM:000189264'],
#  ['hmdb:HMDB0285349'],
#  ['chebi:105205'],
#  ['SLM:000686659'],
#  ['SLM:000504168'],
#  ['SLM:000305511'],
#  ['SLM:000273774'],
#  ['SLM:000273762'],
#  ['chebi:215405'],
#  ['SLM:000301718'],
#  ['SLM:000301841'],
#  ['chebi:215681'],
#  ['chebi:151607'],
#  ['chebi:155484'],
#  ['chebi:152128'],
#  ['chebi:151508'],
#  ['chebi:149125'],
#  ['chebi:152190'],
#  ['chebi:154124'],
#  ['chebi:147642'],
#  ['chebi:154164'],
#  ['chebi:114925'],
#  ['SLM:000778411'],
#  ['SLM:000778410'],
#  ['SLM:000613750'],
#  ['chebi:178205'],
#  ['lipidmapsM:LMGL03016846'],
#  ['SLM:000535927'],
#  ['hmdb:HMDB0235717'],
#  ['SLM:000238445'],
#  ['SLM:000673585'],
#  ['chebi:79955', 'keggC:C15458', 'seedM:cpd11148'],
#  ['SLM:000211875'],
#  ['SLM:000675900'],
#  ['SLM:000051654'],
#  ['chebi:203387'],
#  ['SLM:000214482'],
#  ['SLM:000753329'],
#  ['SLM:000720321'],
#  ['SLM:000299142'],
#  ['SLM:000299107'],
#  ['SLM:000502229'],
#  ['SLM:000543602'],
#  ['chebi:199986'],
#  ['hmdb:HMDB0216467'],
#  ['SLM:000178069'],
#  ['hmdb:HMDB0190586'],
#  ['hmdb:HMDB0246116'],
#  ['SLM:000649147'],
#  ['SLM:000558244'],
#  ['SLM:000526963'],
#  ['SLM:000208061'],
#  ['SLM:000207508'],
#  ['hmdb:HMDB0214020'],
#  ['SLM:000729334'],
#  ['chebi:224674'],
#  ['chebi:219347'],
#  ['chebi:226503'],
#  ['chebi:186389'],
#  ['SLM:000578269'],
#  ['hmdb:HMDB0092892'],
#  ['SLM:000642073'],
#  ['chebi:228005'],
#  ['chebi:190556'],
#  ['hmdb:HMDB0110057'],
#  ['hmdb:HMDB0065182'],
#  ['chebi:112844'],
#  ['chebi:149578',
#   'hmdb:HMDB0009404',
#   'lipidmapsM:LMGP02010959',
#   'SLM:000033119'],
#  ['hmdb:HMDB0220627'],
#  ['chebi:160445'],
#  ['SLM:000638480'],
#  ['hmdb:HMDB0088009'],
#  ['SLM:000749640'],
#  ['SLM:000651796'],
#  ['SLM:000563390'],
#  ['hmdb:HMDB0204087'],
#  ['chebi:62591', 'lipidmapsM:LMFA01160011'],
#  ['chebi:62590', 'lipidmapsM:LMFA01160012'],
#  ['chebi:62592', 'lipidmapsM:LMFA01160013'],
#  ['chebi:62593', 'lipidmapsM:LMFA01160014'],
#  ['SLM:000597165'],
#  ['hmdb:HMDB0076329'],
#  ['SLM:000588995'],
#  ['hmdb:HMDB0056550'],
#  ['hmdb:HMDB0110962'],
#  ['SLM:000510257'],
#  ['hmdb:HMDB0038150'],
#  ['chebi:215940'],
#  ['SLM:000734641'],
#  ['chebi:182960', 'keggC:C21923'],
#  ['seedM:cpd33775'],
#  ['SLM:000757722'],
#  ['SLM:000450807'],
#  ['SLM:000564668'],
#  ['chebi:59310'],
#  ['hmdb:HMDB0105583'],
#  ['hmdb:HMDB0095137'],
#  ['SLM:000585077'],
#  ['seedM:cpd34355'],
#  ['SLM:000461370'],
#  ['SLM:000051510'],
#  ['SLM:000495132'],
#  ['SLM:000492500'],
#  ['chebi:163182'],
#  ['lipidmapsM:LMST01110009'],
#  ['hmdb:HMDB0033815'],
#  ['SLM:000251317'],
#  ['SLM:000251632'],
#  ['chebi:206231'],
#  ['hmdb:HMDB0033020'],
#  ['chebi:190726'],
#  ['chebi:105662'],
#  ['SLM:000196278'],
#  ['SLM:000196307'],
#  ['SLM:000248171'],
#  ['SLM:000248304'],
#  ['SLM:000190859'],
#  ['SLM:000571266'],
#  ['SLM:000283663'],
#  ['SLM:000283863'],
#  ['SLM:000637695'],
#  ['hmdb:HMDB0302118'],
#  ['SLM:000034391'],
#  ['SLM:000625062'],
#  ['hmdb:HMDB0214315'],
#  ['chebi:80445', 'keggC:C16324', 'vmhM:eodctnt'],
#  ['seedM:cpd15040'],
#  ['SLM:000496400'],
#  ['SLM:000491796'],
#  ['SLM:000483636'],
#  ['SLM:000664783'],
#  ['SLM:000738740'],
#  ['hmdb:HMDB0221872'],
#  ['SLM:000706692'],
#  ['SLM:000178939'],
#  ['SLM:000178989'],
#  ['SLM:000483950'],
#  ['SLM:000471810'],
#  ['SLM:000166388'],
#  ['SLM:000166406'],
#  ['SLM:000536682'],
#  ['SLM:000652873'],
#  ['hmdb:HMDB0220252'],
#  ['SLM:000645181'],
#  ['SLM:000444802'],
#  ['SLM:000010677'],
#  ['SLM:000467624'],
#  ['SLM:000429235'],
#  ['SLM:000128007'],
#  ['SLM:000128013'],
#  ['SLM:000736648'],
#  ['SLM:000476098'],
#  ['SLM:000212599'],
#  ['SLM:000213159'],
#  ['SLM:000626146'],
#  ['SLM:000626132'],
#  ['hmdb:HMDB0230202'],
#  ['hmdb:HMDB0269203'],
#  ['SLM:000143671'],
#  ['SLM:000134548'],
#  ['SLM:000612418'],
#  ['hmdb:HMDB0035360'],
#  ['chebi:166564'],
#  ['SLM:000023296'],
#  ['chebi:176280', 'lipidmapsM:LMSP03010079', 'SLM:000395860'],
#  ['SLM:000610537'],
#  ['SLM:000270461'],
#  ['SLM:000722803'],
#  ['hmdb:HMDB0248833'],
#  ['chebi:63235'],
#  ['chebi:156835'],
#  ['chebi:144270'],
#  ['lipidmapsM:LMGL03012194', 'SLM:000220265'],
#  ['hmdb:HMDB0049049', 'SLM:000220197'],
#  ['hmdb:HMDB0078184'],
#  ['keggC:C11936'],
#  ['seedM:cpd08733'],
#  ['SLM:000446374'],
#  ['SLM:000461795'],
#  ['chebi:189001'],
#  ['chebi:114785', 'hmdb:HMDB0014671', 'keggD:D07907'],
#  ['chebi:169422', 'hmdb:HMDB0037094'],
#  ['SLM:000718016'],
#  ['chebi:93435', 'lipidmapsM:LMPK12160022'],
#  ['SLM:000540095'],
#  ['SLM:000640399'],
#  ['SLM:000051985'],
#  ['hmdb:HMDB0289295'],
#  ['lipidmapsM:LMPR01080037'],
#  ['SLM:000256232'],
#  ['SLM:000256202'],
#  ['SLM:000459154'],
#  ['chebi:210753'],
#  ['SLM:000543680'],
#  ['SLM:000774300'],
#  ['SLM:000016256'],
#  ['chebi:53694'],
#  ['SLM:000574055'],
#  ['chebi:73577'],
#  ['SLM:000197557'],
#  ['SLM:000197727'],
#  ['SLM:000544169'],
#  ['chebi:121320'],
#  ['SLM:000737466'],
#  ['SLM:000305529'],
#  ['SLM:000305533'],
#  ['SLM:000157946'],
#  ['lipidmapsM:LMSP0601CA06'],
#  ['SLM:000765016'],
#  ['SLM:000001393'],
#  ['SLM:000694875'],
#  ['SLM:000305227'],
#  ['SLM:000736792'],
#  ['SLM:000147061'],
#  ['hmdb:HMDB0058377'],
#  ['SLM:000551869'],
#  ['SLM:000667649'],
#  ['SLM:000217691'],
#  ['SLM:000589773'],
#  ['chebi:154550'],
#  ['hmdb:HMDB0195950'],
#  ['SLM:000669302'],
#  ['lipidmapsM:LMGL03014111', 'SLM:000195239'],
#  ['SLM:000195253'],
#  ['chebi:109500'],
#  ['SLM:000618646'],
#  ['SLM:000547623'],
#  ['hmdb:HMDB0082177'],
#  ['hmdb:HMDB0209308'],
#  ['SLM:000585193'],
#  ['SLM:000132266'],
#  ['SLM:000609106'],
#  ['SLM:000236996'],
#  ['chebi:27494', 'keggC:C10530', 'lipidmapsM:LMPK12050480', 'seedM:cpd07416'],
#  ['SLM:000613667'],
#  ['chebi:195053'],
#  ['hmdb:HMDB0218540'],
#  ['SLM:000151944'],
#  ['SLM:000723250'],
#  ['hmdb:HMDB0231751'],
#  ['hmdb:HMDB0036837'],
#  ['chebi:3829', 'keggC:C09077', 'seedM:cpd05973'],
#  ['chebi:81144', 'keggC:C17508', 'seedM:cpd17634'],
#  ['SLM:000450501'],
#  ['hmdb:HMDB0259679'],
#  ['hmdb:HMDB0082312'],
#  ['SLM:000265752'],
#  ['SLM:000265890'],
#  ['chebi:92486'],
#  ['SLM:000741082'],
#  ['SLM:000686603'],
#  ['SLM:000300230'],
#  ['SLM:000300247'],
#  ['hmdb:HMDB0241140'],
#  ['SLM:000724415'],
#  ['SLM:000721448'],
#  ['lipidmapsM:LMST01010446'],
#  ['seedM:cpd24563'],
#  ['hmdb:HMDB0012117'],
#  ['SLM:000615063'],
#  ['chebi:123154'],
#  ['hmdb:HMDB0251668'],
#  ['SLM:000006211'],
#  ['SLM:000621131'],
#  ['chebi:173631', 'hmdb:HMDB0031639'],
#  ['SLM:000502973'],
#  ['SLM:000467943'],
#  ['SLM:000429554'],
#  ['hmdb:HMDB0039950'],
#  ['SLM:000011910'],
#  ['hmdb:HMDB0056626'],
#  ['SLM:000516703'],
#  ['chebi:213601'],
#  ['SLM:000695612'],
#  ['SLM:000713759'],
#  ['hmdb:HMDB0202203'],
#  ['SLM:000298713'],
#  ['SLM:000119742'],
#  ['hmdb:HMDB0112492', 'lipidmapsM:LMGP03010437'],
#  ['SLM:000004116'],
#  ['SLM:000517383'],
#  ['hmdb:HMDB0262752'],
#  ['SLM:000395949'],
#  ['SLM:000519675'],
#  ['hmdb:HMDB0208335'],
#  ['chebi:32284', 'keggC:C12410', 'seedM:cpd09163'],
#  ['hmdb:HMDB0280025'],
#  ['SLM:000518444'],
#  ['SLM:000038530'],
#  ['hmdb:HMDB0201998'],
#  ['SLM:000179668'],
#  ['SLM:000179358'],
#  ['chebi:193788'],
#  ['hmdb:HMDB0094767'],
#  ['SLM:000522280'],
#  ['chebi:193245'],
#  ['SLM:000162609'],
#  ['SLM:000162314'],
#  ['hmdb:HMDB0120383'],
#  ['chebi:92902'],
#  ['hmdb:HMDB0289821'],
#  ['SLM:000596734'],
#  ['SLM:000724742'],
#  ['SLM:000017478'],
#  ['SLM:000563977'],
#  ['SLM:000288423'],
#  ['SLM:000267495'],
#  ['SLM:000267569'],
#  ['SLM:000717901'],
#  ['SLM:000470967'],
#  ['hmdb:HMDB0210172'],
#  ['hmdb:HMDB0221808'],
#  ['hmdb:HMDB0288363'],
#  ['SLM:000740257'],
#  ['hmdb:HMDB0257564'],
#  ['hmdb:HMDB0267532'],
#  ['SLM:000496656'],
#  ['SLM:000492052'],
#  ['hmdb:HMDB0281038'],
#  ['SLM:000473596'],
#  ['SLM:000010500'],
#  ['SLM:000442406'],
#  ['SLM:000718066'],
#  ['chebi:137838', 'lipidmapsM:LMFA07040007'],
#  ['SLM:000580126'],
#  ['lipidmapsM:LMPK15020006'],
#  ['chebi:207429'],
#  ['SLM:000146776'],
#  ['SLM:000146758'],
#  ['SLM:000586632'],
#  ['SLM:000266811'],
#  ['hmdb:HMDB0053726', 'SLM:000266827'],
#  ['SLM:000202802'],
#  ['SLM:000202790'],
#  ['hmdb:HMDB0092929'],
#  ['SLM:000498611'],
#  ['chebi:69288'],
#  ['chebi:69289'],
#  ['SLM:000628949'],
#  ['SLM:000510983'],
#  ['SLM:000754846'],
#  ['SLM:000754845'],
#  ['SLM:000209994'],
#  ['SLM:000209992'],
#  ['SLM:000209950'],
#  ['SLM:000209948'],
#  ['SLM:000209496'],
#  ['SLM:000209492'],
#  ['SLM:000209495'],
#  ['hmdb:HMDB0049279', 'SLM:000209491'],
#  ['chebi:233032'],
#  ['chebi:230491'],
#  ['SLM:000725153'],
#  ['chebi:117410'],
#  ['chebi:117522'],
#  ['chebi:117555'],
#  ['chebi:117326'],
#  ['chebi:117548'],
#  ['chebi:117505'],
#  ['chebi:117392'],
#  ['chebi:117283'],
#  ['SLM:000487143'],
#  ['chebi:197363'],
#  ['SLM:000645984'],
#  ['SLM:000668764'],
#  ['SLM:000733870'],
#  ['SLM:000248981'],
#  ['SLM:000248980'],
#  ['SLM:000248613'],
#  ['hmdb:HMDB0051576', 'SLM:000248612'],
#  ['hmdb:HMDB0288274'],
#  ['SLM:000674434'],
#  ['hmdb:HMDB0199583'],
#  ['SLM:000253818'],
#  ['SLM:000253816'],
#  ['SLM:000253925'],
#  ['SLM:000253924'],
#  ['SLM:000447660'],
#  ['hmdb:HMDB0294869'],
#  ['chebi:232314'],
#  ['hmdb:HMDB0293344'],
#  ['SLM:000558922'],
#  ['chebi:184785'],
#  ['lipidmapsM:LMPK12110885'],
#  ['SLM:000474067'],
#  ['SLM:000726964'],
#  ['SLM:000616613'],
#  ['hmdb:HMDB0124536'],
#  ['SLM:000046952'],
#  ['SLM:000053286'],
#  ['chebi:229380', 'hmdb:HMDB0035929'],
#  ['SLM:000663214'],
#  ['SLM:000541992'],
#  ['SLM:000551146'],
#  ['lipidmapsM:LMGL03011881'],
#  ['SLM:000217085'],
#  ['SLM:000527012'],
#  ['SLM:000286545'],
#  ['SLM:000286557'],
#  ['SLM:000447764'],
#  ['SLM:000240216'],
#  ['SLM:000240260'],
#  ['SLM:000196412'],
#  ['SLM:000635212'],
#  ['hmdb:HMDB0080737'],
#  ['chebi:217658'],
#  ['SLM:000192289'],
#  ['SLM:000772774'],
#  ['SLM:000642906'],
#  ['hmdb:HMDB0241231'],
#  ['SLM:000185771'],
#  ['SLM:000570845'],
#  ['SLM:000019355'],
#  ['SLM:000572525'],
#  ['SLM:000217958'],
#  ['SLM:000218009'],
#  ['SLM:000512264'],
#  ['SLM:000665433'],
#  ['SLM:000644477'],
#  ['hmdb:HMDB0199934'],
#  ['SLM:000684645'],
#  ['SLM:000575008'],
#  ['chebi:228730'],
#  ['SLM:000625076'],
#  ['SLM:000137080'],
#  ['SLM:000300544'],
#  ['SLM:000659952'],
#  ['SLM:000668085'],
#  ['SLM:000134047'],
#  ['SLM:000134174'],
#  ['hmdb:HMDB0274173'],
#  ['chebi:161962'],
#  ['hmdb:HMDB0084880'],
#  ['SLM:000160104'],
#  ['SLM:000553053'],
#  ['SLM:000464652'],
#  ['SLM:000426263'],
#  ['SLM:000491273'],
#  ['SLM:000572222'],
#  ['SLM:000585953'],
#  ['chebi:169463', 'hmdb:HMDB0034047'],
#  ['hmdb:HMDB0237461'],
#  ['hmdb:HMDB0299656'],
#  ['SLM:000628258'],
#  ['SLM:000673290'],
#  ['SLM:000672114'],
#  ['SLM:000525155'],
#  ['chebi:179894', 'lipidmapsM:LMFA01020345'],
#  ['SLM:000614351'],
#  ['hmdb:HMDB0263308'],
#  ['SLM:000274626'],
#  ['SLM:000274673'],
#  ['SLM:000181581'],
#  ['SLM:000181611'],
#  ['SLM:000255852'],
#  ['SLM:000255785'],
#  ['hmdb:HMDB0234094'],
#  ['SLM:000302214'],
#  ['SLM:000543773'],
#  ['SLM:000697692'],
#  ['SLM:000760976'],
#  ['SLM:000635700'],
#  ['hmdb:HMDB0077210'],
#  ['chebi:199154'],
#  ['SLM:000131358'],
#  ['chebi:184417', 'hmdb:HMDB0038357'],
#  ['chebi:81326', 'keggC:C17773', 'seedM:cpd17862'],
#  ['chebi:81325', 'keggC:C17772', 'seedM:cpd17861'],
#  ['chebi:79187'],
#  ['chebi:78318'],
#  ['chebi:166171'],
#  ['SLM:000754991'],
#  ['chebi:107654'],
#  ['chebi:32992'],
#  ['chebi:123164'],
#  ['chebi:159798'],
#  ['hmdb:HMDB0286432'],
#  ['hmdb:HMDB0066082'],
#  ['hmdb:HMDB0108317'],
#  ['SLM:000750007'],
#  ['SLM:000614034'],
#  ['chebi:49575',
#   'hmdb:HMDB0014967',
#   'keggC:C06948',
#   'keggD:D00293',
#   'vmhM:C06948',
#   'seedM:cpd04280'],
#  ['chebi:178121', 'hmdb:HMDB0034694'],
#  ['chebi:85132'],
#  ['SLM:000268060'],
#  ['SLM:000267950'],
#  ['lipidmapsM:LMGL03015778'],
#  ['chebi:171321', 'hmdb:HMDB0050061', 'SLM:000191816'],
#  ['SLM:000654995'],
#  ['SLM:000251393'],
#  ['SLM:000251762'],
#  ['chebi:185358', 'lipidmapsM:LMST04020001'],
#  ['hmdb:HMDB0192245'],
#  ['SLM:000123962'],
#  ['SLM:000679246'],
#  ['SLM:000634117'],
#  ['chebi:207656'],
#  ['hmdb:HMDB0303135'],
#  ['chebi:173630', 'hmdb:HMDB0041392'],
#  ['SLM:000202870'],
#  ['SLM:000202869'],
#  ['SLM:000218554'],
#  ['chebi:116932'],
#  ['SLM:000482908'],
#  ['SLM:000549404'],
#  ['SLM:000033283'],
#  ['SLM:000125870'],
#  ['hmdb:HMDB0007756', 'SLM:000125842'],
#  ['SLM:000738706'],
#  ['chebi:29554', 'keggC:C12036'],
#  ['seedM:cpd08827'],
#  ['chebi:120791'],
#  ['SLM:000745224'],
#  ['hmdb:HMDB0290229'],
#  ['SLM:000629135'],
#  ['SLM:000016402'],
#  ['SLM:000519355'],
#  ['SLM:000677104'],
#  ['SLM:000180218'],
#  ['SLM:000180482'],
#  ['SLM:000449583'],
#  ['hmdb:HMDB0279373'],
#  ['SLM:000164512'],
#  ['SLM:000502476'],
#  ['SLM:000649142'],
#  ['hmdb:HMDB0214924'],
#  ['chebi:142828'],
#  ['SLM:000118431'],
#  ['SLM:000118453'],
#  ['SLM:000259475'],
#  ['SLM:000252672'],
#  ['SLM:000252894'],
#  ['SLM:000530939'],
#  ['SLM:000768307'],
#  ['hmdb:HMDB0227765'],
#  ['SLM:000637686'],
#  ['SLM:000130729'],
#  ['SLM:000568778'],
#  ['SLM:000460001'],
#  ['SLM:000777091'],
#  ['hmdb:HMDB0251794'],
#  ['SLM:000242781'],
#  ['SLM:000242660'],
#  ...]

# %%
# now extract 'mnx_id' and 'label' from df_dedup
dedup_dict = dict(zip(df_dedup['dedup_label'], df_dedup['mnx_ref']))
dedup_dict
# Out:
# {'seedM:cpd11416': 'https://rdf.metanetx.org/chem/BIOMASS',
#  'vmhM:oh1': 'https://rdf.metanetx.org/chem/MNXM02',
#  'chebi:13365': 'https://rdf.metanetx.org/chem/MNXM02',
#  'chebi:13419': 'https://rdf.metanetx.org/chem/MNXM02',
#  'chebi:16234': 'https://rdf.metanetx.org/chem/MNXM02',
#  'chebi:29356': 'https://rdf.metanetx.org/chem/MNXM02',
#  'chebi:44641': 'https://rdf.metanetx.org/chem/MNXM02',
#  'chebi:5594': 'https://rdf.metanetx.org/chem/MNXM02',
#  'hmdb:HMDB0001039': 'https://rdf.metanetx.org/chem/MNXM02',
#  'hmdb:HMDB01039': 'https://rdf.metanetx.org/chem/MNXM02',
#  'keggC:C01328': 'https://rdf.metanetx.org/chem/MNXM02',
#  'seedM:cpd15275': 'https://rdf.metanetx.org/chem/MNXM02',
#  'chebi:29412': 'https://rdf.metanetx.org/chem/MNXM03',
#  'vmhM:h': 'https://rdf.metanetx.org/chem/MNXM1',
#  'vmhM:HC02115': 'https://rdf.metanetx.org/chem/MNXM1',
#  'chebi:10744': 'https://rdf.metanetx.org/chem/MNXM1',
#  'chebi:13357': 'https://rdf.metanetx.org/chem/MNXM1',
#  'chebi:15378': 'https://rdf.metanetx.org/chem/MNXM1',
#  'chebi:24636': 'https://rdf.metanetx.org/chem/MNXM1',
#  'chebi:29233': 'https://rdf.metanetx.org/chem/MNXM1',
#  'chebi:29234': 'https://rdf.metanetx.org/chem/MNXM1',
#  'chebi:5584': 'https://rdf.metanetx.org/chem/MNXM1',
#  'hmdb:HMDB0059597': 'https://rdf.metanetx.org/chem/MNXM1',
#  'hmdb:HMDB59597': 'https://rdf.metanetx.org/chem/MNXM1',
#  'keggC:C00080': 'https://rdf.metanetx.org/chem/MNXM1',
#  'sabiorkM:39': 'https://rdf.metanetx.org/chem/MNXM1',
#  'seedM:cpd00067': 'https://rdf.metanetx.org/chem/MNXM1',
#  'vmhM:nadh': 'https://rdf.metanetx.org/chem/MNXM10',
#  'chebi:13395': 'https://rdf.metanetx.org/chem/MNXM10',
#  'chebi:13396': 'https://rdf.metanetx.org/chem/MNXM10',
#  'chebi:16908': 'https://rdf.metanetx.org/chem/MNXM10',
#  'chebi:21902': 'https://rdf.metanetx.org/chem/MNXM10',
#  'chebi:44216': 'https://rdf.metanetx.org/chem/MNXM10',
#  'chebi:57945': 'https://rdf.metanetx.org/chem/MNXM10',
#  'chebi:7423': 'https://rdf.metanetx.org/chem/MNXM10',
#  'hmdb:HMDB0001487': 'https://rdf.metanetx.org/chem/MNXM10',
#  'hmdb:HMDB01487': 'https://rdf.metanetx.org/chem/MNXM10',
#  'keggC:C00004': 'https://rdf.metanetx.org/chem/MNXM10',
#  'sabiorkM:38': 'https://rdf.metanetx.org/chem/MNXM10',
#  'seedM:cpd00004': 'https://rdf.metanetx.org/chem/MNXM10',
#  'vmhM:grdp': 'https://rdf.metanetx.org/chem/MNXM100',
#  'SLM:000000305': 'https://rdf.metanetx.org/chem/MNXM100',
#  'chebi:14299': 'https://rdf.metanetx.org/chem/MNXM100',
#  'chebi:17211': 'https://rdf.metanetx.org/chem/MNXM100',
#  'chebi:24223': 'https://rdf.metanetx.org/chem/MNXM100',
#  'chebi:42877': 'https://rdf.metanetx.org/chem/MNXM100',
#  'chebi:5332': 'https://rdf.metanetx.org/chem/MNXM100',
#  'chebi:58057': 'https://rdf.metanetx.org/chem/MNXM100',
#  'hmdb:HMDB0001285': 'https://rdf.metanetx.org/chem/MNXM100',
#  'hmdb:HMDB0001560': 'https://rdf.metanetx.org/chem/MNXM100',
#  'hmdb:HMDB0002239': 'https://rdf.metanetx.org/chem/MNXM100',
#  'hmdb:HMDB0006506': 'https://rdf.metanetx.org/chem/MNXM100',
#  'hmdb:HMDB01285': 'https://rdf.metanetx.org/chem/MNXM100',
#  'hmdb:HMDB01560': 'https://rdf.metanetx.org/chem/MNXM100',
#  'hmdb:HMDB02239': 'https://rdf.metanetx.org/chem/MNXM100',
#  'hmdb:HMDB06506': 'https://rdf.metanetx.org/chem/MNXM100',
#  'keggC:C00341': 'https://rdf.metanetx.org/chem/MNXM100',
#  'sabiorkM:1846': 'https://rdf.metanetx.org/chem/MNXM100',
#  'sabiorkM:5050': 'https://rdf.metanetx.org/chem/MNXM100',
#  'seedM:cpd00283': 'https://rdf.metanetx.org/chem/MNXM100',
#  'seedM:cpd03476': 'https://rdf.metanetx.org/chem/MNXM100',
#  'lipidmapsM:LMPR0102010001': 'https://rdf.metanetx.org/chem/MNXM100',
#  'chebi:165749': 'https://rdf.metanetx.org/chem/MNXM100000',
#  'lipidmapsM:LMFA12000218': 'https://rdf.metanetx.org/chem/MNXM100000',
#  'SLM:000692388': 'https://rdf.metanetx.org/chem/MNXM1000000',
#  'SLM:000692389': 'https://rdf.metanetx.org/chem/MNXM1000001',
#  'SLM:000692390': 'https://rdf.metanetx.org/chem/MNXM1000002',
#  'SLM:000692391': 'https://rdf.metanetx.org/chem/MNXM1000003',
#  'SLM:000692392': 'https://rdf.metanetx.org/chem/MNXM1000004',
#  'SLM:000692393': 'https://rdf.metanetx.org/chem/MNXM1000005',
#  'SLM:000692394': 'https://rdf.metanetx.org/chem/MNXM1000006',
#  'SLM:000692395': 'https://rdf.metanetx.org/chem/MNXM1000007',
#  'SLM:000692396': 'https://rdf.metanetx.org/chem/MNXM1000008',
#  'SLM:000692397': 'https://rdf.metanetx.org/chem/MNXM1000009',
#  'lipidmapsM:LMFA11000413': 'https://rdf.metanetx.org/chem/MNXM100001',
#  'SLM:000692398': 'https://rdf.metanetx.org/chem/MNXM1000010',
#  'SLM:000692399': 'https://rdf.metanetx.org/chem/MNXM1000011',
#  'SLM:000692400': 'https://rdf.metanetx.org/chem/MNXM1000012',
#  'SLM:000692401': 'https://rdf.metanetx.org/chem/MNXM1000013',
#  'SLM:000692402': 'https://rdf.metanetx.org/chem/MNXM1000014',
#  'SLM:000692403': 'https://rdf.metanetx.org/chem/MNXM1000015',
#  'SLM:000692404': 'https://rdf.metanetx.org/chem/MNXM1000016',
#  'SLM:000692405': 'https://rdf.metanetx.org/chem/MNXM1000017',
#  'SLM:000692406': 'https://rdf.metanetx.org/chem/MNXM1000018',
#  'SLM:000692407': 'https://rdf.metanetx.org/chem/MNXM1000019',
#  'lipidmapsM:LMFA11000539': 'https://rdf.metanetx.org/chem/MNXM100002',
#  'SLM:000692408': 'https://rdf.metanetx.org/chem/MNXM1000020',
#  'SLM:000692409': 'https://rdf.metanetx.org/chem/MNXM1000021',
#  'SLM:000692410': 'https://rdf.metanetx.org/chem/MNXM1000022',
#  'SLM:000692411': 'https://rdf.metanetx.org/chem/MNXM1000023',
#  'SLM:000692412': 'https://rdf.metanetx.org/chem/MNXM1000024',
#  'SLM:000692413': 'https://rdf.metanetx.org/chem/MNXM1000025',
#  'SLM:000692414': 'https://rdf.metanetx.org/chem/MNXM1000026',
#  'SLM:000692415': 'https://rdf.metanetx.org/chem/MNXM1000027',
#  'SLM:000692416': 'https://rdf.metanetx.org/chem/MNXM1000028',
#  'SLM:000692417': 'https://rdf.metanetx.org/chem/MNXM1000029',
#  'chebi:179593': 'https://rdf.metanetx.org/chem/MNXM100003',
#  'lipidmapsM:LMFA12000301': 'https://rdf.metanetx.org/chem/MNXM100003',
#  'SLM:000692418': 'https://rdf.metanetx.org/chem/MNXM1000030',
#  'SLM:000692419': 'https://rdf.metanetx.org/chem/MNXM1000031',
#  'SLM:000692420': 'https://rdf.metanetx.org/chem/MNXM1000032',
#  'SLM:000692421': 'https://rdf.metanetx.org/chem/MNXM1000033',
#  'SLM:000692422': 'https://rdf.metanetx.org/chem/MNXM1000034',
#  'SLM:000692423': 'https://rdf.metanetx.org/chem/MNXM1000035',
#  'SLM:000692424': 'https://rdf.metanetx.org/chem/MNXM1000036',
#  'SLM:000692425': 'https://rdf.metanetx.org/chem/MNXM1000037',
#  'SLM:000692426': 'https://rdf.metanetx.org/chem/MNXM1000038',
#  'SLM:000692427': 'https://rdf.metanetx.org/chem/MNXM1000039',
#  'chebi:196064': 'https://rdf.metanetx.org/chem/MNXM100004',
#  'lipidmapsM:LMFA07010530': 'https://rdf.metanetx.org/chem/MNXM100004',
#  'SLM:000692428': 'https://rdf.metanetx.org/chem/MNXM1000040',
#  'SLM:000692429': 'https://rdf.metanetx.org/chem/MNXM1000041',
#  'SLM:000692430': 'https://rdf.metanetx.org/chem/MNXM1000042',
#  'SLM:000692431': 'https://rdf.metanetx.org/chem/MNXM1000043',
#  'SLM:000692432': 'https://rdf.metanetx.org/chem/MNXM1000044',
#  'SLM:000692433': 'https://rdf.metanetx.org/chem/MNXM1000045',
#  'SLM:000692434': 'https://rdf.metanetx.org/chem/MNXM1000046',
#  'SLM:000692435': 'https://rdf.metanetx.org/chem/MNXM1000047',
#  'SLM:000692436': 'https://rdf.metanetx.org/chem/MNXM1000048',
#  'SLM:000692437': 'https://rdf.metanetx.org/chem/MNXM1000049',
#  'chebi:196177': 'https://rdf.metanetx.org/chem/MNXM100005',
#  'lipidmapsM:LMFA07010368': 'https://rdf.metanetx.org/chem/MNXM100005',
#  'SLM:000692438': 'https://rdf.metanetx.org/chem/MNXM1000050',
#  'SLM:000692439': 'https://rdf.metanetx.org/chem/MNXM1000051',
#  'SLM:000692440': 'https://rdf.metanetx.org/chem/MNXM1000052',
#  'SLM:000692441': 'https://rdf.metanetx.org/chem/MNXM1000053',
#  'SLM:000692442': 'https://rdf.metanetx.org/chem/MNXM1000054',
#  'SLM:000692443': 'https://rdf.metanetx.org/chem/MNXM1000055',
#  'SLM:000692444': 'https://rdf.metanetx.org/chem/MNXM1000056',
#  'SLM:000692445': 'https://rdf.metanetx.org/chem/MNXM1000057',
#  'SLM:000692446': 'https://rdf.metanetx.org/chem/MNXM1000058',
#  'SLM:000692447': 'https://rdf.metanetx.org/chem/MNXM1000059',
#  'chebi:179952': 'https://rdf.metanetx.org/chem/MNXM100006',
#  'chebi:179953': 'https://rdf.metanetx.org/chem/MNXM100006',
#  'lipidmapsM:LMFA12000119': 'https://rdf.metanetx.org/chem/MNXM100006',
#  'lipidmapsM:LMFA12000123': 'https://rdf.metanetx.org/chem/MNXM100006',
#  'SLM:000692448': 'https://rdf.metanetx.org/chem/MNXM1000060',
#  'SLM:000692449': 'https://rdf.metanetx.org/chem/MNXM1000061',
#  'SLM:000692450': 'https://rdf.metanetx.org/chem/MNXM1000062',
#  'SLM:000692451': 'https://rdf.metanetx.org/chem/MNXM1000063',
#  'SLM:000692452': 'https://rdf.metanetx.org/chem/MNXM1000064',
#  'SLM:000692453': 'https://rdf.metanetx.org/chem/MNXM1000065',
#  'SLM:000692454': 'https://rdf.metanetx.org/chem/MNXM1000066',
#  'SLM:000692455': 'https://rdf.metanetx.org/chem/MNXM1000067',
#  'SLM:000692456': 'https://rdf.metanetx.org/chem/MNXM1000068',
#  'SLM:000692457': 'https://rdf.metanetx.org/chem/MNXM1000069',
#  'chebi:169163': 'https://rdf.metanetx.org/chem/MNXM100007',
#  'lipidmapsM:LMFA07010261': 'https://rdf.metanetx.org/chem/MNXM100007',
#  'SLM:000692458': 'https://rdf.metanetx.org/chem/MNXM1000070',
#  'SLM:000692459': 'https://rdf.metanetx.org/chem/MNXM1000071',
#  'SLM:000692460': 'https://rdf.metanetx.org/chem/MNXM1000072',
#  'SLM:000692461': 'https://rdf.metanetx.org/chem/MNXM1000073',
#  'SLM:000692462': 'https://rdf.metanetx.org/chem/MNXM1000074',
#  'SLM:000692463': 'https://rdf.metanetx.org/chem/MNXM1000075',
#  'SLM:000692464': 'https://rdf.metanetx.org/chem/MNXM1000076',
#  'SLM:000692465': 'https://rdf.metanetx.org/chem/MNXM1000077',
#  'SLM:000692466': 'https://rdf.metanetx.org/chem/MNXM1000078',
#  'SLM:000692467': 'https://rdf.metanetx.org/chem/MNXM1000079',
#  'SLM:000692468': 'https://rdf.metanetx.org/chem/MNXM1000080',
#  'SLM:000692469': 'https://rdf.metanetx.org/chem/MNXM1000081',
#  'SLM:000692470': 'https://rdf.metanetx.org/chem/MNXM1000082',
#  'SLM:000692471': 'https://rdf.metanetx.org/chem/MNXM1000083',
#  'SLM:000692472': 'https://rdf.metanetx.org/chem/MNXM1000084',
#  'SLM:000692473': 'https://rdf.metanetx.org/chem/MNXM1000085',
#  'SLM:000692474': 'https://rdf.metanetx.org/chem/MNXM1000086',
#  'SLM:000692475': 'https://rdf.metanetx.org/chem/MNXM1000087',
#  'SLM:000692476': 'https://rdf.metanetx.org/chem/MNXM1000088',
#  'SLM:000692477': 'https://rdf.metanetx.org/chem/MNXM1000089',
#  'chebi:179779': 'https://rdf.metanetx.org/chem/MNXM100009',
#  'hmdb:HMDB0037312': 'https://rdf.metanetx.org/chem/MNXM100009',
#  'hmdb:HMDB37312': 'https://rdf.metanetx.org/chem/MNXM100009',
#  'lipidmapsM:LMFA07010422': 'https://rdf.metanetx.org/chem/MNXM100009',
#  'SLM:000692478': 'https://rdf.metanetx.org/chem/MNXM1000090',
#  'SLM:000692479': 'https://rdf.metanetx.org/chem/MNXM1000091',
#  'SLM:000692480': 'https://rdf.metanetx.org/chem/MNXM1000092',
#  'SLM:000692481': 'https://rdf.metanetx.org/chem/MNXM1000093',
#  'SLM:000692482': 'https://rdf.metanetx.org/chem/MNXM1000094',
#  'SLM:000692483': 'https://rdf.metanetx.org/chem/MNXM1000095',
#  'SLM:000692484': 'https://rdf.metanetx.org/chem/MNXM1000096',
#  'SLM:000692485': 'https://rdf.metanetx.org/chem/MNXM1000097',
#  'SLM:000692486': 'https://rdf.metanetx.org/chem/MNXM1000098',
#  'SLM:000692487': 'https://rdf.metanetx.org/chem/MNXM1000099',
#  'chebi:230744': 'https://rdf.metanetx.org/chem/MNXM100010',
#  'lipidmapsM:LMFA11000123': 'https://rdf.metanetx.org/chem/MNXM100010',
#  'SLM:000692488': 'https://rdf.metanetx.org/chem/MNXM1000100',
#  'SLM:000692489': 'https://rdf.metanetx.org/chem/MNXM1000101',
#  'SLM:000692490': 'https://rdf.metanetx.org/chem/MNXM1000102',
#  'SLM:000692491': 'https://rdf.metanetx.org/chem/MNXM1000103',
#  'SLM:000692492': 'https://rdf.metanetx.org/chem/MNXM1000104',
#  'SLM:000692493': 'https://rdf.metanetx.org/chem/MNXM1000105',
#  'SLM:000692494': 'https://rdf.metanetx.org/chem/MNXM1000106',
#  'SLM:000692495': 'https://rdf.metanetx.org/chem/MNXM1000107',
#  'SLM:000692496': 'https://rdf.metanetx.org/chem/MNXM1000108',
#  'SLM:000692497': 'https://rdf.metanetx.org/chem/MNXM1000109',
#  'lipidmapsM:LMFA11000254': 'https://rdf.metanetx.org/chem/MNXM100011',
#  'SLM:000692498': 'https://rdf.metanetx.org/chem/MNXM1000110',
#  'SLM:000692499': 'https://rdf.metanetx.org/chem/MNXM1000111',
#  'SLM:000692500': 'https://rdf.metanetx.org/chem/MNXM1000112',
#  'SLM:000692501': 'https://rdf.metanetx.org/chem/MNXM1000113',
#  'SLM:000692502': 'https://rdf.metanetx.org/chem/MNXM1000114',
#  'SLM:000692503': 'https://rdf.metanetx.org/chem/MNXM1000115',
#  'SLM:000692504': 'https://rdf.metanetx.org/chem/MNXM1000116',
#  'SLM:000692505': 'https://rdf.metanetx.org/chem/MNXM1000117',
#  'SLM:000692506': 'https://rdf.metanetx.org/chem/MNXM1000118',
#  'SLM:000692507': 'https://rdf.metanetx.org/chem/MNXM1000119',
#  'chebi:180345': 'https://rdf.metanetx.org/chem/MNXM100012',
#  'lipidmapsM:LMFA07010384': 'https://rdf.metanetx.org/chem/MNXM100012',
#  'SLM:000692508': 'https://rdf.metanetx.org/chem/MNXM1000120',
#  'SLM:000692509': 'https://rdf.metanetx.org/chem/MNXM1000121',
#  'SLM:000692510': 'https://rdf.metanetx.org/chem/MNXM1000122',
#  'SLM:000692511': 'https://rdf.metanetx.org/chem/MNXM1000123',
#  'SLM:000692512': 'https://rdf.metanetx.org/chem/MNXM1000124',
#  'SLM:000692513': 'https://rdf.metanetx.org/chem/MNXM1000125',
#  'SLM:000692514': 'https://rdf.metanetx.org/chem/MNXM1000126',
#  'SLM:000692515': 'https://rdf.metanetx.org/chem/MNXM1000127',
#  'SLM:000692516': 'https://rdf.metanetx.org/chem/MNXM1000128',
#  'SLM:000692517': 'https://rdf.metanetx.org/chem/MNXM1000129',
#  'chebi:78471': 'https://rdf.metanetx.org/chem/MNXM100013',
#  'lipidmapsM:LMFA11000321': 'https://rdf.metanetx.org/chem/MNXM100013',
#  'SLM:000692518': 'https://rdf.metanetx.org/chem/MNXM1000130',
#  'SLM:000692519': 'https://rdf.metanetx.org/chem/MNXM1000131',
#  'SLM:000692520': 'https://rdf.metanetx.org/chem/MNXM1000132',
#  'SLM:000692521': 'https://rdf.metanetx.org/chem/MNXM1000133',
#  'SLM:000692522': 'https://rdf.metanetx.org/chem/MNXM1000134',
#  'SLM:000692523': 'https://rdf.metanetx.org/chem/MNXM1000135',
#  'SLM:000692524': 'https://rdf.metanetx.org/chem/MNXM1000136',
#  'SLM:000692525': 'https://rdf.metanetx.org/chem/MNXM1000137',
#  'SLM:000692526': 'https://rdf.metanetx.org/chem/MNXM1000138',
#  'SLM:000692527': 'https://rdf.metanetx.org/chem/MNXM1000139',
#  'lipidmapsM:LMFA11000351': 'https://rdf.metanetx.org/chem/MNXM100014',
#  'SLM:000692528': 'https://rdf.metanetx.org/chem/MNXM1000140',
#  'SLM:000692529': 'https://rdf.metanetx.org/chem/MNXM1000141',
#  'SLM:000692530': 'https://rdf.metanetx.org/chem/MNXM1000142',
#  'SLM:000692531': 'https://rdf.metanetx.org/chem/MNXM1000143',
#  'SLM:000692532': 'https://rdf.metanetx.org/chem/MNXM1000144',
#  'SLM:000692533': 'https://rdf.metanetx.org/chem/MNXM1000145',
#  'SLM:000692534': 'https://rdf.metanetx.org/chem/MNXM1000146',
#  'SLM:000692535': 'https://rdf.metanetx.org/chem/MNXM1000147',
#  'SLM:000692536': 'https://rdf.metanetx.org/chem/MNXM1000148',
#  'SLM:000692537': 'https://rdf.metanetx.org/chem/MNXM1000149',
#  'chebi:179501': 'https://rdf.metanetx.org/chem/MNXM100015',
#  'lipidmapsM:LMFA12000174': 'https://rdf.metanetx.org/chem/MNXM100015',
#  'SLM:000692538': 'https://rdf.metanetx.org/chem/MNXM1000150',
#  'SLM:000692539': 'https://rdf.metanetx.org/chem/MNXM1000151',
#  'SLM:000692540': 'https://rdf.metanetx.org/chem/MNXM1000152',
#  'SLM:000692541': 'https://rdf.metanetx.org/chem/MNXM1000153',
#  'SLM:000692542': 'https://rdf.metanetx.org/chem/MNXM1000154',
#  'SLM:000692543': 'https://rdf.metanetx.org/chem/MNXM1000155',
#  'SLM:000692544': 'https://rdf.metanetx.org/chem/MNXM1000156',
#  'SLM:000692545': 'https://rdf.metanetx.org/chem/MNXM1000157',
#  'SLM:000692546': 'https://rdf.metanetx.org/chem/MNXM1000158',
#  'SLM:000692547': 'https://rdf.metanetx.org/chem/MNXM1000159',
#  'chebi:179622': 'https://rdf.metanetx.org/chem/MNXM100016',
#  'lipidmapsM:LMFA07010427': 'https://rdf.metanetx.org/chem/MNXM100016',
#  'SLM:000692548': 'https://rdf.metanetx.org/chem/MNXM1000160',
#  'SLM:000692549': 'https://rdf.metanetx.org/chem/MNXM1000161',
#  'SLM:000692550': 'https://rdf.metanetx.org/chem/MNXM1000162',
#  'SLM:000692551': 'https://rdf.metanetx.org/chem/MNXM1000163',
#  'SLM:000692552': 'https://rdf.metanetx.org/chem/MNXM1000164',
#  'SLM:000692553': 'https://rdf.metanetx.org/chem/MNXM1000165',
#  'SLM:000692554': 'https://rdf.metanetx.org/chem/MNXM1000166',
#  'SLM:000692555': 'https://rdf.metanetx.org/chem/MNXM1000167',
#  'SLM:000692556': 'https://rdf.metanetx.org/chem/MNXM1000168',
#  'SLM:000692557': 'https://rdf.metanetx.org/chem/MNXM1000169',
#  'chebi:196044': 'https://rdf.metanetx.org/chem/MNXM100017',
#  'lipidmapsM:LMFA07010231': 'https://rdf.metanetx.org/chem/MNXM100017',
#  'SLM:000692558': 'https://rdf.metanetx.org/chem/MNXM1000170',
#  'SLM:000692559': 'https://rdf.metanetx.org/chem/MNXM1000171',
#  'SLM:000692560': 'https://rdf.metanetx.org/chem/MNXM1000172',
#  'SLM:000692561': 'https://rdf.metanetx.org/chem/MNXM1000173',
#  'SLM:000692562': 'https://rdf.metanetx.org/chem/MNXM1000174',
#  'SLM:000692563': 'https://rdf.metanetx.org/chem/MNXM1000175',
#  'SLM:000692564': 'https://rdf.metanetx.org/chem/MNXM1000176',
#  'SLM:000692565': 'https://rdf.metanetx.org/chem/MNXM1000177',
#  'SLM:000692566': 'https://rdf.metanetx.org/chem/MNXM1000178',
#  'SLM:000692567': 'https://rdf.metanetx.org/chem/MNXM1000179',
#  'chebi:87427': 'https://rdf.metanetx.org/chem/MNXM100018',
#  'hmdb:HMDB0033788': 'https://rdf.metanetx.org/chem/MNXM100018',
#  'hmdb:HMDB33788': 'https://rdf.metanetx.org/chem/MNXM100018',
#  'lipidmapsM:LMFA07010464': 'https://rdf.metanetx.org/chem/MNXM100018',
#  'SLM:000692568': 'https://rdf.metanetx.org/chem/MNXM1000180',
#  'SLM:000692569': 'https://rdf.metanetx.org/chem/MNXM1000181',
#  'SLM:000692570': 'https://rdf.metanetx.org/chem/MNXM1000182',
#  'SLM:000692571': 'https://rdf.metanetx.org/chem/MNXM1000183',
#  'SLM:000692572': 'https://rdf.metanetx.org/chem/MNXM1000184',
#  'SLM:000692573': 'https://rdf.metanetx.org/chem/MNXM1000185',
#  'SLM:000692574': 'https://rdf.metanetx.org/chem/MNXM1000186',
#  'SLM:000692575': 'https://rdf.metanetx.org/chem/MNXM1000187',
#  'SLM:000692576': 'https://rdf.metanetx.org/chem/MNXM1000188',
#  'SLM:000692577': 'https://rdf.metanetx.org/chem/MNXM1000189',
#  'lipidmapsM:LMFA05000479': 'https://rdf.metanetx.org/chem/MNXM100019',
#  'SLM:000692578': 'https://rdf.metanetx.org/chem/MNXM1000190',
#  'SLM:000692579': 'https://rdf.metanetx.org/chem/MNXM1000191',
#  'SLM:000692580': 'https://rdf.metanetx.org/chem/MNXM1000192',
#  'SLM:000692581': 'https://rdf.metanetx.org/chem/MNXM1000193',
#  'SLM:000692582': 'https://rdf.metanetx.org/chem/MNXM1000194',
#  'SLM:000692583': 'https://rdf.metanetx.org/chem/MNXM1000195',
#  'SLM:000692584': 'https://rdf.metanetx.org/chem/MNXM1000196',
#  'SLM:000692585': 'https://rdf.metanetx.org/chem/MNXM1000197',
#  'SLM:000692586': 'https://rdf.metanetx.org/chem/MNXM1000198',
#  'SLM:000692587': 'https://rdf.metanetx.org/chem/MNXM1000199',
#  'chebi:72642': 'https://rdf.metanetx.org/chem/MNXM10002',
#  'sabiorkM:21116': 'https://rdf.metanetx.org/chem/MNXM10002',
#  'seedM:cpd24531': 'https://rdf.metanetx.org/chem/MNXM10002',
#  'lipidmapsM:LMFA07010532': 'https://rdf.metanetx.org/chem/MNXM100020',
#  'SLM:000692588': 'https://rdf.metanetx.org/chem/MNXM1000200',
#  'SLM:000692589': 'https://rdf.metanetx.org/chem/MNXM1000201',
#  'SLM:000692590': 'https://rdf.metanetx.org/chem/MNXM1000202',
#  'SLM:000692591': 'https://rdf.metanetx.org/chem/MNXM1000203',
#  'SLM:000692592': 'https://rdf.metanetx.org/chem/MNXM1000204',
#  'SLM:000692593': 'https://rdf.metanetx.org/chem/MNXM1000205',
#  'SLM:000692594': 'https://rdf.metanetx.org/chem/MNXM1000206',
#  'SLM:000692595': 'https://rdf.metanetx.org/chem/MNXM1000207',
#  'SLM:000692596': 'https://rdf.metanetx.org/chem/MNXM1000208',
#  'SLM:000692597': 'https://rdf.metanetx.org/chem/MNXM1000209',
#  'chebi:196299': 'https://rdf.metanetx.org/chem/MNXM100021',
#  'lipidmapsM:LMFA07010549': 'https://rdf.metanetx.org/chem/MNXM100021',
#  'SLM:000692598': 'https://rdf.metanetx.org/chem/MNXM1000210',
#  'SLM:000692599': 'https://rdf.metanetx.org/chem/MNXM1000211',
#  'SLM:000692600': 'https://rdf.metanetx.org/chem/MNXM1000212',
#  'SLM:000692601': 'https://rdf.metanetx.org/chem/MNXM1000213',
#  'SLM:000692602': 'https://rdf.metanetx.org/chem/MNXM1000214',
#  'SLM:000692603': 'https://rdf.metanetx.org/chem/MNXM1000215',
#  'SLM:000692604': 'https://rdf.metanetx.org/chem/MNXM1000216',
#  'SLM:000692605': 'https://rdf.metanetx.org/chem/MNXM1000217',
#  'SLM:000692606': 'https://rdf.metanetx.org/chem/MNXM1000218',
#  'SLM:000692607': 'https://rdf.metanetx.org/chem/MNXM1000219',
#  'chebi:179184': 'https://rdf.metanetx.org/chem/MNXM100022',
#  'lipidmapsM:LMFA07010208': 'https://rdf.metanetx.org/chem/MNXM100022',
#  'SLM:000692608': 'https://rdf.metanetx.org/chem/MNXM1000220',
#  'SLM:000692609': 'https://rdf.metanetx.org/chem/MNXM1000221',
#  'SLM:000692610': 'https://rdf.metanetx.org/chem/MNXM1000222',
#  'SLM:000692611': 'https://rdf.metanetx.org/chem/MNXM1000223',
#  'SLM:000692612': 'https://rdf.metanetx.org/chem/MNXM1000224',
#  'SLM:000692613': 'https://rdf.metanetx.org/chem/MNXM1000225',
#  'SLM:000692614': 'https://rdf.metanetx.org/chem/MNXM1000226',
#  'SLM:000692615': 'https://rdf.metanetx.org/chem/MNXM1000227',
#  'SLM:000692616': 'https://rdf.metanetx.org/chem/MNXM1000228',
#  'SLM:000692617': 'https://rdf.metanetx.org/chem/MNXM1000229',
#  'lipidmapsM:LMFA11000196': 'https://rdf.metanetx.org/chem/MNXM100023',
#  'SLM:000692618': 'https://rdf.metanetx.org/chem/MNXM1000230',
#  'SLM:000692619': 'https://rdf.metanetx.org/chem/MNXM1000231',
#  'SLM:000692620': 'https://rdf.metanetx.org/chem/MNXM1000232',
#  'SLM:000692621': 'https://rdf.metanetx.org/chem/MNXM1000233',
#  'SLM:000692622': 'https://rdf.metanetx.org/chem/MNXM1000234',
#  'SLM:000692623': 'https://rdf.metanetx.org/chem/MNXM1000235',
#  'SLM:000692624': 'https://rdf.metanetx.org/chem/MNXM1000236',
#  'SLM:000692625': 'https://rdf.metanetx.org/chem/MNXM1000237',
#  'SLM:000692626': 'https://rdf.metanetx.org/chem/MNXM1000238',
#  'SLM:000692627': 'https://rdf.metanetx.org/chem/MNXM1000239',
#  'lipidmapsM:LMFA11000050': 'https://rdf.metanetx.org/chem/MNXM100024',
#  'SLM:000692628': 'https://rdf.metanetx.org/chem/MNXM1000240',
#  'SLM:000692629': 'https://rdf.metanetx.org/chem/MNXM1000241',
#  'SLM:000692630': 'https://rdf.metanetx.org/chem/MNXM1000242',
#  'SLM:000692631': 'https://rdf.metanetx.org/chem/MNXM1000243',
#  'SLM:000692632': 'https://rdf.metanetx.org/chem/MNXM1000244',
#  'SLM:000692633': 'https://rdf.metanetx.org/chem/MNXM1000245',
#  'SLM:000692634': 'https://rdf.metanetx.org/chem/MNXM1000246',
#  'SLM:000692635': 'https://rdf.metanetx.org/chem/MNXM1000247',
#  'SLM:000692636': 'https://rdf.metanetx.org/chem/MNXM1000248',
#  'SLM:000692637': 'https://rdf.metanetx.org/chem/MNXM1000249',
#  'chebi:187111': 'https://rdf.metanetx.org/chem/MNXM100025',
#  'lipidmapsM:LMFA11000052': 'https://rdf.metanetx.org/chem/MNXM100025',
#  'SLM:000692638': 'https://rdf.metanetx.org/chem/MNXM1000250',
#  'SLM:000692639': 'https://rdf.metanetx.org/chem/MNXM1000251',
#  'SLM:000692640': 'https://rdf.metanetx.org/chem/MNXM1000252',
#  'SLM:000692641': 'https://rdf.metanetx.org/chem/MNXM1000253',
#  'SLM:000692642': 'https://rdf.metanetx.org/chem/MNXM1000254',
#  'SLM:000692643': 'https://rdf.metanetx.org/chem/MNXM1000255',
#  'SLM:000692644': 'https://rdf.metanetx.org/chem/MNXM1000256',
#  'SLM:000692645': 'https://rdf.metanetx.org/chem/MNXM1000257',
#  'SLM:000692646': 'https://rdf.metanetx.org/chem/MNXM1000258',
#  'SLM:000692647': 'https://rdf.metanetx.org/chem/MNXM1000259',
#  'lipidmapsM:LMFA07010632': 'https://rdf.metanetx.org/chem/MNXM100026',
#  'SLM:000692648': 'https://rdf.metanetx.org/chem/MNXM1000260',
#  'SLM:000692649': 'https://rdf.metanetx.org/chem/MNXM1000261',
#  'SLM:000692650': 'https://rdf.metanetx.org/chem/MNXM1000262',
#  'SLM:000692651': 'https://rdf.metanetx.org/chem/MNXM1000263',
#  'SLM:000692652': 'https://rdf.metanetx.org/chem/MNXM1000264',
#  'SLM:000692653': 'https://rdf.metanetx.org/chem/MNXM1000265',
#  'SLM:000692654': 'https://rdf.metanetx.org/chem/MNXM1000266',
#  'SLM:000692655': 'https://rdf.metanetx.org/chem/MNXM1000267',
#  'SLM:000692656': 'https://rdf.metanetx.org/chem/MNXM1000268',
#  'SLM:000692657': 'https://rdf.metanetx.org/chem/MNXM1000269',
#  'chebi:87315': 'https://rdf.metanetx.org/chem/MNXM100027',
#  'lipidmapsM:LMFA11000311': 'https://rdf.metanetx.org/chem/MNXM100027',
#  'SLM:000692658': 'https://rdf.metanetx.org/chem/MNXM1000270',
#  'SLM:000692659': 'https://rdf.metanetx.org/chem/MNXM1000271',
#  'SLM:000692660': 'https://rdf.metanetx.org/chem/MNXM1000272',
#  'SLM:000692661': 'https://rdf.metanetx.org/chem/MNXM1000273',
#  'SLM:000692662': 'https://rdf.metanetx.org/chem/MNXM1000274',
#  'SLM:000692663': 'https://rdf.metanetx.org/chem/MNXM1000275',
#  'SLM:000692664': 'https://rdf.metanetx.org/chem/MNXM1000276',
#  'SLM:000692665': 'https://rdf.metanetx.org/chem/MNXM1000277',
#  'SLM:000692666': 'https://rdf.metanetx.org/chem/MNXM1000278',
#  'SLM:000692667': 'https://rdf.metanetx.org/chem/MNXM1000279',
#  'chebi:134476': 'https://rdf.metanetx.org/chem/MNXM100028',
#  'lipidmapsM:LMFA07010389': 'https://rdf.metanetx.org/chem/MNXM100028',
#  'SLM:000692668': 'https://rdf.metanetx.org/chem/MNXM1000280',
#  'SLM:000692669': 'https://rdf.metanetx.org/chem/MNXM1000281',
#  'SLM:000692670': 'https://rdf.metanetx.org/chem/MNXM1000282',
#  'SLM:000692671': 'https://rdf.metanetx.org/chem/MNXM1000283',
#  'SLM:000692672': 'https://rdf.metanetx.org/chem/MNXM1000284',
#  'SLM:000692673': 'https://rdf.metanetx.org/chem/MNXM1000285',
#  'SLM:000692674': 'https://rdf.metanetx.org/chem/MNXM1000286',
#  'SLM:000692675': 'https://rdf.metanetx.org/chem/MNXM1000287',
#  'SLM:000692676': 'https://rdf.metanetx.org/chem/MNXM1000288',
#  'SLM:000692677': 'https://rdf.metanetx.org/chem/MNXM1000289',
#  'lipidmapsM:LMFA11000213': 'https://rdf.metanetx.org/chem/MNXM100029',
#  'SLM:000692678': 'https://rdf.metanetx.org/chem/MNXM1000290',
#  'SLM:000692679': 'https://rdf.metanetx.org/chem/MNXM1000291',
#  'SLM:000692680': 'https://rdf.metanetx.org/chem/MNXM1000292',
#  'SLM:000692681': 'https://rdf.metanetx.org/chem/MNXM1000293',
#  'SLM:000692682': 'https://rdf.metanetx.org/chem/MNXM1000294',
#  'SLM:000692683': 'https://rdf.metanetx.org/chem/MNXM1000295',
#  'SLM:000692684': 'https://rdf.metanetx.org/chem/MNXM1000296',
#  'SLM:000692685': 'https://rdf.metanetx.org/chem/MNXM1000297',
#  'SLM:000692686': 'https://rdf.metanetx.org/chem/MNXM1000298',
#  'SLM:000692687': 'https://rdf.metanetx.org/chem/MNXM1000299',
#  'lipidmapsM:LMFA11000473': 'https://rdf.metanetx.org/chem/MNXM100030',
#  'SLM:000692688': 'https://rdf.metanetx.org/chem/MNXM1000300',
#  'SLM:000692689': 'https://rdf.metanetx.org/chem/MNXM1000301',
#  'SLM:000692690': 'https://rdf.metanetx.org/chem/MNXM1000302',
#  'SLM:000692691': 'https://rdf.metanetx.org/chem/MNXM1000303',
#  'SLM:000692692': 'https://rdf.metanetx.org/chem/MNXM1000304',
#  'SLM:000692693': 'https://rdf.metanetx.org/chem/MNXM1000305',
#  'SLM:000692694': 'https://rdf.metanetx.org/chem/MNXM1000306',
#  'SLM:000692695': 'https://rdf.metanetx.org/chem/MNXM1000307',
#  'SLM:000692696': 'https://rdf.metanetx.org/chem/MNXM1000308',
#  'SLM:000692697': 'https://rdf.metanetx.org/chem/MNXM1000309',
#  'lipidmapsM:LMFA12000320': 'https://rdf.metanetx.org/chem/MNXM100031',
#  'SLM:000692698': 'https://rdf.metanetx.org/chem/MNXM1000310',
#  'SLM:000692699': 'https://rdf.metanetx.org/chem/MNXM1000311',
#  'SLM:000692700': 'https://rdf.metanetx.org/chem/MNXM1000312',
#  'SLM:000692701': 'https://rdf.metanetx.org/chem/MNXM1000313',
#  'SLM:000692702': 'https://rdf.metanetx.org/chem/MNXM1000314',
#  'SLM:000692703': 'https://rdf.metanetx.org/chem/MNXM1000315',
#  'SLM:000692704': 'https://rdf.metanetx.org/chem/MNXM1000316',
#  'SLM:000692705': 'https://rdf.metanetx.org/chem/MNXM1000317',
#  'SLM:000692706': 'https://rdf.metanetx.org/chem/MNXM1000318',
#  'SLM:000692707': 'https://rdf.metanetx.org/chem/MNXM1000319',
#  'chebi:89985': 'https://rdf.metanetx.org/chem/MNXM100032',
#  'hmdb:HMDB0031583': 'https://rdf.metanetx.org/chem/MNXM100032',
#  'hmdb:HMDB31583': 'https://rdf.metanetx.org/chem/MNXM100032',
#  'lipidmapsM:LMFA11000606': 'https://rdf.metanetx.org/chem/MNXM100032',
#  'SLM:000692708': 'https://rdf.metanetx.org/chem/MNXM1000320',
#  'SLM:000692709': 'https://rdf.metanetx.org/chem/MNXM1000321',
#  'SLM:000692710': 'https://rdf.metanetx.org/chem/MNXM1000322',
#  'SLM:000692711': 'https://rdf.metanetx.org/chem/MNXM1000323',
#  'SLM:000692712': 'https://rdf.metanetx.org/chem/MNXM1000324',
#  'SLM:000692713': 'https://rdf.metanetx.org/chem/MNXM1000325',
#  'SLM:000692714': 'https://rdf.metanetx.org/chem/MNXM1000326',
#  'SLM:000692715': 'https://rdf.metanetx.org/chem/MNXM1000327',
#  'SLM:000692716': 'https://rdf.metanetx.org/chem/MNXM1000328',
#  'SLM:000692717': 'https://rdf.metanetx.org/chem/MNXM1000329',
#  'chebi:196046': 'https://rdf.metanetx.org/chem/MNXM100033',
#  'lipidmapsM:LMFA07010234': 'https://rdf.metanetx.org/chem/MNXM100033',
#  'SLM:000692718': 'https://rdf.metanetx.org/chem/MNXM1000330',
#  'SLM:000692719': 'https://rdf.metanetx.org/chem/MNXM1000331',
#  'SLM:000692720': 'https://rdf.metanetx.org/chem/MNXM1000332',
#  'SLM:000692721': 'https://rdf.metanetx.org/chem/MNXM1000333',
#  'SLM:000692722': 'https://rdf.metanetx.org/chem/MNXM1000334',
#  'SLM:000692723': 'https://rdf.metanetx.org/chem/MNXM1000335',
#  'SLM:000692724': 'https://rdf.metanetx.org/chem/MNXM1000336',
#  'SLM:000692725': 'https://rdf.metanetx.org/chem/MNXM1000337',
#  'SLM:000692726': 'https://rdf.metanetx.org/chem/MNXM1000338',
#  'SLM:000692727': 'https://rdf.metanetx.org/chem/MNXM1000339',
#  'chebi:195864': 'https://rdf.metanetx.org/chem/MNXM100034',
#  'lipidmapsM:LMFA12000042': 'https://rdf.metanetx.org/chem/MNXM100034',
#  'SLM:000692728': 'https://rdf.metanetx.org/chem/MNXM1000340',
#  'SLM:000692729': 'https://rdf.metanetx.org/chem/MNXM1000341',
#  'SLM:000692730': 'https://rdf.metanetx.org/chem/MNXM1000342',
#  'SLM:000692731': 'https://rdf.metanetx.org/chem/MNXM1000343',
#  'SLM:000692732': 'https://rdf.metanetx.org/chem/MNXM1000344',
#  'SLM:000692733': 'https://rdf.metanetx.org/chem/MNXM1000345',
#  'SLM:000692734': 'https://rdf.metanetx.org/chem/MNXM1000346',
#  'SLM:000692735': 'https://rdf.metanetx.org/chem/MNXM1000347',
#  'SLM:000692736': 'https://rdf.metanetx.org/chem/MNXM1000348',
#  'SLM:000692737': 'https://rdf.metanetx.org/chem/MNXM1000349',
#  'lipidmapsM:LMFA07010404': 'https://rdf.metanetx.org/chem/MNXM100035',
#  'SLM:000692738': 'https://rdf.metanetx.org/chem/MNXM1000350',
#  'SLM:000692739': 'https://rdf.metanetx.org/chem/MNXM1000351',
#  'SLM:000692740': 'https://rdf.metanetx.org/chem/MNXM1000352',
#  'SLM:000692741': 'https://rdf.metanetx.org/chem/MNXM1000353',
#  'SLM:000692742': 'https://rdf.metanetx.org/chem/MNXM1000354',
#  'SLM:000692743': 'https://rdf.metanetx.org/chem/MNXM1000355',
#  'SLM:000692744': 'https://rdf.metanetx.org/chem/MNXM1000356',
#  'SLM:000692745': 'https://rdf.metanetx.org/chem/MNXM1000357',
#  'SLM:000692746': 'https://rdf.metanetx.org/chem/MNXM1000358',
#  'SLM:000692747': 'https://rdf.metanetx.org/chem/MNXM1000359',
#  'chebi:196471': 'https://rdf.metanetx.org/chem/MNXM100036',
#  'chebi:196476': 'https://rdf.metanetx.org/chem/MNXM100036',
#  'lipidmapsM:LMPK09000022': 'https://rdf.metanetx.org/chem/MNXM100036',
#  'lipidmapsM:LMPK09000026': 'https://rdf.metanetx.org/chem/MNXM100036',
#  'SLM:000692748': 'https://rdf.metanetx.org/chem/MNXM1000360',
#  'SLM:000692749': 'https://rdf.metanetx.org/chem/MNXM1000361',
#  'SLM:000692750': 'https://rdf.metanetx.org/chem/MNXM1000362',
#  'SLM:000692751': 'https://rdf.metanetx.org/chem/MNXM1000363',
#  'SLM:000692752': 'https://rdf.metanetx.org/chem/MNXM1000364',
#  'SLM:000692753': 'https://rdf.metanetx.org/chem/MNXM1000365',
#  'SLM:000692754': 'https://rdf.metanetx.org/chem/MNXM1000366',
#  'SLM:000692755': 'https://rdf.metanetx.org/chem/MNXM1000367',
#  'SLM:000692756': 'https://rdf.metanetx.org/chem/MNXM1000368',
#  'SLM:000692757': 'https://rdf.metanetx.org/chem/MNXM1000369',
#  'lipidmapsM:LMFA11000508': 'https://rdf.metanetx.org/chem/MNXM100037',
#  'SLM:000692758': 'https://rdf.metanetx.org/chem/MNXM1000370',
#  'SLM:000692759': 'https://rdf.metanetx.org/chem/MNXM1000371',
#  'SLM:000692760': 'https://rdf.metanetx.org/chem/MNXM1000372',
#  'SLM:000692761': 'https://rdf.metanetx.org/chem/MNXM1000373',
#  'SLM:000692762': 'https://rdf.metanetx.org/chem/MNXM1000374',
#  'SLM:000692763': 'https://rdf.metanetx.org/chem/MNXM1000375',
#  'SLM:000692764': 'https://rdf.metanetx.org/chem/MNXM1000376',
#  'SLM:000692765': 'https://rdf.metanetx.org/chem/MNXM1000377',
#  'SLM:000692766': 'https://rdf.metanetx.org/chem/MNXM1000378',
#  'SLM:000692767': 'https://rdf.metanetx.org/chem/MNXM1000379',
#  'lipidmapsM:LMFA12000293': 'https://rdf.metanetx.org/chem/MNXM100038',
#  'SLM:000692768': 'https://rdf.metanetx.org/chem/MNXM1000380',
#  'SLM:000692769': 'https://rdf.metanetx.org/chem/MNXM1000381',
#  'SLM:000692770': 'https://rdf.metanetx.org/chem/MNXM1000382',
#  'SLM:000692771': 'https://rdf.metanetx.org/chem/MNXM1000383',
#  'SLM:000692772': 'https://rdf.metanetx.org/chem/MNXM1000384',
#  'SLM:000692773': 'https://rdf.metanetx.org/chem/MNXM1000385',
#  'SLM:000692774': 'https://rdf.metanetx.org/chem/MNXM1000386',
#  'SLM:000692775': 'https://rdf.metanetx.org/chem/MNXM1000387',
#  'SLM:000692776': 'https://rdf.metanetx.org/chem/MNXM1000388',
#  'SLM:000692777': 'https://rdf.metanetx.org/chem/MNXM1000389',
#  'lipidmapsM:LMFA07010542': 'https://rdf.metanetx.org/chem/MNXM100039',
#  'SLM:000692778': 'https://rdf.metanetx.org/chem/MNXM1000390',
#  'SLM:000692779': 'https://rdf.metanetx.org/chem/MNXM1000391',
#  'SLM:000692780': 'https://rdf.metanetx.org/chem/MNXM1000392',
#  'SLM:000692781': 'https://rdf.metanetx.org/chem/MNXM1000393',
#  'SLM:000692782': 'https://rdf.metanetx.org/chem/MNXM1000394',
#  'SLM:000692783': 'https://rdf.metanetx.org/chem/MNXM1000395',
#  'SLM:000692784': 'https://rdf.metanetx.org/chem/MNXM1000396',
#  'SLM:000692785': 'https://rdf.metanetx.org/chem/MNXM1000397',
#  'SLM:000692786': 'https://rdf.metanetx.org/chem/MNXM1000398',
#  'SLM:000692787': 'https://rdf.metanetx.org/chem/MNXM1000399',
#  'seedM:cpd24010': 'https://rdf.metanetx.org/chem/MNXM10004',
#  'lipidmapsM:LMFA11000339': 'https://rdf.metanetx.org/chem/MNXM100040',
#  'SLM:000692788': 'https://rdf.metanetx.org/chem/MNXM1000400',
#  'SLM:000692789': 'https://rdf.metanetx.org/chem/MNXM1000401',
#  'SLM:000692790': 'https://rdf.metanetx.org/chem/MNXM1000402',
#  'SLM:000692791': 'https://rdf.metanetx.org/chem/MNXM1000403',
#  'SLM:000692792': 'https://rdf.metanetx.org/chem/MNXM1000404',
#  'SLM:000692793': 'https://rdf.metanetx.org/chem/MNXM1000405',
#  'SLM:000692794': 'https://rdf.metanetx.org/chem/MNXM1000406',
#  'SLM:000692795': 'https://rdf.metanetx.org/chem/MNXM1000407',
#  'SLM:000692796': 'https://rdf.metanetx.org/chem/MNXM1000408',
#  'SLM:000692797': 'https://rdf.metanetx.org/chem/MNXM1000409',
#  'chebi:180240': 'https://rdf.metanetx.org/chem/MNXM100041',
#  'lipidmapsM:LMFA07010525': 'https://rdf.metanetx.org/chem/MNXM100041',
#  'SLM:000692798': 'https://rdf.metanetx.org/chem/MNXM1000410',
#  'SLM:000692799': 'https://rdf.metanetx.org/chem/MNXM1000411',
#  'SLM:000692800': 'https://rdf.metanetx.org/chem/MNXM1000412',
#  'SLM:000692801': 'https://rdf.metanetx.org/chem/MNXM1000413',
#  'SLM:000692802': 'https://rdf.metanetx.org/chem/MNXM1000414',
#  'SLM:000692803': 'https://rdf.metanetx.org/chem/MNXM1000415',
#  'SLM:000692804': 'https://rdf.metanetx.org/chem/MNXM1000416',
#  'SLM:000692805': 'https://rdf.metanetx.org/chem/MNXM1000417',
#  'SLM:000692806': 'https://rdf.metanetx.org/chem/MNXM1000418',
#  'SLM:000692807': 'https://rdf.metanetx.org/chem/MNXM1000419',
#  'chebi:196063': 'https://rdf.metanetx.org/chem/MNXM100042',
#  'lipidmapsM:LMFA07010533': 'https://rdf.metanetx.org/chem/MNXM100042',
#  'SLM:000692808': 'https://rdf.metanetx.org/chem/MNXM1000420',
#  'SLM:000692809': 'https://rdf.metanetx.org/chem/MNXM1000421',
#  'SLM:000692810': 'https://rdf.metanetx.org/chem/MNXM1000422',
#  'SLM:000692811': 'https://rdf.metanetx.org/chem/MNXM1000423',
#  'SLM:000692812': 'https://rdf.metanetx.org/chem/MNXM1000424',
#  'SLM:000692813': 'https://rdf.metanetx.org/chem/MNXM1000425',
#  'SLM:000692814': 'https://rdf.metanetx.org/chem/MNXM1000426',
#  'SLM:000692815': 'https://rdf.metanetx.org/chem/MNXM1000427',
#  'SLM:000692816': 'https://rdf.metanetx.org/chem/MNXM1000428',
#  'SLM:000692817': 'https://rdf.metanetx.org/chem/MNXM1000429',
#  'chebi:196033': 'https://rdf.metanetx.org/chem/MNXM100043',
#  'lipidmapsM:LMFA07010240': 'https://rdf.metanetx.org/chem/MNXM100043',
#  'SLM:000692818': 'https://rdf.metanetx.org/chem/MNXM1000430',
#  'SLM:000692819': 'https://rdf.metanetx.org/chem/MNXM1000431',
#  'SLM:000692820': 'https://rdf.metanetx.org/chem/MNXM1000432',
#  'SLM:000692821': 'https://rdf.metanetx.org/chem/MNXM1000433',
#  'SLM:000692822': 'https://rdf.metanetx.org/chem/MNXM1000434',
#  'SLM:000692823': 'https://rdf.metanetx.org/chem/MNXM1000435',
#  'SLM:000692824': 'https://rdf.metanetx.org/chem/MNXM1000436',
#  'SLM:000692825': 'https://rdf.metanetx.org/chem/MNXM1000437',
#  'SLM:000692826': 'https://rdf.metanetx.org/chem/MNXM1000438',
#  'SLM:000692827': 'https://rdf.metanetx.org/chem/MNXM1000439',
#  'lipidmapsM:LMFA11000623': 'https://rdf.metanetx.org/chem/MNXM100044',
#  'SLM:000692828': 'https://rdf.metanetx.org/chem/MNXM1000440',
#  'SLM:000692829': 'https://rdf.metanetx.org/chem/MNXM1000441',
#  'SLM:000692830': 'https://rdf.metanetx.org/chem/MNXM1000442',
#  'SLM:000692831': 'https://rdf.metanetx.org/chem/MNXM1000443',
#  'SLM:000692832': 'https://rdf.metanetx.org/chem/MNXM1000444',
#  'SLM:000692833': 'https://rdf.metanetx.org/chem/MNXM1000445',
#  'SLM:000692834': 'https://rdf.metanetx.org/chem/MNXM1000446',
#  'SLM:000692835': 'https://rdf.metanetx.org/chem/MNXM1000447',
#  'SLM:000692836': 'https://rdf.metanetx.org/chem/MNXM1000448',
#  'SLM:000692837': 'https://rdf.metanetx.org/chem/MNXM1000449',
#  'chebi:187141': 'https://rdf.metanetx.org/chem/MNXM100045',
#  'lipidmapsM:LMFA05000522': 'https://rdf.metanetx.org/chem/MNXM100045',
#  'SLM:000692838': 'https://rdf.metanetx.org/chem/MNXM1000450',
#  'SLM:000692839': 'https://rdf.metanetx.org/chem/MNXM1000451',
#  'SLM:000692840': 'https://rdf.metanetx.org/chem/MNXM1000452',
#  'SLM:000692841': 'https://rdf.metanetx.org/chem/MNXM1000453',
#  'SLM:000692842': 'https://rdf.metanetx.org/chem/MNXM1000454',
#  'SLM:000692843': 'https://rdf.metanetx.org/chem/MNXM1000455',
#  'SLM:000692844': 'https://rdf.metanetx.org/chem/MNXM1000456',
#  'SLM:000692845': 'https://rdf.metanetx.org/chem/MNXM1000457',
#  'SLM:000692846': 'https://rdf.metanetx.org/chem/MNXM1000458',
#  'SLM:000692847': 'https://rdf.metanetx.org/chem/MNXM1000459',
#  'lipidmapsM:LMFA11000344': 'https://rdf.metanetx.org/chem/MNXM100046',
#  'SLM:000692848': 'https://rdf.metanetx.org/chem/MNXM1000460',
#  'SLM:000692849': 'https://rdf.metanetx.org/chem/MNXM1000461',
#  'SLM:000692850': 'https://rdf.metanetx.org/chem/MNXM1000462',
#  'SLM:000692851': 'https://rdf.metanetx.org/chem/MNXM1000463',
#  'SLM:000692852': 'https://rdf.metanetx.org/chem/MNXM1000464',
#  'SLM:000692853': 'https://rdf.metanetx.org/chem/MNXM1000465',
#  'SLM:000692854': 'https://rdf.metanetx.org/chem/MNXM1000466',
#  'SLM:000692855': 'https://rdf.metanetx.org/chem/MNXM1000467',
#  'SLM:000692856': 'https://rdf.metanetx.org/chem/MNXM1000468',
#  'SLM:000692857': 'https://rdf.metanetx.org/chem/MNXM1000469',
#  'lipidmapsM:LMFA11000149': 'https://rdf.metanetx.org/chem/MNXM100047',
#  'SLM:000692858': 'https://rdf.metanetx.org/chem/MNXM1000470',
#  'SLM:000692859': 'https://rdf.metanetx.org/chem/MNXM1000471',
#  'SLM:000692860': 'https://rdf.metanetx.org/chem/MNXM1000472',
#  'SLM:000692861': 'https://rdf.metanetx.org/chem/MNXM1000473',
#  'SLM:000692862': 'https://rdf.metanetx.org/chem/MNXM1000474',
#  'SLM:000692863': 'https://rdf.metanetx.org/chem/MNXM1000475',
#  'SLM:000692864': 'https://rdf.metanetx.org/chem/MNXM1000476',
#  'SLM:000692865': 'https://rdf.metanetx.org/chem/MNXM1000477',
#  'SLM:000692866': 'https://rdf.metanetx.org/chem/MNXM1000478',
#  'SLM:000692867': 'https://rdf.metanetx.org/chem/MNXM1000479',
#  'lipidmapsM:LMFA11000221': 'https://rdf.metanetx.org/chem/MNXM100048',
#  'SLM:000692868': 'https://rdf.metanetx.org/chem/MNXM1000480',
#  'SLM:000692869': 'https://rdf.metanetx.org/chem/MNXM1000481',
#  'SLM:000692870': 'https://rdf.metanetx.org/chem/MNXM1000482',
#  'SLM:000692871': 'https://rdf.metanetx.org/chem/MNXM1000483',
#  'SLM:000692872': 'https://rdf.metanetx.org/chem/MNXM1000484',
#  'SLM:000692873': 'https://rdf.metanetx.org/chem/MNXM1000485',
#  'SLM:000692874': 'https://rdf.metanetx.org/chem/MNXM1000486',
#  'SLM:000692875': 'https://rdf.metanetx.org/chem/MNXM1000487',
#  'SLM:000692876': 'https://rdf.metanetx.org/chem/MNXM1000488',
#  'SLM:000692877': 'https://rdf.metanetx.org/chem/MNXM1000489',
#  'lipidmapsM:LMFA11000289': 'https://rdf.metanetx.org/chem/MNXM100049',
#  'SLM:000692878': 'https://rdf.metanetx.org/chem/MNXM1000490',
#  'SLM:000692879': 'https://rdf.metanetx.org/chem/MNXM1000491',
#  'SLM:000692880': 'https://rdf.metanetx.org/chem/MNXM1000492',
#  'SLM:000692881': 'https://rdf.metanetx.org/chem/MNXM1000493',
#  'SLM:000692882': 'https://rdf.metanetx.org/chem/MNXM1000494',
#  'SLM:000692883': 'https://rdf.metanetx.org/chem/MNXM1000495',
#  'SLM:000692884': 'https://rdf.metanetx.org/chem/MNXM1000496',
#  'SLM:000692885': 'https://rdf.metanetx.org/chem/MNXM1000497',
#  'SLM:000692886': 'https://rdf.metanetx.org/chem/MNXM1000498',
#  'SLM:000692887': 'https://rdf.metanetx.org/chem/MNXM1000499',
#  'chebi:187668': 'https://rdf.metanetx.org/chem/MNXM100050',
#  'lipidmapsM:LMFA11000333': 'https://rdf.metanetx.org/chem/MNXM100050',
#  'SLM:000692888': 'https://rdf.metanetx.org/chem/MNXM1000500',
#  'SLM:000692889': 'https://rdf.metanetx.org/chem/MNXM1000501',
#  'SLM:000692890': 'https://rdf.metanetx.org/chem/MNXM1000502',
#  'SLM:000692891': 'https://rdf.metanetx.org/chem/MNXM1000503',
#  'SLM:000692892': 'https://rdf.metanetx.org/chem/MNXM1000504',
#  'SLM:000692893': 'https://rdf.metanetx.org/chem/MNXM1000505',
#  'SLM:000692894': 'https://rdf.metanetx.org/chem/MNXM1000506',
#  'SLM:000692895': 'https://rdf.metanetx.org/chem/MNXM1000507',
#  'SLM:000692896': 'https://rdf.metanetx.org/chem/MNXM1000508',
#  'SLM:000692897': 'https://rdf.metanetx.org/chem/MNXM1000509',
#  'chebi:187719': 'https://rdf.metanetx.org/chem/MNXM100051',
#  'lipidmapsM:LMFA12000272': 'https://rdf.metanetx.org/chem/MNXM100051',
#  'chebi:188242': 'https://rdf.metanetx.org/chem/MNXM100344',
#  'lipidmapsM:LMFA12000277': 'https://rdf.metanetx.org/chem/MNXM100344',
#  'lipidmapsM:LMFA12000278': 'https://rdf.metanetx.org/chem/MNXM99630',
#  'SLM:000692898': 'https://rdf.metanetx.org/chem/MNXM1000510',
#  'SLM:000692899': 'https://rdf.metanetx.org/chem/MNXM1000511',
#  'SLM:000692900': 'https://rdf.metanetx.org/chem/MNXM1000512',
#  'SLM:000692901': 'https://rdf.metanetx.org/chem/MNXM1000513',
#  'SLM:000692902': 'https://rdf.metanetx.org/chem/MNXM1000514',
#  'SLM:000692903': 'https://rdf.metanetx.org/chem/MNXM1000515',
#  'SLM:000692904': 'https://rdf.metanetx.org/chem/MNXM1000516',
#  'SLM:000692905': 'https://rdf.metanetx.org/chem/MNXM1000517',
#  'SLM:000692906': 'https://rdf.metanetx.org/chem/MNXM1000518',
#  'SLM:000692907': 'https://rdf.metanetx.org/chem/MNXM1000519',
#  'chebi:180003': 'https://rdf.metanetx.org/chem/MNXM100052',
#  'sabiorkM:23126': 'https://rdf.metanetx.org/chem/MNXM100052',
#  'lipidmapsM:LMFA12000021': 'https://rdf.metanetx.org/chem/MNXM100052',
#  'SLM:000692908': 'https://rdf.metanetx.org/chem/MNXM1000520',
#  'SLM:000692909': 'https://rdf.metanetx.org/chem/MNXM1000521',
#  'SLM:000692910': 'https://rdf.metanetx.org/chem/MNXM1000522',
#  'SLM:000692911': 'https://rdf.metanetx.org/chem/MNXM1000523',
#  'SLM:000692912': 'https://rdf.metanetx.org/chem/MNXM1000524',
#  'SLM:000692913': 'https://rdf.metanetx.org/chem/MNXM1000525',
#  'SLM:000692914': 'https://rdf.metanetx.org/chem/MNXM1000526',
#  'SLM:000692915': 'https://rdf.metanetx.org/chem/MNXM1000527',
#  'SLM:000692916': 'https://rdf.metanetx.org/chem/MNXM1000528',
#  'SLM:000692917': 'https://rdf.metanetx.org/chem/MNXM1000529',
#  'chebi:196173': 'https://rdf.metanetx.org/chem/MNXM100053',
#  'lipidmapsM:LMFA07010500': 'https://rdf.metanetx.org/chem/MNXM100053',
#  'SLM:000692918': 'https://rdf.metanetx.org/chem/MNXM1000530',
#  'SLM:000692919': 'https://rdf.metanetx.org/chem/MNXM1000531',
#  'SLM:000692920': 'https://rdf.metanetx.org/chem/MNXM1000532',
#  'SLM:000692921': 'https://rdf.metanetx.org/chem/MNXM1000533',
#  'SLM:000692922': 'https://rdf.metanetx.org/chem/MNXM1000534',
#  'SLM:000692923': 'https://rdf.metanetx.org/chem/MNXM1000535',
#  'SLM:000692924': 'https://rdf.metanetx.org/chem/MNXM1000536',
#  'SLM:000692925': 'https://rdf.metanetx.org/chem/MNXM1000537',
#  'SLM:000692926': 'https://rdf.metanetx.org/chem/MNXM1000538',
#  'SLM:000692927': 'https://rdf.metanetx.org/chem/MNXM1000539',
#  'chebi:229313': 'https://rdf.metanetx.org/chem/MNXM100054',
#  'lipidmapsM:LMFA11000613': 'https://rdf.metanetx.org/chem/MNXM100054',
#  'SLM:000692928': 'https://rdf.metanetx.org/chem/MNXM1000540',
#  'SLM:000692929': 'https://rdf.metanetx.org/chem/MNXM1000541',
#  'SLM:000692930': 'https://rdf.metanetx.org/chem/MNXM1000542',
#  'SLM:000692931': 'https://rdf.metanetx.org/chem/MNXM1000543',
#  'SLM:000692932': 'https://rdf.metanetx.org/chem/MNXM1000544',
#  'SLM:000692933': 'https://rdf.metanetx.org/chem/MNXM1000545',
#  'SLM:000692934': 'https://rdf.metanetx.org/chem/MNXM1000546',
#  'SLM:000692935': 'https://rdf.metanetx.org/chem/MNXM1000547',
#  'SLM:000692936': 'https://rdf.metanetx.org/chem/MNXM1000548',
#  'SLM:000692937': 'https://rdf.metanetx.org/chem/MNXM1000549',
#  'lipidmapsM:LMFA11000461': 'https://rdf.metanetx.org/chem/MNXM100055',
#  'SLM:000692938': 'https://rdf.metanetx.org/chem/MNXM1000550',
#  'SLM:000692939': 'https://rdf.metanetx.org/chem/MNXM1000551',
#  'SLM:000692940': 'https://rdf.metanetx.org/chem/MNXM1000552',
#  'SLM:000692941': 'https://rdf.metanetx.org/chem/MNXM1000553',
#  'SLM:000692942': 'https://rdf.metanetx.org/chem/MNXM1000554',
#  'SLM:000692943': 'https://rdf.metanetx.org/chem/MNXM1000555',
#  'SLM:000692944': 'https://rdf.metanetx.org/chem/MNXM1000556',
#  'SLM:000692945': 'https://rdf.metanetx.org/chem/MNXM1000557',
#  'SLM:000692946': 'https://rdf.metanetx.org/chem/MNXM1000558',
#  'SLM:000692947': 'https://rdf.metanetx.org/chem/MNXM1000559',
#  'chebi:179383': 'https://rdf.metanetx.org/chem/MNXM100056',
#  'hmdb:HMDB0036229': 'https://rdf.metanetx.org/chem/MNXM100056',
#  'hmdb:HMDB36229': 'https://rdf.metanetx.org/chem/MNXM100056',
#  'lipidmapsM:LMFA07010437': 'https://rdf.metanetx.org/chem/MNXM100056',
#  'SLM:000692948': 'https://rdf.metanetx.org/chem/MNXM1000560',
#  'SLM:000692949': 'https://rdf.metanetx.org/chem/MNXM1000561',
#  'SLM:000692950': 'https://rdf.metanetx.org/chem/MNXM1000562',
#  'SLM:000692951': 'https://rdf.metanetx.org/chem/MNXM1000563',
#  'SLM:000692952': 'https://rdf.metanetx.org/chem/MNXM1000564',
#  'SLM:000692953': 'https://rdf.metanetx.org/chem/MNXM1000565',
#  'SLM:000692954': 'https://rdf.metanetx.org/chem/MNXM1000566',
#  'SLM:000692955': 'https://rdf.metanetx.org/chem/MNXM1000567',
#  'SLM:000692956': 'https://rdf.metanetx.org/chem/MNXM1000568',
#  'SLM:000692957': 'https://rdf.metanetx.org/chem/MNXM1000569',
#  'chebi:187297': 'https://rdf.metanetx.org/chem/MNXM100057',
#  'lipidmapsM:LMFA11000047': 'https://rdf.metanetx.org/chem/MNXM100057',
#  'SLM:000692958': 'https://rdf.metanetx.org/chem/MNXM1000570',
#  'SLM:000692959': 'https://rdf.metanetx.org/chem/MNXM1000571',
#  'SLM:000692960': 'https://rdf.metanetx.org/chem/MNXM1000572',
#  'SLM:000692961': 'https://rdf.metanetx.org/chem/MNXM1000573',
#  'SLM:000692962': 'https://rdf.metanetx.org/chem/MNXM1000574',
#  'SLM:000692963': 'https://rdf.metanetx.org/chem/MNXM1000575',
#  'SLM:000692964': 'https://rdf.metanetx.org/chem/MNXM1000576',
#  'SLM:000692965': 'https://rdf.metanetx.org/chem/MNXM1000577',
#  'SLM:000692966': 'https://rdf.metanetx.org/chem/MNXM1000578',
#  'SLM:000692967': 'https://rdf.metanetx.org/chem/MNXM1000579',
#  'chebi:195946': 'https://rdf.metanetx.org/chem/MNXM100058',
#  'lipidmapsM:LMFA07010219': 'https://rdf.metanetx.org/chem/MNXM100058',
#  'SLM:000692968': 'https://rdf.metanetx.org/chem/MNXM1000580',
#  'SLM:000692969': 'https://rdf.metanetx.org/chem/MNXM1000581',
#  'SLM:000692970': 'https://rdf.metanetx.org/chem/MNXM1000582',
#  'SLM:000692971': 'https://rdf.metanetx.org/chem/MNXM1000583',
#  'SLM:000692972': 'https://rdf.metanetx.org/chem/MNXM1000584',
#  'SLM:000692973': 'https://rdf.metanetx.org/chem/MNXM1000585',
#  'SLM:000692974': 'https://rdf.metanetx.org/chem/MNXM1000586',
#  'SLM:000692975': 'https://rdf.metanetx.org/chem/MNXM1000587',
#  'SLM:000692976': 'https://rdf.metanetx.org/chem/MNXM1000588',
#  'SLM:000692977': 'https://rdf.metanetx.org/chem/MNXM1000589',
#  'lipidmapsM:LMFA07010072': 'https://rdf.metanetx.org/chem/MNXM100059',
#  'SLM:000692978': 'https://rdf.metanetx.org/chem/MNXM1000590',
#  'SLM:000692979': 'https://rdf.metanetx.org/chem/MNXM1000591',
#  'SLM:000692980': 'https://rdf.metanetx.org/chem/MNXM1000592',
#  'SLM:000692981': 'https://rdf.metanetx.org/chem/MNXM1000593',
#  'SLM:000692982': 'https://rdf.metanetx.org/chem/MNXM1000594',
#  'SLM:000692983': 'https://rdf.metanetx.org/chem/MNXM1000595',
#  'SLM:000692984': 'https://rdf.metanetx.org/chem/MNXM1000596',
#  'SLM:000692985': 'https://rdf.metanetx.org/chem/MNXM1000597',
#  'SLM:000692986': 'https://rdf.metanetx.org/chem/MNXM1000598',
#  'SLM:000692987': 'https://rdf.metanetx.org/chem/MNXM1000599',
#  'chebi:80531': 'https://rdf.metanetx.org/chem/MNXM10006',
#  'keggC:C16496': 'https://rdf.metanetx.org/chem/MNXM10006',
#  'seedM:cpd16284': 'https://rdf.metanetx.org/chem/MNXM10006',
#  'lipidmapsM:LMFA11000656': 'https://rdf.metanetx.org/chem/MNXM100060',
#  'SLM:000692988': 'https://rdf.metanetx.org/chem/MNXM1000600',
#  'SLM:000692989': 'https://rdf.metanetx.org/chem/MNXM1000601',
#  'SLM:000692990': 'https://rdf.metanetx.org/chem/MNXM1000602',
#  'SLM:000692991': 'https://rdf.metanetx.org/chem/MNXM1000603',
#  'SLM:000692992': 'https://rdf.metanetx.org/chem/MNXM1000604',
#  'SLM:000692993': 'https://rdf.metanetx.org/chem/MNXM1000605',
#  'SLM:000692994': 'https://rdf.metanetx.org/chem/MNXM1000606',
#  'SLM:000692995': 'https://rdf.metanetx.org/chem/MNXM1000607',
#  'SLM:000692996': 'https://rdf.metanetx.org/chem/MNXM1000608',
#  'SLM:000692997': 'https://rdf.metanetx.org/chem/MNXM1000609',
#  'chebi:179965': 'https://rdf.metanetx.org/chem/MNXM100061',
#  'lipidmapsM:LMFA07010602': 'https://rdf.metanetx.org/chem/MNXM100061',
#  'SLM:000692998': 'https://rdf.metanetx.org/chem/MNXM1000610',
#  'SLM:000692999': 'https://rdf.metanetx.org/chem/MNXM1000611',
#  'SLM:000693000': 'https://rdf.metanetx.org/chem/MNXM1000612',
#  'SLM:000693001': 'https://rdf.metanetx.org/chem/MNXM1000613',
#  'SLM:000693002': 'https://rdf.metanetx.org/chem/MNXM1000614',
#  'SLM:000693003': 'https://rdf.metanetx.org/chem/MNXM1000615',
#  'SLM:000693004': 'https://rdf.metanetx.org/chem/MNXM1000616',
#  'SLM:000693005': 'https://rdf.metanetx.org/chem/MNXM1000617',
#  'SLM:000693006': 'https://rdf.metanetx.org/chem/MNXM1000618',
#  'SLM:000693007': 'https://rdf.metanetx.org/chem/MNXM1000619',
#  'chebi:137765': 'https://rdf.metanetx.org/chem/MNXM100062',
#  'lipidmapsM:LMFA12000253': 'https://rdf.metanetx.org/chem/MNXM100062',
#  'SLM:000693008': 'https://rdf.metanetx.org/chem/MNXM1000620',
#  'SLM:000693009': 'https://rdf.metanetx.org/chem/MNXM1000621',
#  'SLM:000693010': 'https://rdf.metanetx.org/chem/MNXM1000622',
#  'SLM:000693011': 'https://rdf.metanetx.org/chem/MNXM1000623',
#  'SLM:000693012': 'https://rdf.metanetx.org/chem/MNXM1000624',
#  'SLM:000693013': 'https://rdf.metanetx.org/chem/MNXM1000625',
#  'SLM:000693014': 'https://rdf.metanetx.org/chem/MNXM1000626',
#  'SLM:000693015': 'https://rdf.metanetx.org/chem/MNXM1000627',
#  'SLM:000693016': 'https://rdf.metanetx.org/chem/MNXM1000628',
#  'SLM:000693017': 'https://rdf.metanetx.org/chem/MNXM1000629',
#  'lipidmapsM:LMFA11000673': 'https://rdf.metanetx.org/chem/MNXM100063',
#  'SLM:000693018': 'https://rdf.metanetx.org/chem/MNXM1000630',
#  'SLM:000693019': 'https://rdf.metanetx.org/chem/MNXM1000631',
#  'SLM:000693020': 'https://rdf.metanetx.org/chem/MNXM1000632',
#  'SLM:000693021': 'https://rdf.metanetx.org/chem/MNXM1000633',
#  'SLM:000693022': 'https://rdf.metanetx.org/chem/MNXM1000634',
#  'SLM:000693023': 'https://rdf.metanetx.org/chem/MNXM1000635',
#  'SLM:000693024': 'https://rdf.metanetx.org/chem/MNXM1000636',
#  'SLM:000693025': 'https://rdf.metanetx.org/chem/MNXM1000637',
#  'SLM:000693026': 'https://rdf.metanetx.org/chem/MNXM1000638',
#  'SLM:000693027': 'https://rdf.metanetx.org/chem/MNXM1000639',
#  'chebi:169442': 'https://rdf.metanetx.org/chem/MNXM100064',
#  'lipidmapsM:LMFA07040039': 'https://rdf.metanetx.org/chem/MNXM100064',
#  'SLM:000693028': 'https://rdf.metanetx.org/chem/MNXM1000640',
#  'SLM:000693029': 'https://rdf.metanetx.org/chem/MNXM1000641',
#  'SLM:000693030': 'https://rdf.metanetx.org/chem/MNXM1000642',
#  'SLM:000693031': 'https://rdf.metanetx.org/chem/MNXM1000643',
#  'SLM:000693032': 'https://rdf.metanetx.org/chem/MNXM1000644',
#  'SLM:000693033': 'https://rdf.metanetx.org/chem/MNXM1000645',
#  'SLM:000693034': 'https://rdf.metanetx.org/chem/MNXM1000646',
#  'SLM:000693035': 'https://rdf.metanetx.org/chem/MNXM1000647',
#  'SLM:000693036': 'https://rdf.metanetx.org/chem/MNXM1000648',
#  'SLM:000693037': 'https://rdf.metanetx.org/chem/MNXM1000649',
#  'lipidmapsM:LMFA11000497': 'https://rdf.metanetx.org/chem/MNXM100065',
#  'SLM:000693038': 'https://rdf.metanetx.org/chem/MNXM1000650',
#  'SLM:000693039': 'https://rdf.metanetx.org/chem/MNXM1000651',
#  'SLM:000693040': 'https://rdf.metanetx.org/chem/MNXM1000652',
#  'SLM:000693041': 'https://rdf.metanetx.org/chem/MNXM1000653',
#  'SLM:000693042': 'https://rdf.metanetx.org/chem/MNXM1000654',
#  'SLM:000693043': 'https://rdf.metanetx.org/chem/MNXM1000655',
#  'SLM:000693044': 'https://rdf.metanetx.org/chem/MNXM1000656',
#  'SLM:000693045': 'https://rdf.metanetx.org/chem/MNXM1000657',
#  'SLM:000693046': 'https://rdf.metanetx.org/chem/MNXM1000658',
#  'SLM:000693047': 'https://rdf.metanetx.org/chem/MNXM1000659',
#  'chebi:187958': 'https://rdf.metanetx.org/chem/MNXM100066',
#  'lipidmapsM:LMFA07010646': 'https://rdf.metanetx.org/chem/MNXM100066',
#  'SLM:000693048': 'https://rdf.metanetx.org/chem/MNXM1000660',
#  'SLM:000693049': 'https://rdf.metanetx.org/chem/MNXM1000661',
#  'SLM:000693050': 'https://rdf.metanetx.org/chem/MNXM1000662',
#  'SLM:000693051': 'https://rdf.metanetx.org/chem/MNXM1000663',
#  'SLM:000693052': 'https://rdf.metanetx.org/chem/MNXM1000664',
#  'SLM:000693053': 'https://rdf.metanetx.org/chem/MNXM1000665',
#  'SLM:000693054': 'https://rdf.metanetx.org/chem/MNXM1000666',
#  'SLM:000693055': 'https://rdf.metanetx.org/chem/MNXM1000667',
#  'SLM:000693056': 'https://rdf.metanetx.org/chem/MNXM1000668',
#  'SLM:000693057': 'https://rdf.metanetx.org/chem/MNXM1000669',
#  'lipidmapsM:LMFA11000556': 'https://rdf.metanetx.org/chem/MNXM100067',
#  'SLM:000693058': 'https://rdf.metanetx.org/chem/MNXM1000670',
#  'SLM:000693059': 'https://rdf.metanetx.org/chem/MNXM1000671',
#  'SLM:000693060': 'https://rdf.metanetx.org/chem/MNXM1000672',
#  'SLM:000693061': 'https://rdf.metanetx.org/chem/MNXM1000673',
#  'SLM:000693062': 'https://rdf.metanetx.org/chem/MNXM1000674',
#  'SLM:000693063': 'https://rdf.metanetx.org/chem/MNXM1000675',
#  'SLM:000693064': 'https://rdf.metanetx.org/chem/MNXM1000676',
#  'SLM:000693065': 'https://rdf.metanetx.org/chem/MNXM1000677',
#  'SLM:000693066': 'https://rdf.metanetx.org/chem/MNXM1000678',
#  'SLM:000693067': 'https://rdf.metanetx.org/chem/MNXM1000679',
#  'lipidmapsM:LMFA11000630': 'https://rdf.metanetx.org/chem/MNXM100068',
#  'SLM:000693068': 'https://rdf.metanetx.org/chem/MNXM1000680',
#  'SLM:000693069': 'https://rdf.metanetx.org/chem/MNXM1000681',
#  'SLM:000693070': 'https://rdf.metanetx.org/chem/MNXM1000682',
#  'SLM:000693071': 'https://rdf.metanetx.org/chem/MNXM1000683',
#  'SLM:000693072': 'https://rdf.metanetx.org/chem/MNXM1000684',
#  'SLM:000693073': 'https://rdf.metanetx.org/chem/MNXM1000685',
#  'SLM:000693074': 'https://rdf.metanetx.org/chem/MNXM1000686',
#  'SLM:000693075': 'https://rdf.metanetx.org/chem/MNXM1000687',
#  'SLM:000693076': 'https://rdf.metanetx.org/chem/MNXM1000688',
#  'SLM:000693077': 'https://rdf.metanetx.org/chem/MNXM1000689',
#  'chebi:179800': 'https://rdf.metanetx.org/chem/MNXM100069',
#  'lipidmapsM:LMFA07010494': 'https://rdf.metanetx.org/chem/MNXM100069',
#  'SLM:000693078': 'https://rdf.metanetx.org/chem/MNXM1000690',
#  'SLM:000693079': 'https://rdf.metanetx.org/chem/MNXM1000691',
#  'SLM:000693080': 'https://rdf.metanetx.org/chem/MNXM1000692',
#  'SLM:000693081': 'https://rdf.metanetx.org/chem/MNXM1000693',
#  'SLM:000693082': 'https://rdf.metanetx.org/chem/MNXM1000694',
#  'SLM:000693083': 'https://rdf.metanetx.org/chem/MNXM1000695',
#  'SLM:000693084': 'https://rdf.metanetx.org/chem/MNXM1000696',
#  'SLM:000693085': 'https://rdf.metanetx.org/chem/MNXM1000697',
#  'SLM:000693086': 'https://rdf.metanetx.org/chem/MNXM1000698',
#  'SLM:000693087': 'https://rdf.metanetx.org/chem/MNXM1000699',
#  'seedM:cpd16897': 'https://rdf.metanetx.org/chem/MNXM10007',
#  'chebi:140568': 'https://rdf.metanetx.org/chem/MNXM100070',
#  'lipidmapsM:LMFA11000693': 'https://rdf.metanetx.org/chem/MNXM100070',
#  'SLM:000693088': 'https://rdf.metanetx.org/chem/MNXM1000700',
#  'SLM:000693089': 'https://rdf.metanetx.org/chem/MNXM1000701',
#  'SLM:000693090': 'https://rdf.metanetx.org/chem/MNXM1000702',
#  'SLM:000693091': 'https://rdf.metanetx.org/chem/MNXM1000703',
#  'SLM:000693092': 'https://rdf.metanetx.org/chem/MNXM1000704',
#  'SLM:000693093': 'https://rdf.metanetx.org/chem/MNXM1000705',
#  'SLM:000693094': 'https://rdf.metanetx.org/chem/MNXM1000706',
#  'SLM:000693095': 'https://rdf.metanetx.org/chem/MNXM1000707',
#  'SLM:000693096': 'https://rdf.metanetx.org/chem/MNXM1000708',
#  'SLM:000693097': 'https://rdf.metanetx.org/chem/MNXM1000709',
#  'lipidmapsM:LMFA01090105': 'https://rdf.metanetx.org/chem/MNXM100071',
#  'SLM:000693098': 'https://rdf.metanetx.org/chem/MNXM1000710',
#  'SLM:000693099': 'https://rdf.metanetx.org/chem/MNXM1000711',
#  'SLM:000693100': 'https://rdf.metanetx.org/chem/MNXM1000712',
#  'SLM:000693101': 'https://rdf.metanetx.org/chem/MNXM1000713',
#  'SLM:000693102': 'https://rdf.metanetx.org/chem/MNXM1000714',
#  'SLM:000693103': 'https://rdf.metanetx.org/chem/MNXM1000715',
#  'SLM:000693104': 'https://rdf.metanetx.org/chem/MNXM1000716',
#  'SLM:000693105': 'https://rdf.metanetx.org/chem/MNXM1000717',
#  'SLM:000693106': 'https://rdf.metanetx.org/chem/MNXM1000718',
#  'SLM:000693107': 'https://rdf.metanetx.org/chem/MNXM1000719',
#  'chebi:195790': 'https://rdf.metanetx.org/chem/MNXM100072',
#  'hmdb:HMDB0032312': 'https://rdf.metanetx.org/chem/MNXM100072',
#  'hmdb:HMDB32312': 'https://rdf.metanetx.org/chem/MNXM100072',
#  'lipidmapsM:LMFA07010639': 'https://rdf.metanetx.org/chem/MNXM100072',
#  'SLM:000693108': 'https://rdf.metanetx.org/chem/MNXM1000720',
#  'SLM:000693109': 'https://rdf.metanetx.org/chem/MNXM1000721',
#  'SLM:000693110': 'https://rdf.metanetx.org/chem/MNXM1000722',
#  'SLM:000693111': 'https://rdf.metanetx.org/chem/MNXM1000723',
#  'SLM:000693112': 'https://rdf.metanetx.org/chem/MNXM1000724',
#  'SLM:000693113': 'https://rdf.metanetx.org/chem/MNXM1000725',
#  'SLM:000693114': 'https://rdf.metanetx.org/chem/MNXM1000726',
#  'SLM:000693115': 'https://rdf.metanetx.org/chem/MNXM1000727',
#  'SLM:000693116': 'https://rdf.metanetx.org/chem/MNXM1000728',
#  'SLM:000693117': 'https://rdf.metanetx.org/chem/MNXM1000729',
#  'lipidmapsM:LMFA12000289': 'https://rdf.metanetx.org/chem/MNXM100073',
#  'SLM:000693118': 'https://rdf.metanetx.org/chem/MNXM1000730',
#  'SLM:000693119': 'https://rdf.metanetx.org/chem/MNXM1000731',
#  'SLM:000693120': 'https://rdf.metanetx.org/chem/MNXM1000732',
#  'SLM:000693121': 'https://rdf.metanetx.org/chem/MNXM1000733',
#  'SLM:000693122': 'https://rdf.metanetx.org/chem/MNXM1000734',
#  'SLM:000693123': 'https://rdf.metanetx.org/chem/MNXM1000735',
#  'SLM:000693124': 'https://rdf.metanetx.org/chem/MNXM1000736',
#  'SLM:000693125': 'https://rdf.metanetx.org/chem/MNXM1000737',
#  'SLM:000693126': 'https://rdf.metanetx.org/chem/MNXM1000738',
#  'SLM:000693127': 'https://rdf.metanetx.org/chem/MNXM1000739',
#  'lipidmapsM:LMFA12000203': 'https://rdf.metanetx.org/chem/MNXM100074',
#  'SLM:000693128': 'https://rdf.metanetx.org/chem/MNXM1000740',
#  'SLM:000693129': 'https://rdf.metanetx.org/chem/MNXM1000741',
#  'SLM:000693130': 'https://rdf.metanetx.org/chem/MNXM1000742',
#  'SLM:000693131': 'https://rdf.metanetx.org/chem/MNXM1000743',
#  'SLM:000693132': 'https://rdf.metanetx.org/chem/MNXM1000744',
#  'SLM:000693133': 'https://rdf.metanetx.org/chem/MNXM1000745',
#  'SLM:000693134': 'https://rdf.metanetx.org/chem/MNXM1000746',
#  'SLM:000693135': 'https://rdf.metanetx.org/chem/MNXM1000747',
#  'SLM:000693136': 'https://rdf.metanetx.org/chem/MNXM1000748',
#  'SLM:000693137': 'https://rdf.metanetx.org/chem/MNXM1000749',
#  'SLM:000693138': 'https://rdf.metanetx.org/chem/MNXM1000750',
#  'SLM:000693139': 'https://rdf.metanetx.org/chem/MNXM1000751',
#  'SLM:000693140': 'https://rdf.metanetx.org/chem/MNXM1000752',
#  'SLM:000693141': 'https://rdf.metanetx.org/chem/MNXM1000753',
#  'SLM:000693142': 'https://rdf.metanetx.org/chem/MNXM1000754',
#  'SLM:000693143': 'https://rdf.metanetx.org/chem/MNXM1000755',
#  'SLM:000693144': 'https://rdf.metanetx.org/chem/MNXM1000756',
#  'SLM:000693145': 'https://rdf.metanetx.org/chem/MNXM1000757',
#  'SLM:000693146': 'https://rdf.metanetx.org/chem/MNXM1000758',
#  'SLM:000693147': 'https://rdf.metanetx.org/chem/MNXM1000759',
#  'chebi:179799': 'https://rdf.metanetx.org/chem/MNXM100076',
#  'lipidmapsM:LMFA07010492': 'https://rdf.metanetx.org/chem/MNXM100076',
#  'SLM:000693148': 'https://rdf.metanetx.org/chem/MNXM1000760',
#  'SLM:000693149': 'https://rdf.metanetx.org/chem/MNXM1000761',
#  'SLM:000693150': 'https://rdf.metanetx.org/chem/MNXM1000762',
#  'SLM:000693151': 'https://rdf.metanetx.org/chem/MNXM1000763',
#  'SLM:000693152': 'https://rdf.metanetx.org/chem/MNXM1000764',
#  'SLM:000693153': 'https://rdf.metanetx.org/chem/MNXM1000765',
#  'SLM:000693154': 'https://rdf.metanetx.org/chem/MNXM1000766',
#  'SLM:000693155': 'https://rdf.metanetx.org/chem/MNXM1000767',
#  'SLM:000693156': 'https://rdf.metanetx.org/chem/MNXM1000768',
#  'SLM:000693157': 'https://rdf.metanetx.org/chem/MNXM1000769',
#  'chebi:184718': 'https://rdf.metanetx.org/chem/MNXM100077',
#  'hmdb:HMDB0030300': 'https://rdf.metanetx.org/chem/MNXM100077',
#  'hmdb:HMDB30300': 'https://rdf.metanetx.org/chem/MNXM100077',
#  'lipidmapsM:LMFA11000405': 'https://rdf.metanetx.org/chem/MNXM100077',
#  'SLM:000693158': 'https://rdf.metanetx.org/chem/MNXM1000770',
#  'SLM:000693159': 'https://rdf.metanetx.org/chem/MNXM1000771',
#  'SLM:000693160': 'https://rdf.metanetx.org/chem/MNXM1000772',
#  'SLM:000693161': 'https://rdf.metanetx.org/chem/MNXM1000773',
#  'SLM:000693162': 'https://rdf.metanetx.org/chem/MNXM1000774',
#  'SLM:000693163': 'https://rdf.metanetx.org/chem/MNXM1000775',
#  'SLM:000693164': 'https://rdf.metanetx.org/chem/MNXM1000776',
#  'SLM:000693165': 'https://rdf.metanetx.org/chem/MNXM1000777',
#  'SLM:000693166': 'https://rdf.metanetx.org/chem/MNXM1000778',
#  'SLM:000693167': 'https://rdf.metanetx.org/chem/MNXM1000779',
#  'lipidmapsM:LMFA11000665': 'https://rdf.metanetx.org/chem/MNXM100078',
#  'SLM:000693168': 'https://rdf.metanetx.org/chem/MNXM1000780',
#  'SLM:000693169': 'https://rdf.metanetx.org/chem/MNXM1000781',
#  'SLM:000693170': 'https://rdf.metanetx.org/chem/MNXM1000782',
#  'SLM:000693171': 'https://rdf.metanetx.org/chem/MNXM1000783',
#  'SLM:000693172': 'https://rdf.metanetx.org/chem/MNXM1000784',
#  'SLM:000693173': 'https://rdf.metanetx.org/chem/MNXM1000785',
#  'SLM:000693174': 'https://rdf.metanetx.org/chem/MNXM1000786',
#  'SLM:000693175': 'https://rdf.metanetx.org/chem/MNXM1000787',
#  'SLM:000693176': 'https://rdf.metanetx.org/chem/MNXM1000788',
#  ...}

# %%
def build_mnx_index(dedup_dict: Dict[str, str]) -> Dict[str, Set[str]]:
    """Invert label->MNX mapping to MNX->set(labels)."""
    mnx_to_labels = defaultdict(set)
    for label, mnx in dedup_dict.items():
        mnx_to_labels[mnx].add(label)
    return mnx_to_labels

def _pick_primary_mnx(labels: List[str], dedup_dict: Dict[str, str]) -> Optional[str]:
    """Pick the MNX id with the highest support among present labels (stable if tie)."""
    present_mnxs = [dedup_dict[lbl] for lbl in labels if lbl in dedup_dict]
    if not present_mnxs:
        return None
    counts = Counter(present_mnxs)
    # Most common; in a tie Counter keeps first-seen order which follows labels order
    return counts.most_common(1)[0][0]

def compare_clusters_to_mnx(
    clusters: List[List[str]],
    dedup_dict: Dict[str, str],
    show_progress: bool = True
) -> List[Dict[str, Any]]:
    """
    Compare each stereomapper cluster (list of labels) to MetaNetX groupings from dedup_dict.

    Labels (mutually exclusive):
      - exact_agreement:         cluster_set == mnx_related
      - mnx_superset_agreement:  cluster_set  ⊂ mnx_related
      - stereomapper_superset_agreement: mnx_related ⊂ cluster_set
      - mnx_id_disagreement:     >1 MNX id among labels present in dict
      - partial_overlap_unmapped: 1 MNX id, but some cluster labels are unmapped in dict
      - no_overlap_with_dict:    none of the cluster labels are in dict
    """
    mnx_to_labels = build_mnx_index(dedup_dict)
    results = []

    iterator = tqdm(clusters, desc="Comparing clusters", unit="cluster") if show_progress else clusters

    for cluster in iterator:
        cluster_list = list(cluster)  # preserve user order for reporting
        cluster_set = set(cluster_list)

        # Partition cluster into dict-mapped vs unmapped
        present = [lbl for lbl in cluster_list if lbl in dedup_dict]
        unmapped = sorted(cluster_set - set(present))

        hit_mnx_ids = {dedup_dict[lbl] for lbl in present}
        support_count = len(present)
        cluster_size = len(cluster_list)
        support_frac  = support_count / cluster_size if cluster_size else 0.0

        # Fast exits
        if support_count == 0:
            classification = "no_overlap_with_dict"
            results.append({
                "cluster": cluster_list,
                "present_in_dict": [],
                "unmapped_in_dict": unmapped,
                "mnx_ids_hit": [],
                "support_count": 0,
                "cluster_size": cluster_size,
                "support_fraction": 0.0,
                "overlap_size": 0,
                "jaccard_cluster_vs_mnx": 0.0,
                "related_labels_by_mnx": {},
                "mnx_minus_cluster": [],
                "cluster_minus_mnx": [],
                "all_related_labels_union": [],
                "classification": classification,
            })
            continue

        if len(hit_mnx_ids) > 1:
            # Your 'disagreement' case — multiple MNX ids claimed inside one cluster
            related_by_mnx = {mnx: sorted(mnx_to_labels[mnx]) for mnx in hit_mnx_ids}
            all_related_union = sorted(set().union(*(set(v) for v in related_by_mnx.values())))
            results.append({
                "cluster": cluster_list,
                "present_in_dict": sorted(present),
                "unmapped_in_dict": unmapped,
                "mnx_ids_hit": sorted(hit_mnx_ids),
                "support_count": support_count,
                "cluster_size": cluster_size,
                "support_fraction": support_frac,
                "overlap_size": len(set(present)),  # overlap with dict-mapped labels
                "jaccard_cluster_vs_mnx": 0.0,     # undefined for multi-MNX; leave 0.0
                "related_labels_by_mnx": related_by_mnx,
                "mnx_minus_cluster": [],           # undefined for multi-MNX; leave empty
                "cluster_minus_mnx": [],
                "all_related_labels_union": all_related_union,
                "classification": "mnx_id_disagreement",
            })
            continue

        # Single MNX id path
        mnx = next(iter(hit_mnx_ids))
        mnx_related_set = set(mnx_to_labels[mnx])
        # Set differences both ways
        mnx_minus_cluster = sorted(mnx_related_set - cluster_set)
        cluster_minus_mnx = sorted(cluster_set - mnx_related_set)

        # Similarity (on sets), safe for zeros
        union = len(mnx_related_set | cluster_set)
        inter = len(mnx_related_set & cluster_set)
        jaccard = (inter / union) if union else 1.0

        # Labeling logic
        if unmapped:
            # Some labels in the cluster aren't even in the dict — keep this explicit.
            classification = "partial_overlap_unmapped"
        elif mnx_related_set == cluster_set:
            classification = "exact_agreement"
        elif cluster_set < mnx_related_set:
            classification = "mnx_superset_agreement"              # stereomapper ⊂ MNX
        elif mnx_related_set < cluster_set:
            classification = "stereomapper_superset_agreement"      # stereomapper ⊃ MNX
        else:
            # Shouldn't really happen given above cases, but keep a safe default
            classification = "partial_overlap_unmapped" if unmapped else "mnx_superset_agreement" if len(mnx_minus_cluster) else "stereomapper_superset_agreement"

        results.append({
            "cluster": cluster_list,
            "present_in_dict": sorted(present),
            "unmapped_in_dict": unmapped,
            "mnx_ids_hit": [mnx],
            "primary_mnx": mnx,  # explicit surface
            "support_count": support_count,
            "cluster_size": cluster_size,
            "support_fraction": support_frac,
            "overlap_size": inter,
            "jaccard_cluster_vs_mnx": jaccard,
            "related_labels_by_mnx": {mnx: sorted(mnx_related_set)},
            "mnx_minus_cluster": mnx_minus_cluster,  # MNX has these extra labels
            "cluster_minus_mnx": cluster_minus_mnx,  # stereomapper has these extra labels
            "all_related_labels_union": sorted(mnx_related_set),
            "classification": classification,
        })

    return results

# %%
results = compare_clusters_to_mnx(all_members, dedup_dict)
# Out:
# Comparing clusters: 100%|██████████| 987926/987926 [00:12<00:00, 77040.27cluster/s]

# %%
results
# Out:
# [{'cluster': ['SLM:000736507'],
#   'present_in_dict': ['SLM:000736507'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM1044118'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM1044118',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM1044118': ['SLM:000736507']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000736507'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000496071'],
#   'present_in_dict': ['SLM:000496071'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM446350'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM446350',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM446350': ['SLM:000496071']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000496071'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000491467'],
#   'present_in_dict': ['SLM:000491467'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM446347'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM446347',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM446347': ['SLM:000491467']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000491467'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000512033'],
#   'present_in_dict': ['SLM:000512033'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM822853'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM822853',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM822853': ['SLM:000512033']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000512033'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['chebi:80858', 'keggC:C17009', 'seedM:cpd17277'],
#   'present_in_dict': ['chebi:80858', 'keggC:C17009', 'seedM:cpd17277'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM62681'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM62681',
#   'support_count': 3,
#   'cluster_size': 3,
#   'support_fraction': 1.0,
#   'overlap_size': 3,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM62681': ['chebi:80858',
#     'keggC:C17009',
#     'seedM:cpd17277']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['chebi:80858',
#    'keggC:C17009',
#    'seedM:cpd17277'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000012662'],
#   'present_in_dict': ['SLM:000012662'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM344848'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM344848',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM344848': ['SLM:000012662']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000012662'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['lipidmapsM:LMGP04010069'],
#   'present_in_dict': ['lipidmapsM:LMGP04010069'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM73492'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM73492',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 0.5,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM73492': ['SLM:000042967',
#     'lipidmapsM:LMGP04010069']},
#   'mnx_minus_cluster': ['SLM:000042967'],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000042967', 'lipidmapsM:LMGP04010069'],
#   'classification': 'mnx_superset_agreement'},
#  {'cluster': ['SLM:000042967'],
#   'present_in_dict': ['SLM:000042967'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM73492'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM73492',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 0.5,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM73492': ['SLM:000042967',
#     'lipidmapsM:LMGP04010069']},
#   'mnx_minus_cluster': ['lipidmapsM:LMGP04010069'],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000042967', 'lipidmapsM:LMGP04010069'],
#   'classification': 'mnx_superset_agreement'},
#  {'cluster': ['SLM:000644088'],
#   'present_in_dict': ['SLM:000644088'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM951703'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM951703',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM951703': ['SLM:000644088']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000644088'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000572531'],
#   'present_in_dict': ['SLM:000572531'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM881552'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM881552',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM881552': ['SLM:000572531']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000572531'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000213588'],
#   'present_in_dict': ['SLM:000213588'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM220634'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM220634',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM220634': ['SLM:000213588']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000213588'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000213725'],
#   'present_in_dict': ['SLM:000213725'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM324572'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM324572',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM324572': ['SLM:000213725']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000213725'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000452819'],
#   'present_in_dict': ['SLM:000452819'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM216050'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM216050',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM216050': ['SLM:000452819']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000452819'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000433625'],
#   'present_in_dict': ['SLM:000433625'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM216053'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM216053',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM216053': ['SLM:000433625']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000433625'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['sabiorkM:1470'],
#   'present_in_dict': ['sabiorkM:1470'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM1584689'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM1584689',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 0.08333333333333333,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM1584689': ['chebi:13012',
#     'chebi:17994',
#     'chebi:21079',
#     'chebi:4234',
#     'chebi:58345',
#     'chebi:68688',
#     'chebi:68819',
#     'hmdb:HMDB0011688',
#     'hmdb:HMDB11688',
#     'keggC:C01151',
#     'sabiorkM:1470',
#     'seedM:cpd00847']},
#   'mnx_minus_cluster': ['chebi:13012',
#    'chebi:17994',
#    'chebi:21079',
#    'chebi:4234',
#    'chebi:58345',
#    'chebi:68688',
#    'chebi:68819',
#    'hmdb:HMDB0011688',
#    'hmdb:HMDB11688',
#    'keggC:C01151',
#    'seedM:cpd00847'],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['chebi:13012',
#    'chebi:17994',
#    'chebi:21079',
#    'chebi:4234',
#    'chebi:58345',
#    'chebi:68688',
#    'chebi:68819',
#    'hmdb:HMDB0011688',
#    'hmdb:HMDB11688',
#    'keggC:C01151',
#    'sabiorkM:1470',
#    'seedM:cpd00847'],
#   'classification': 'mnx_superset_agreement'},
#  {'cluster': ['chebi:17994'],
#   'present_in_dict': ['chebi:17994'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM1584689'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM1584689',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 0.08333333333333333,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM1584689': ['chebi:13012',
#     'chebi:17994',
#     'chebi:21079',
#     'chebi:4234',
#     'chebi:58345',
#     'chebi:68688',
#     'chebi:68819',
#     'hmdb:HMDB0011688',
#     'hmdb:HMDB11688',
#     'keggC:C01151',
#     'sabiorkM:1470',
#     'seedM:cpd00847']},
#   'mnx_minus_cluster': ['chebi:13012',
#    'chebi:21079',
#    'chebi:4234',
#    'chebi:58345',
#    'chebi:68688',
#    'chebi:68819',
#    'hmdb:HMDB0011688',
#    'hmdb:HMDB11688',
#    'keggC:C01151',
#    'sabiorkM:1470',
#    'seedM:cpd00847'],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['chebi:13012',
#    'chebi:17994',
#    'chebi:21079',
#    'chebi:4234',
#    'chebi:58345',
#    'chebi:68688',
#    'chebi:68819',
#    'hmdb:HMDB0011688',
#    'hmdb:HMDB11688',
#    'keggC:C01151',
#    'sabiorkM:1470',
#    'seedM:cpd00847'],
#   'classification': 'mnx_superset_agreement'},
#  {'cluster': ['chebi:68819', 'hmdb:HMDB0011688', 'keggC:C01151'],
#   'present_in_dict': ['chebi:68819', 'hmdb:HMDB0011688', 'keggC:C01151'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM1584689'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM1584689',
#   'support_count': 3,
#   'cluster_size': 3,
#   'support_fraction': 1.0,
#   'overlap_size': 3,
#   'jaccard_cluster_vs_mnx': 0.25,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM1584689': ['chebi:13012',
#     'chebi:17994',
#     'chebi:21079',
#     'chebi:4234',
#     'chebi:58345',
#     'chebi:68688',
#     'chebi:68819',
#     'hmdb:HMDB0011688',
#     'hmdb:HMDB11688',
#     'keggC:C01151',
#     'sabiorkM:1470',
#     'seedM:cpd00847']},
#   'mnx_minus_cluster': ['chebi:13012',
#    'chebi:17994',
#    'chebi:21079',
#    'chebi:4234',
#    'chebi:58345',
#    'chebi:68688',
#    'hmdb:HMDB11688',
#    'sabiorkM:1470',
#    'seedM:cpd00847'],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['chebi:13012',
#    'chebi:17994',
#    'chebi:21079',
#    'chebi:4234',
#    'chebi:58345',
#    'chebi:68688',
#    'chebi:68819',
#    'hmdb:HMDB0011688',
#    'hmdb:HMDB11688',
#    'keggC:C01151',
#    'sabiorkM:1470',
#    'seedM:cpd00847'],
#   'classification': 'mnx_superset_agreement'},
#  {'cluster': ['vmhM:r15bp'],
#   'present_in_dict': ['vmhM:r15bp'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM1584690'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM1584690',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM1584690': ['vmhM:r15bp']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['vmhM:r15bp'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['chebi:58345'],
#   'present_in_dict': ['chebi:58345'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM1584689'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM1584689',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 0.08333333333333333,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM1584689': ['chebi:13012',
#     'chebi:17994',
#     'chebi:21079',
#     'chebi:4234',
#     'chebi:58345',
#     'chebi:68688',
#     'chebi:68819',
#     'hmdb:HMDB0011688',
#     'hmdb:HMDB11688',
#     'keggC:C01151',
#     'sabiorkM:1470',
#     'seedM:cpd00847']},
#   'mnx_minus_cluster': ['chebi:13012',
#    'chebi:17994',
#    'chebi:21079',
#    'chebi:4234',
#    'chebi:68688',
#    'chebi:68819',
#    'hmdb:HMDB0011688',
#    'hmdb:HMDB11688',
#    'keggC:C01151',
#    'sabiorkM:1470',
#    'seedM:cpd00847'],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['chebi:13012',
#    'chebi:17994',
#    'chebi:21079',
#    'chebi:4234',
#    'chebi:58345',
#    'chebi:68688',
#    'chebi:68819',
#    'hmdb:HMDB0011688',
#    'hmdb:HMDB11688',
#    'keggC:C01151',
#    'sabiorkM:1470',
#    'seedM:cpd00847'],
#   'classification': 'mnx_superset_agreement'},
#  {'cluster': ['chebi:68688', 'seedM:cpd00847'],
#   'present_in_dict': ['chebi:68688', 'seedM:cpd00847'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM1584689'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM1584689',
#   'support_count': 2,
#   'cluster_size': 2,
#   'support_fraction': 1.0,
#   'overlap_size': 2,
#   'jaccard_cluster_vs_mnx': 0.16666666666666666,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM1584689': ['chebi:13012',
#     'chebi:17994',
#     'chebi:21079',
#     'chebi:4234',
#     'chebi:58345',
#     'chebi:68688',
#     'chebi:68819',
#     'hmdb:HMDB0011688',
#     'hmdb:HMDB11688',
#     'keggC:C01151',
#     'sabiorkM:1470',
#     'seedM:cpd00847']},
#   'mnx_minus_cluster': ['chebi:13012',
#    'chebi:17994',
#    'chebi:21079',
#    'chebi:4234',
#    'chebi:58345',
#    'chebi:68819',
#    'hmdb:HMDB0011688',
#    'hmdb:HMDB11688',
#    'keggC:C01151',
#    'sabiorkM:1470'],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['chebi:13012',
#    'chebi:17994',
#    'chebi:21079',
#    'chebi:4234',
#    'chebi:58345',
#    'chebi:68688',
#    'chebi:68819',
#    'hmdb:HMDB0011688',
#    'hmdb:HMDB11688',
#    'keggC:C01151',
#    'sabiorkM:1470',
#    'seedM:cpd00847'],
#   'classification': 'mnx_superset_agreement'},
#  {'cluster': ['SLM:000658062'],
#   'present_in_dict': ['SLM:000658062'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM965677'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM965677',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM965677': ['SLM:000658062']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000658062'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['chebi:220580'],
#   'present_in_dict': ['chebi:220580'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM1402125'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM1402125',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM1402125': ['chebi:220580']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['chebi:220580'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000586824'],
#   'present_in_dict': ['SLM:000586824'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM895168'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM895168',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM895168': ['SLM:000586824']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000586824'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000571636'],
#   'present_in_dict': ['SLM:000571636'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM880657'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM880657',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM880657': ['SLM:000571636']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000571636'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['chebi:124608'],
#   'present_in_dict': ['chebi:124608'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM579466'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM579466',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM579466': ['chebi:124608']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['chebi:124608'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['chebi:124583'],
#   'present_in_dict': ['chebi:124583'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM577997'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM577997',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM577997': ['chebi:124583']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['chebi:124583'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['chebi:124427'],
#   'present_in_dict': ['chebi:124427'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM578650'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM578650',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM578650': ['chebi:124427']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['chebi:124427'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000006176'],
#   'present_in_dict': ['SLM:000006176'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM447728'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM447728',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM447728': ['SLM:000006176']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000006176'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['hmdb:HMDB0077047'],
#   'present_in_dict': ['hmdb:HMDB0077047'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM762006'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM762006',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 0.5,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM762006': ['hmdb:HMDB0077047',
#     'hmdb:HMDB77047']},
#   'mnx_minus_cluster': ['hmdb:HMDB77047'],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['hmdb:HMDB0077047', 'hmdb:HMDB77047'],
#   'classification': 'mnx_superset_agreement'},
#  {'cluster': ['SLM:000198371'],
#   'present_in_dict': ['SLM:000198371'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM382893'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM382893',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM382893': ['SLM:000198371']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000198371'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['hmdb:HMDB0193085'],
#   'present_in_dict': ['hmdb:HMDB0193085'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM1457164'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM1457164',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM1457164': ['hmdb:HMDB0193085']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['hmdb:HMDB0193085'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000044867'],
#   'present_in_dict': ['SLM:000044867'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM434437'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM434437',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM434437': ['SLM:000044867']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000044867'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['chebi:179970', 'lipidmapsM:LMFA07010342'],
#   'present_in_dict': ['chebi:179970', 'lipidmapsM:LMFA07010342'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM99369'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM99369',
#   'support_count': 2,
#   'cluster_size': 2,
#   'support_fraction': 1.0,
#   'overlap_size': 2,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM99369': ['chebi:179970',
#     'lipidmapsM:LMFA07010342']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['chebi:179970', 'lipidmapsM:LMFA07010342'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000195318'],
#   'present_in_dict': ['SLM:000195318'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM447870'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM447870',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM447870': ['SLM:000195318']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000195318'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000195436'],
#   'present_in_dict': ['SLM:000195436'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM310103'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM310103',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM310103': ['SLM:000195436']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000195436'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000687410'],
#   'present_in_dict': ['SLM:000687410'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM995024'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM995024',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM995024': ['SLM:000687410']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000687410'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000650520'],
#   'present_in_dict': ['SLM:000650520'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM958135'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM958135',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM958135': ['SLM:000650520']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000650520'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['chebi:200904'],
#   'present_in_dict': ['chebi:200904'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM1383215'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM1383215',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM1383215': ['chebi:200904']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['chebi:200904'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['chebi:53110'],
#   'present_in_dict': ['chebi:53110'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM37128'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM37128',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM37128': ['chebi:53110']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['chebi:53110'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['hmdb:HMDB0188781'],
#   'present_in_dict': ['hmdb:HMDB0188781'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM1452861'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM1452861',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM1452861': ['hmdb:HMDB0188781']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['hmdb:HMDB0188781'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000491033'],
#   'present_in_dict': ['SLM:000491033'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM203527'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM203527',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM203527': ['SLM:000491033']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000491033'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000646818'],
#   'present_in_dict': ['SLM:000646818'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM954433'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM954433',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM954433': ['SLM:000646818']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000646818'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000396055'],
#   'present_in_dict': ['SLM:000396055'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM572716'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM572716',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM572716': ['SLM:000396055']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000396055'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000511466'],
#   'present_in_dict': ['SLM:000511466'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM822316'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM822316',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM822316': ['SLM:000511466']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000511466'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['chebi:175328', 'hmdb:HMDB0034182'],
#   'present_in_dict': ['chebi:175328', 'hmdb:HMDB0034182'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM115773'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM115773',
#   'support_count': 2,
#   'cluster_size': 2,
#   'support_fraction': 1.0,
#   'overlap_size': 2,
#   'jaccard_cluster_vs_mnx': 0.6666666666666666,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM115773': ['chebi:175328',
#     'hmdb:HMDB0034182',
#     'hmdb:HMDB34182']},
#   'mnx_minus_cluster': ['hmdb:HMDB34182'],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['chebi:175328',
#    'hmdb:HMDB0034182',
#    'hmdb:HMDB34182'],
#   'classification': 'mnx_superset_agreement'},
#  {'cluster': ['SLM:000495730'],
#   'present_in_dict': ['SLM:000495730'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM226322'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM226322',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM226322': ['SLM:000495730']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000495730'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000274335'],
#   'present_in_dict': ['SLM:000274335'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM427748'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM427748',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM427748': ['SLM:000274335']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000274335'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000022773'],
#   'present_in_dict': ['SLM:000022773'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM240786'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM240786',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM240786': ['SLM:000022773']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000022773'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000134999'],
#   'present_in_dict': ['SLM:000134999'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM336918'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM336918',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM336918': ['SLM:000134999']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000134999'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000135021'],
#   'present_in_dict': ['SLM:000135021'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM279051'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM279051',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM279051': ['SLM:000135021']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000135021'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['hmdb:HMDB0244491'],
#   'present_in_dict': ['hmdb:HMDB0244491'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM477251'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM477251',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 0.3333333333333333,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM477251': ['chebi:95082',
#     'hmdb:HMDB0244491',
#     'keggD:D11326']},
#   'mnx_minus_cluster': ['chebi:95082', 'keggD:D11326'],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['chebi:95082',
#    'hmdb:HMDB0244491',
#    'keggD:D11326'],
#   'classification': 'mnx_superset_agreement'},
#  {'cluster': ['chebi:95082', 'keggD:D11326'],
#   'present_in_dict': ['chebi:95082', 'keggD:D11326'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM477251'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM477251',
#   'support_count': 2,
#   'cluster_size': 2,
#   'support_fraction': 1.0,
#   'overlap_size': 2,
#   'jaccard_cluster_vs_mnx': 0.6666666666666666,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM477251': ['chebi:95082',
#     'hmdb:HMDB0244491',
#     'keggD:D11326']},
#   'mnx_minus_cluster': ['hmdb:HMDB0244491'],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['chebi:95082',
#    'hmdb:HMDB0244491',
#    'keggD:D11326'],
#   'classification': 'mnx_superset_agreement'},
#  {'cluster': ['chebi:76212', 'hmdb:HMDB0259264'],
#   'present_in_dict': ['chebi:76212', 'hmdb:HMDB0259264'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM161930'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM161930',
#   'support_count': 2,
#   'cluster_size': 2,
#   'support_fraction': 1.0,
#   'overlap_size': 2,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM161930': ['chebi:76212',
#     'hmdb:HMDB0259264']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['chebi:76212', 'hmdb:HMDB0259264'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['hmdb:HMDB0293573'],
#   'present_in_dict': ['hmdb:HMDB0293573'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM1546729'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM1546729',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM1546729': ['hmdb:HMDB0293573']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['hmdb:HMDB0293573'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['lipidmapsM:LMPK12070088'],
#   'present_in_dict': ['lipidmapsM:LMPK12070088'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM39361'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM39361',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM39361': ['lipidmapsM:LMPK12070088']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['lipidmapsM:LMPK12070088'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['hmdb:HMDB0220063'],
#   'present_in_dict': ['hmdb:HMDB0220063'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM1484142'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM1484142',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM1484142': ['hmdb:HMDB0220063']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['hmdb:HMDB0220063'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000490537'],
#   'present_in_dict': ['SLM:000490537'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM251461'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM251461',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM251461': ['SLM:000490537']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000490537'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000232499'],
#   'present_in_dict': ['SLM:000232499'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM201845'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM201845',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM201845': ['SLM:000232499']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000232499'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['hmdb:HMDB0053324', 'SLM:000232367'],
#   'present_in_dict': ['SLM:000232367', 'hmdb:HMDB0053324'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM139671'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM139671',
#   'support_count': 2,
#   'cluster_size': 2,
#   'support_fraction': 1.0,
#   'overlap_size': 2,
#   'jaccard_cluster_vs_mnx': 0.6666666666666666,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM139671': ['SLM:000232367',
#     'hmdb:HMDB0053324',
#     'hmdb:HMDB53324']},
#   'mnx_minus_cluster': ['hmdb:HMDB53324'],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000232367',
#    'hmdb:HMDB0053324',
#    'hmdb:HMDB53324'],
#   'classification': 'mnx_superset_agreement'},
#  {'cluster': ['SLM:000212939'],
#   'present_in_dict': ['SLM:000212939'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM309961'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM309961',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM309961': ['SLM:000212939']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000212939'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000212673'],
#   'present_in_dict': ['SLM:000212673'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM320852'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM320852',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM320852': ['SLM:000212673']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000212673'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000265761'],
#   'present_in_dict': ['SLM:000265761'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM357218'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM357218',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM357218': ['SLM:000265761']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000265761'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000265848'],
#   'present_in_dict': ['SLM:000265848'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM367942'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM367942',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM367942': ['SLM:000265848']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000265848'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000772464'],
#   'present_in_dict': ['SLM:000772464'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM1079245'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM1079245',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM1079245': ['SLM:000772464']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000772464'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['chebi:85124', 'lipidmapsM:LMPK12112771'],
#   'present_in_dict': ['chebi:85124', 'lipidmapsM:LMPK12112771'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM80380'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM80380',
#   'support_count': 2,
#   'cluster_size': 2,
#   'support_fraction': 1.0,
#   'overlap_size': 2,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM80380': ['chebi:85124',
#     'lipidmapsM:LMPK12112771']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['chebi:85124', 'lipidmapsM:LMPK12112771'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['hmdb:HMDB0204518'],
#   'present_in_dict': ['hmdb:HMDB0204518'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM1468597'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM1468597',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM1468597': ['hmdb:HMDB0204518']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['hmdb:HMDB0204518'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['lipidmapsM:LMGL03012320', 'SLM:000243628'],
#   'present_in_dict': ['SLM:000243628', 'lipidmapsM:LMGL03012320'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM85962'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM85962',
#   'support_count': 2,
#   'cluster_size': 2,
#   'support_fraction': 1.0,
#   'overlap_size': 2,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM85962': ['SLM:000243628',
#     'lipidmapsM:LMGL03012320']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000243628', 'lipidmapsM:LMGL03012320'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['hmdb:HMDB0052723', 'SLM:000243469'],
#   'present_in_dict': ['SLM:000243469', 'hmdb:HMDB0052723'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM137295'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM137295',
#   'support_count': 2,
#   'cluster_size': 2,
#   'support_fraction': 1.0,
#   'overlap_size': 2,
#   'jaccard_cluster_vs_mnx': 0.6666666666666666,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM137295': ['SLM:000243469',
#     'hmdb:HMDB0052723',
#     'hmdb:HMDB52723']},
#   'mnx_minus_cluster': ['hmdb:HMDB52723'],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000243469',
#    'hmdb:HMDB0052723',
#    'hmdb:HMDB52723'],
#   'classification': 'mnx_superset_agreement'},
#  {'cluster': ['SLM:000051304'],
#   'present_in_dict': ['SLM:000051304'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM400930'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM400930',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM400930': ['SLM:000051304']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000051304'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['hmdb:HMDB0054752'],
#   'present_in_dict': ['hmdb:HMDB0054752'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM143057'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM143057',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 0.5,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM143057': ['hmdb:HMDB0054752',
#     'hmdb:HMDB54752']},
#   'mnx_minus_cluster': ['hmdb:HMDB54752'],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['hmdb:HMDB0054752', 'hmdb:HMDB54752'],
#   'classification': 'mnx_superset_agreement'},
#  {'cluster': ['SLM:000767278'],
#   'present_in_dict': ['SLM:000767278'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM1074097'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM1074097',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM1074097': ['SLM:000767278']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000767278'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['hmdb:HMDB0107668'],
#   'present_in_dict': ['hmdb:HMDB0107668'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM790672'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM790672',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM790672': ['hmdb:HMDB0107668']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['hmdb:HMDB0107668'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['hmdb:HMDB0105104'],
#   'present_in_dict': ['hmdb:HMDB0105104'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM788473'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM788473',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM788473': ['hmdb:HMDB0105104']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['hmdb:HMDB0105104'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000706426'],
#   'present_in_dict': ['SLM:000706426'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM1014037'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM1014037',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM1014037': ['SLM:000706426']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
# ...
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM246160': ['SLM:000016402']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000016402'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000519355'],
#   'present_in_dict': ['SLM:000519355'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM829764'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM829764',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM829764': ['SLM:000519355']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000519355'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000677104'],
#   'present_in_dict': ['SLM:000677104'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM984718'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM984718',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM984718': ['SLM:000677104']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000677104'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000180218'],
#   'present_in_dict': ['SLM:000180218'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM361280'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM361280',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM361280': ['SLM:000180218']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000180218'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000180482'],
#   'present_in_dict': ['SLM:000180482'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM459431'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM459431',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM459431': ['SLM:000180482']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000180482'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000449583'],
#   'present_in_dict': ['SLM:000449583'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM322731'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM322731',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM322731': ['SLM:000449583']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000449583'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['hmdb:HMDB0279373'],
#   'present_in_dict': ['hmdb:HMDB0279373'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM1532662'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM1532662',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM1532662': ['hmdb:HMDB0279373']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['hmdb:HMDB0279373'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000164512'],
#   'present_in_dict': ['SLM:000164512'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM423354'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM423354',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM423354': ['SLM:000164512']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000164512'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000502476'],
#   'present_in_dict': ['SLM:000502476'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM432984'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM432984',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM432984': ['SLM:000502476']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000502476'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000649142'],
#   'present_in_dict': ['SLM:000649142'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM956757'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM956757',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM956757': ['SLM:000649142']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000649142'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['hmdb:HMDB0214924'],
#   'present_in_dict': ['hmdb:HMDB0214924'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM1479003'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM1479003',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM1479003': ['hmdb:HMDB0214924']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['hmdb:HMDB0214924'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['chebi:142828'],
#   'present_in_dict': ['chebi:142828'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM746875'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM746875',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM746875': ['chebi:142828']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['chebi:142828'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000118431'],
#   'present_in_dict': ['SLM:000118431'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM368587'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM368587',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM368587': ['SLM:000118431']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000118431'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000118453'],
#   'present_in_dict': ['SLM:000118453'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM472521'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM472521',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM472521': ['SLM:000118453']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000118453'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000259475'],
#   'present_in_dict': ['SLM:000259475'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM415357'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM415357',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM415357': ['SLM:000259475']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000259475'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000252672'],
#   'present_in_dict': ['SLM:000252672'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM365749'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM365749',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM365749': ['SLM:000252672']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000252672'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000252894'],
#   'present_in_dict': ['SLM:000252894'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM268948'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM268948',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM268948': ['SLM:000252894']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000252894'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000530939'],
#   'present_in_dict': ['SLM:000530939'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM841116'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM841116',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM841116': ['SLM:000530939']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000530939'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000768307'],
#   'present_in_dict': ['SLM:000768307'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM1075126'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM1075126',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM1075126': ['SLM:000768307']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000768307'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['hmdb:HMDB0227765'],
#   'present_in_dict': ['hmdb:HMDB0227765'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM1491843'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM1491843',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM1491843': ['hmdb:HMDB0227765']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['hmdb:HMDB0227765'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000637686'],
#   'present_in_dict': ['SLM:000637686'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM945301'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM945301',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM945301': ['SLM:000637686']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000637686'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000130729'],
#   'present_in_dict': ['SLM:000130729'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM422986'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM422986',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM422986': ['SLM:000130729']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000130729'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000568778'],
#   'present_in_dict': ['SLM:000568778'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM877799'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM877799',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM877799': ['SLM:000568778']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000568778'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000460001'],
#   'present_in_dict': ['SLM:000460001'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM239515'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM239515',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM239515': ['SLM:000460001']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000460001'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000777091'],
#   'present_in_dict': ['SLM:000777091'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM1083811'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM1083811',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM1083811': ['SLM:000777091']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000777091'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['hmdb:HMDB0251794'],
#   'present_in_dict': ['hmdb:HMDB0251794'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM511756'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM511756',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM511756': ['hmdb:HMDB0251794']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['hmdb:HMDB0251794'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000242781'],
#   'present_in_dict': ['SLM:000242781'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM214178'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM214178',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM214178': ['SLM:000242781']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000242781'],
#   'classification': 'exact_agreement'},
#  {'cluster': ['SLM:000242660'],
#   'present_in_dict': ['SLM:000242660'],
#   'unmapped_in_dict': [],
#   'mnx_ids_hit': ['https://rdf.metanetx.org/chem/MNXM347998'],
#   'primary_mnx': 'https://rdf.metanetx.org/chem/MNXM347998',
#   'support_count': 1,
#   'cluster_size': 1,
#   'support_fraction': 1.0,
#   'overlap_size': 1,
#   'jaccard_cluster_vs_mnx': 1.0,
#   'related_labels_by_mnx': {'https://rdf.metanetx.org/chem/MNXM347998': ['SLM:000242660']},
#   'mnx_minus_cluster': [],
#   'cluster_minus_mnx': [],
#   'all_related_labels_union': ['SLM:000242660'],
#   'classification': 'exact_agreement'},
#  ...]

# %%
def _sets_from_row(r: Dict[str, Any]):
    C = set(r.get("cluster", []) or [])
    M = set(r.get("all_related_labels_union", []) or [])
    return C, M

def _tp_fp_fn(C, M):
    tp = len(C & M)
    fp = len(M - C)           # MNX extras (mnx_minus_cluster count)
    fn = len(C - M)           # cluster extras (cluster_minus_mnx count)
    return tp, fp, fn

def summarize_results(results: List[Dict[str, Any]]) -> Dict[str, Any]:
    """
    Works with rows shaped like your schema, e.g.:
      'cluster', 'present_in_dict', 'unmapped_in_dict', 'mnx_ids_hit', 'primary_mnx',
      'support_count', 'cluster_size', 'support_fraction', 'overlap_size',
      'jaccard_cluster_vs_mnx', 'related_labels_by_mnx',
      'mnx_minus_cluster', 'cluster_minus_mnx',
      'all_related_labels_union', 'classification'
    """
    # Per-row derived counts (kept separate; original rows untouched)
    derived = []
    for r in results:
        C, M = _sets_from_row(r)
        tp, fp, fn = _tp_fp_fn(C, M)

        # Use provided jaccard if present; else compute
        union = len(C | M)
        jacc = r.get("jaccard_cluster_vs_mnx")
        if jacc is None:
            jacc = (tp / union) if union else math.nan

        # For multi-MNX disagreements you may prefer to NaN scores; leaving as-is (union-based)
        purity_cluster = (tp / len(C)) if len(C) else math.nan
        coverage_mnx   = (tp / len(M)) if len(M) else math.nan
        f1 = (
            (2 * purity_cluster * coverage_mnx) / (purity_cluster + coverage_mnx)
            if all(x == x for x in (purity_cluster, coverage_mnx)) and (purity_cluster + coverage_mnx) > 0
            else math.nan
        )

        derived.append({
            "tp": tp, "fp": fp, "fn": fn,
            "jaccard": jacc,
            "purity_cluster": purity_cluster,
            "coverage_mnx": coverage_mnx,
            "f1": f1,
        })

    # Overview tallies
    by_class = Counter(r.get("classification", "unclassified") for r in results)

    # Micro (instance-level)
    tot_tp = sum(d["tp"] for d in derived)
    tot_fp = sum(d["fp"] for d in derived)
    tot_fn = sum(d["fn"] for d in derived)
    micro_purity   = tot_tp / (tot_tp + tot_fn) if (tot_tp + tot_fn) else math.nan   # |C∩M| / |C|
    micro_coverage = tot_tp / (tot_tp + tot_fp) if (tot_tp + tot_fp) else math.nan   # |C∩M| / |M|
    micro_f1 = (
        (2 * micro_purity * micro_coverage) / (micro_purity + micro_coverage)
        if all(x == x for x in (micro_purity, micro_coverage)) and (micro_purity + micro_coverage) > 0
        else math.nan
    )

    # Macro means (ignore NaN)
    def _mean(vs):
        vs = [v for v in vs if isinstance(v, (int, float)) and v == v]
        return sum(vs)/len(vs) if vs else math.nan

    macro_f1    = _mean([d["f1"] for d in derived])
    macro_jacc  = _mean([d["jaccard"] for d in derived])
    macro_purit = _mean([d["purity_cluster"] for d in derived])
    macro_cov   = _mean([d["coverage_mnx"] for d in derived])

    # Namespace-level disagreement totals (from the two diffs already in your schema)
    ns_fp_tot = defaultdict(int); ns_fn_tot = defaultdict(int)
    for r in results:
        for x in r.get("mnx_minus_cluster", []) or []:
            ns = x.split(":", 1)[0].lower() if ":" in x else ""
            ns_fp_tot[ns] += 1
        for x in r.get("cluster_minus_mnx", []) or []:
            ns = x.split(":", 1)[0].lower() if ":" in x else ""
            ns_fn_tot[ns] += 1
    fp_sum = sum(ns_fp_tot.values()) or 1
    fn_sum = sum(ns_fn_tot.values()) or 1
    fp_by_ns = {ns: {"count": c, "pct": c/fp_sum} for ns, c in sorted(ns_fp_tot.items(), key=lambda x: -x[1])}
    fn_by_ns = {ns: {"count": c, "pct": c/fn_sum} for ns, c in sorted(ns_fn_tot.items(), key=lambda x: -x[1])}

    # Worst offenders (by total disagreement size)
    disagreement_scores = [
        (i, derived[i]["fp"] + derived[i]["fn"]) for i in range(len(results))
    ]
    worst_idx = [i for i, _ in sorted(disagreement_scores, key=lambda t: -t[1])[:25]]
    worst = [results[i] | {"tp": derived[i]["tp"], "fp": derived[i]["fp"], "fn": derived[i]["fn"]} for i in worst_idx]

    # Flat DataFrame with ONLY your schema’s names (plus tp/fp/fn & derived scores for convenience)
    rows = []
    for r, d in zip(results, derived):
        rows.append({
            "cluster": "|".join(r.get("cluster", [])),
            "present_in_dict": "|".join(r.get("present_in_dict", [])),
            "unmapped_in_dict": "|".join(r.get("unmapped_in_dict", [])),
            "mnx_ids_hit": "|".join(r.get("mnx_ids_hit", [])),
            "primary_mnx": r.get("primary_mnx", ""),
            "classification": r.get("classification", "unclassified"),
            "support_count": r.get("support_count", math.nan),
            "cluster_size": r.get("cluster_size", math.nan),
            "support_fraction": r.get("support_fraction", math.nan),
            "overlap_size": r.get("overlap_size", math.nan),
            "jaccard_cluster_vs_mnx": r.get("jaccard_cluster_vs_mnx", d["jaccard"]),
            "mnx_minus_cluster": "|".join(r.get("mnx_minus_cluster", [])),
            "cluster_minus_mnx": "|".join(r.get("cluster_minus_mnx", [])),
            # helpful extras (keep names separate from your schema keys)
            "tp": d["tp"], "fp": d["fp"], "fn": d["fn"],
            "purity_cluster": d["purity_cluster"],
            "coverage_mnx": d["coverage_mnx"],
            "f1": d["f1"],
        })
    df = pd.DataFrame(rows)

    return {
        "overview": {
            "by_classification": dict(by_class),
            "micro": {"purity_cluster": micro_purity, "coverage_mnx": micro_coverage, "f1": micro_f1},
            "macro": {"purity_cluster": macro_purit, "coverage_mnx": macro_cov, "f1": macro_f1, "jaccard": macro_jacc},
            "totals": {"TP": tot_tp, "FP": tot_fp, "FN": tot_fn},
        },
        "namespace_disagreements": {"fp_by_ns": fp_by_ns, "fn_by_ns": fn_by_ns},
        "worst_offenders_top25": worst,
        "flat_df": df,
    }

# %%
summary = summarize_results(results)

df = summary["flat_df"]
df
# Out:
#                                         cluster  \
# 0                                 SLM:000736507
# 1                                 SLM:000496071
# 2                                 SLM:000491467
# 3                                 SLM:000512033
# 4       chebi:80858|keggC:C17009|seedM:cpd17277
# ...                                         ...
# 987921                              chebi:64493
# 987922               chebi:64514|seedM:cpd22804
# 987923                         hmdb:HMDB0243532
# 987924   chebi:3197|keggC:C08754|seedM:cpd05659
# 987925                            SLM:000719588
#
#                                 present_in_dict unmapped_in_dict  \
# 0                                 SLM:000736507
# 1                                 SLM:000496071
# 2                                 SLM:000491467
# 3                                 SLM:000512033
# 4       chebi:80858|keggC:C17009|seedM:cpd17277
# ...                                         ...              ...
# 987921                              chebi:64493
# 987922               chebi:64514|seedM:cpd22804
# 987923                         hmdb:HMDB0243532
# 987924   chebi:3197|keggC:C08754|seedM:cpd05659
# 987925                            SLM:000719588
#
#                                       mnx_ids_hit  \
# 0       https://rdf.metanetx.org/chem/MNXM1044118
# 1        https://rdf.metanetx.org/chem/MNXM446350
# 2        https://rdf.metanetx.org/chem/MNXM446347
# 3        https://rdf.metanetx.org/chem/MNXM822853
# 4         https://rdf.metanetx.org/chem/MNXM62681
# ...                                           ...
# 987921   https://rdf.metanetx.org/chem/MNXM725413
# 987922   https://rdf.metanetx.org/chem/MNXM725413
# 987923    https://rdf.metanetx.org/chem/MNXM44853
# 987924    https://rdf.metanetx.org/chem/MNXM44853
# 987925  https://rdf.metanetx.org/chem/MNXM1027199
#
#                                       primary_mnx          classification  \
# 0       https://rdf.metanetx.org/chem/MNXM1044118         exact_agreement
# 1        https://rdf.metanetx.org/chem/MNXM446350         exact_agreement
# 2        https://rdf.metanetx.org/chem/MNXM446347         exact_agreement
# 3        https://rdf.metanetx.org/chem/MNXM822853         exact_agreement
# 4         https://rdf.metanetx.org/chem/MNXM62681         exact_agreement
# ...                                           ...                     ...
# 987921   https://rdf.metanetx.org/chem/MNXM725413  mnx_superset_agreement
# 987922   https://rdf.metanetx.org/chem/MNXM725413  mnx_superset_agreement
# 987923    https://rdf.metanetx.org/chem/MNXM44853  mnx_superset_agreement
# 987924    https://rdf.metanetx.org/chem/MNXM44853  mnx_superset_agreement
# 987925  https://rdf.metanetx.org/chem/MNXM1027199         exact_agreement
#
#         support_count  cluster_size  support_fraction  overlap_size  \
# 0                   1             1               1.0             1
# 1                   1             1               1.0             1
# 2                   1             1               1.0             1
# 3                   1             1               1.0             1
# 4                   3             3               1.0             3
# ...               ...           ...               ...           ...
# 987921              1             1               1.0             1
# 987922              2             2               1.0             2
# 987923              1             1               1.0             1
# 987924              3             3               1.0             3
# 987925              1             1               1.0             1
#
#         jaccard_cluster_vs_mnx                       mnx_minus_cluster  \
# 0                     1.000000
# 1                     1.000000
# 2                     1.000000
# 3                     1.000000
# 4                     1.000000
# ...                        ...                                     ...
# 987921                0.333333              chebi:64514|seedM:cpd22804
# 987922                0.666667                             chebi:64493
# 987923                0.250000  chebi:3197|keggC:C08754|seedM:cpd05659
# 987924                0.750000                        hmdb:HMDB0243532
# 987925                1.000000
#
#        cluster_minus_mnx  tp  fp  fn  purity_cluster  coverage_mnx        f1
# 0                          1   0   0             1.0      1.000000  1.000000
# 1                          1   0   0             1.0      1.000000  1.000000
# 2                          1   0   0             1.0      1.000000  1.000000
# 3                          1   0   0             1.0      1.000000  1.000000
# 4                          3   0   0             1.0      1.000000  1.000000
# ...                  ...  ..  ..  ..             ...           ...       ...
# 987921                     1   2   0             1.0      0.333333  0.500000
# 987922                     2   1   0             1.0      0.666667  0.800000
# 987923                     1   3   0             1.0      0.250000  0.400000
# 987924                     3   1   0             1.0      0.750000  0.857143
# 987925                     1   0   0             1.0      1.000000  1.000000
#
# [987926 rows x 19 columns]

# %%
df.value_counts('classification')
# Out:
# classification
# exact_agreement             850733
# mnx_superset_agreement      134211
# mnx_id_disagreement           2073
# no_overlap_with_dict           617
# partial_overlap_unmapped       292
# Name: count, dtype: int64

# %% [markdown]
# Vast majority show an exact agreement, this is what we aimed for. 850 thousand show an exact agreement, indicating that both approaches give similar identity clusters in their outputs. 130 thousand are shown to be cases where MNX clusters contain more entries than those in the stereomapper cluster. There are many potential reasons for this. The primary reason is likely due to the presence of secondary identifiers from sources like CHEBI and HMDB, which cannot be handled trivially, introducing some inaccuracies. Another valid reason is that the stereomapper pipeline actually clustered the extra identifiers into another cluster (stored in 'mnx_id_disagreement') causing some of these superset disagreements. This is actually quite likely and inidcates the possible disagreements are actually higher than shown here. Follow up analysis will confirm this.

# %%
def detect_fragmentation(results: List[Dict[str, Any]]) -> Dict[str, Any]:
    """
    Post-pass audit over your schema to find MNX groups split across multiple clusters.

    Returns:
      {
        "mnx_to_clusters": {mnx_id: sorted(list_of_cluster_idxs)},
        "fragmented_mnx":  {mnx_id: {"num_clusters": k, "cluster_idxs": [...]}},
        "cluster_flags":   {cluster_idx: {"fragmented_for_primary_mnx": bool,
                                          "num_clusters_for_primary_mnx": int,
                                          "missing_members_in_other_clusters": sorted([...])}},
        "summary":         {"num_fragmented_mnx": int,
                            "num_clusters_flagged": int,
                            "mnx_superset_agreement_that_are_fragmented": int}
      }
    """
    # 1) Build label -> cluster_idx map
    label_to_cluster = {}
    for i, row in enumerate(results):
        for lbl in row.get("cluster", []):
            label_to_cluster[lbl] = i

    # 2) For each row with a single MNX id, get the MNX "ground-truth" set
    #    (from your row['related_labels_by_mnx'][mnx]) and see how many distinct
    #    clusters those labels are spread across.
    mnx_to_clusters = defaultdict(set)
    mnx_to_all_related = {}
    for i, row in enumerate(results):
        mnx_ids = row.get("mnx_ids_hit", []) or []
        if len(mnx_ids) != 1:
            continue
        mnx = mnx_ids[0]
        rel = set(row.get("related_labels_by_mnx", {}).get(mnx, []))
        if not rel:
            continue
        mnx_to_all_related[mnx] = rel  # they should all be identical across rows that hit this MNX
        for lbl in rel:
            if lbl in label_to_cluster:
                mnx_to_clusters[mnx].add(label_to_cluster[lbl])

    # 3) Fragmented MNX groups are those spanning >1 cluster
    fragmented_mnx = {
        mnx: {"num_clusters": len(idxs), "cluster_idxs": sorted(idxs)}
        for mnx, idxs in mnx_to_clusters.items() if len(idxs) > 1
    }

    # 4) Per-cluster flags: if row is mnx_superset_agreement (or exact/other),
    #    annotate whether its primary MNX is fragmented globally and which "extras"
    #    are actually located in other clusters.
    cluster_flags = {}
    fragmented_superset_count = 0
    for i, row in enumerate(results):
        mnx_ids = row.get("mnx_ids_hit", []) or []
        primary = row.get("primary_mnx") or (mnx_ids[0] if len(mnx_ids) == 1 else None)
        cluster_set = set(row.get("cluster", []))
        extras_mnx  = set(row.get("mnx_minus_cluster", []))  # MNX minus this cluster (already in your schema)

        fragmented = False
        num_clusters_for_primary = 1
        missing_members_in_other_clusters = []

        if primary and primary in fragmented_mnx:
            fragmented = True
            num_clusters_for_primary = fragmented_mnx[primary]["num_clusters"]
            # Which of this row's MNX-extras are sitting in other clusters?
            for lbl in extras_mnx:
                j = label_to_cluster.get(lbl)
                if j is not None and j != i:
                    missing_members_in_other_clusters.append(lbl)

        cluster_flags[i] = {
            "fragmented_for_primary_mnx": fragmented,
            "num_clusters_for_primary_mnx": num_clusters_for_primary,
            "missing_members_in_other_clusters": sorted(missing_members_in_other_clusters),
        }

        if fragmented and row.get("classification") == "mnx_superset_agreement":
            fragmented_superset_count += 1

    summary = {
        "num_fragmented_mnx": len(fragmented_mnx),
        "num_clusters_flagged": sum(1 for v in cluster_flags.values() if v["fragmented_for_primary_mnx"]),
        "mnx_superset_agreement_that_are_fragmented": fragmented_superset_count,
    }

    return {
        "mnx_to_clusters": {k: sorted(v) for k, v in mnx_to_clusters.items()},
        "fragmented_mnx": fragmented_mnx,
        "cluster_flags": cluster_flags,
        "summary": summary,
    }

# %%
frag = detect_fragmentation(results)

# %%
frag['summary']
# Out:
# {'num_fragmented_mnx': 29974,
#  'num_clusters_flagged': 62658,
#  'mnx_superset_agreement_that_are_fragmented': 62475}

# %% [markdown]
# Let's account for this rate of fragmentation in the initial output. This will give a more accurate overview of the similarities and differences in terms of mapping.

# %%
def derive_strict_view(results: List[Dict[str, Any]], frag: Dict[str, Any]):
    """
    Buckets rows into:
      - 'strict_agreement'                 : exact_agreement
      - 'strict_disagreement'              : mnx_id_disagreement OR stereomapper_superset_agreement
                                            OR (mnx_superset_agreement AND fragmented_for_primary_mnx)
      - 'mnx_superset_agreement_actual'    : mnx_superset_agreement AND NOT fragmented (MNX truly broader)
      - 'mapping_gap'                      : partial_overlap_unmapped OR no_overlap_with_dict
      - 'other'                            : anything else (should be tiny/none)

    Also returns a compact summary and convenience DataFrames.
    """
    # indices of clusters whose primary MNX is split across multiple stereomapper clusters
    fragmented_cluster_idxs = {
        i for i, v in frag.get("cluster_flags", {}).items() if v.get("fragmented_for_primary_mnx")
    }

    labeled_rows = []
    for i, r in enumerate(results):
        base = r.get("classification", "unclassified")

        if base == "exact_agreement":
            strict_bucket = "strict_agreement"
            reason = None

        elif base in ("partial_overlap_unmapped", "no_overlap_with_dict"):
            strict_bucket = "mapping_gap"
            reason = base

        elif base == "mnx_superset_agreement":
            if i in fragmented_cluster_idxs:
                strict_bucket = "strict_disagreement"
                reason = "masked_split_fragmentation"
            else:
                strict_bucket = "mnx_superset_agreement_actual"
                reason = None

        elif base in ("mnx_id_disagreement", "stereomapper_superset_agreement"):
            strict_bucket = "strict_disagreement"
            reason = base  # over-merge or multi-MNX

        else:
            strict_bucket = "other"
            reason = base

        labeled_rows.append({**r, "strict_bucket": strict_bucket, "strict_disagreement_reason": reason})

    # Build a flat DataFrame
    flat = []
    for r in labeled_rows:
        flat.append({
            "strict_bucket": r["strict_bucket"],
            "strict_disagreement_reason": r.get("strict_disagreement_reason"),
            "classification": r.get("classification"),
            "cluster": "|".join(r.get("cluster", [])),
            "mnx_ids_hit": "|".join(r.get("mnx_ids_hit", [])),
            "primary_mnx": r.get("primary_mnx", ""),
            "mnx_minus_cluster": "|".join(r.get("mnx_minus_cluster", [])),
            "cluster_minus_mnx": "|".join(r.get("cluster_minus_mnx", [])),
            "support_count": r.get("support_count"),
            "cluster_size": r.get("cluster_size"),
            "support_fraction": r.get("support_fraction"),
        })
    df = pd.DataFrame(flat)

    # Overall counts and percentages
    total = len(df) if not df.empty else 1
    counts = df["strict_bucket"].value_counts().to_dict()
    perc = {k: v/total for k, v in counts.items()}

    # Disagreement breakdown (reason-level)
    dis_df = df[df["strict_bucket"] == "strict_disagreement"]
    dis_counts = dis_df["strict_disagreement_reason"].fillna("unspecified").value_counts().to_dict()
    dis_perc = {k: v/len(dis_df) if len(dis_df) else 0.0 for k, v in dis_counts.items()}

    # Convenience slices
    views = {
        "strict_agreement_df": df[df["strict_bucket"] == "strict_agreement"].copy(),
        "strict_disagreement_df": dis_df.copy(),
        "mnx_superset_agreement_actual_df": df[df["strict_bucket"] == "mnx_superset_agreement_actual"].copy(),
        "mapping_gap_df": df[df["strict_bucket"] == "mapping_gap"].copy(),
        "other_df": df[df["strict_bucket"] == "other"].copy(),
        "all_df": df,
    }

    summary = {
        "counts": counts,
        "percentages": perc,
        "disagreement_breakdown_counts": dis_counts,
        "disagreement_breakdown_percentages": dis_perc,
        "total_rows": len(df),
    }

    return labeled_rows, summary, views

# %%
labelled_res, strict_summary, strict_views = derive_strict_view(results, frag)
strict_summary
# Out:
# {'counts': {'strict_agreement': 850733,
#   'mnx_superset_agreement_actual': 71736,
#   'strict_disagreement': 64548,
#   'mapping_gap': 909},
#  'percentages': {'strict_agreement': 0.8611302870862797,
#   'mnx_superset_agreement_actual': 0.07261272605438059,
#   'strict_disagreement': 0.06533687745843313,
#   'mapping_gap': 0.0009201094009065456},
#  'disagreement_breakdown_counts': {'masked_split_fragmentation': 62475,
#   'mnx_id_disagreement': 2073},
#  'disagreement_breakdown_percentages': {'masked_split_fragmentation': 0.967884365123629,
#   'mnx_id_disagreement': 0.03211563487637107},
#  'total_rows': 987926}

# %%
# replace category names for better readability
rename_map = {
    "strict_agreement": "Strict Agreement",
    "mnx_superset_agreement_actual": "ReconXKG Superset Agreement",
    "strict_disagreement": "Strict Disagreement",
    "mapping_gap": "Mapping Gap",
}

# rebuild both dicts with readable names
counts = {rename_map[k]: v for k, v in strict_summary['counts'].items() if k in rename_map}
percentages = {rename_map[k]: v for k, v in strict_summary['percentages'].items() if k in rename_map}


color_map = {
    "Strict Agreement": "#4daf4a",
    "ReconXKG Superset Agreement": "#4daf4a",
    "Strict Disagreement": "#e41a1c",
    "Mapping Gap": "#999999",
}

colors = [color_map.get(cat, "#808080") for cat in counts.keys()]

# --- Typography & figure defaults ---
plt.rcParams.update({
    "font.family": "sans-serif",
    "font.sans-serif": ["DejaVu Sans"],   # substitute with a journal-preferred font if needed
    "font.size": 14,
    "axes.titlesize": 16,
    "axes.labelsize": 14,
    "xtick.labelsize": 10,
    "ytick.labelsize": 10,
    "figure.dpi": 300,
    "pdf.fonttype": 42,                  # for editable text in vector outputs
    "ps.fonttype": 42,
})

legend_elements = [
    Patch(facecolor="#4daf4a", edgecolor='black', label='Agreement'),
    Patch(facecolor="#e41a1c", edgecolor='black', label='Disagreement'),
    Patch(facecolor="#999999", edgecolor='black', label='Mapping Gap')
]

# --- Build figure ---
fig = plt.figure(figsize=(10, 6))
ax = plt.gca()

x_labels = list(counts.keys())
x = np.arange(len(x_labels))
y = np.array(list(counts.values()))

# Bars (grayscale is safe for print; edge enhances clarity)
bars = ax.bar(x, y, color=colors, width=0.7, edgecolor="black")

# Title & axes
# ax.set_title("Agreement between StereoLynx and ReconXKG mapping assignments.")
ax.set_xlabel("Classification Type")
ax.set_ylabel("Number of Clusters")

# X tick labels
ax.set_xticks(x)
ax.set_xticklabels(x_labels, rotation=45, ha="right")

# set the legend 
ax.legend(handles=legend_elements, loc='upper right', fontsize=11, frameon=False, edgecolor='black', title=None)

# Add a little headroom for labels above bars
y_max = y.max() if len(y) else 1
ax.set_ylim(0, y_max * 1.12)

# Add percentage labels on each bar
for i, (cat, count) in enumerate(counts.items()):
    pct = percentages[cat] * 100
    ax.text(i, count + y_max * 0.01, f"{pct:.1f}%", ha='center',
             va='bottom', fontsize=11,
            fontweight="semibold")
    
# Gridlines to aid reading without clutter
ax.yaxis.grid(True, linestyle="--", linewidth=0.6, alpha=0.6)
ax.set_axisbelow(True)

fig.tight_layout()

plt.show()

# %%
rename_map = {
    "strict_agreement": "Matching clusters",
    "mnx_superset_agreement_actual": "Context-aware broader clusters",
    "strict_disagreement": "Different equivalence clusters",
    "mapping_gap": "Mapping Gap",
}

counts_all = {
    rename_map[k]: v
    for k, v in strict_summary["counts"].items()
    if k in rename_map
}

percentages_all = {
    rename_map[k]: v
    for k, v in strict_summary["percentages"].items()
    if k in rename_map
}

include_labels = [
    "Matching clusters",
    "Context-aware broader clusters",
    "Different equivalence clusters",
]

counts = {k: counts_all[k] for k in include_labels}
percentages = {k: percentages_all[k] for k in include_labels}

colour_map = {
    "Matching clusters": "#3f984f",
    "Context-aware broader clusters": "#7fc97f",
    "Different equivalence clusters": "#e31a1c",
}

labels = list(counts.keys())
sizes = np.array(list(counts.values()), dtype=float)
colours = [colour_map[cat] for cat in labels]

plt.rcParams.update({
    "font.family": "sans-serif",
    "font.sans-serif": ["DejaVu Sans"],
    "font.size": 12,
    "figure.dpi": 300,
    "pdf.fonttype": 42,
    "ps.fonttype": 42,
})

fig, ax = plt.subplots(figsize=(5, 5))

explode = [0.0, 0.0, 0.05]

def autopct_with_counts(pct):
    total = sizes.sum()
    count = int(round(pct / 100.0 * total))
    return f"{pct:.1f}%"

wedges, texts, autotexts = ax.pie(
    sizes,
    explode=explode,
    colors=colours,
    startangle=0,
    counterclock=False,
    autopct=autopct_with_counts,
    pctdistance=0.75,
    wedgeprops=dict(edgecolor="black", linewidth=1.0),
    textprops=dict(fontsize=10),
)

# Adjust Strict Agreement label as before
idx_sa = labels.index("Matching clusters")
w_sa = wedges[idx_sa]
t_sa = autotexts[idx_sa]

theta_mid = 0.5 * (w_sa.theta1 + w_sa.theta2)
theta_mid += 15
r = 0.4

x = r * np.cos(np.deg2rad(theta_mid))
y = r * np.sin(np.deg2rad(theta_mid))

t_sa.set_position((x, y))
t_sa.set_ha("center")
t_sa.set_va("center")

ax.set_aspect("equal")

ax.legend(
    wedges,
    labels,
    loc="lower center",
    bbox_to_anchor=(0.5, -0.15),  # same as pie 1
    ncol=1,
    frameon=False,
    fontsize=10,
)

# Same margins as pie 1
plt.subplots_adjust(left=0.15, right=0.85, top=0.95, bottom=0.25)

plt.show()

# %%
# DataFrames you can display/export
df_agree      = strict_views["strict_agreement_df"]
df_disagree   = strict_views["strict_disagreement_df"]
df_mnx_super  = strict_views["mnx_superset_agreement_actual_df"]
df_map_gap    = strict_views["mapping_gap_df"]
df_all        = strict_views["all_df"]

# %%
df_disagree
# Out:
#               strict_bucket  strict_disagreement_reason  \
# 6       strict_disagreement  masked_split_fragmentation
# 7       strict_disagreement  masked_split_fragmentation
# 14      strict_disagreement  masked_split_fragmentation
# 15      strict_disagreement  masked_split_fragmentation
# 16      strict_disagreement  masked_split_fragmentation
# ...                     ...                         ...
# 987910  strict_disagreement  masked_split_fragmentation
# 987921  strict_disagreement  masked_split_fragmentation
# 987922  strict_disagreement  masked_split_fragmentation
# 987923  strict_disagreement  masked_split_fragmentation
# 987924  strict_disagreement  masked_split_fragmentation
#
#                 classification                                    cluster  \
# 6       mnx_superset_agreement                    lipidmapsM:LMGP04010069
# 7       mnx_superset_agreement                              SLM:000042967
# 14      mnx_superset_agreement                              sabiorkM:1470
# 15      mnx_superset_agreement                                chebi:17994
# 16      mnx_superset_agreement  chebi:68819|hmdb:HMDB0011688|keggC:C01151
# ...                        ...                                        ...
# 987910  mnx_superset_agreement                                chebi:94378
# 987921  mnx_superset_agreement                                chebi:64493
# 987922  mnx_superset_agreement                 chebi:64514|seedM:cpd22804
# 987923  mnx_superset_agreement                           hmdb:HMDB0243532
# 987924  mnx_superset_agreement     chebi:3197|keggC:C08754|seedM:cpd05659
#
#                                       mnx_ids_hit  \
# 6         https://rdf.metanetx.org/chem/MNXM73492
# 7         https://rdf.metanetx.org/chem/MNXM73492
# 14      https://rdf.metanetx.org/chem/MNXM1584689
# 15      https://rdf.metanetx.org/chem/MNXM1584689
# 16      https://rdf.metanetx.org/chem/MNXM1584689
# ...                                           ...
# 987910   https://rdf.metanetx.org/chem/MNXM172519
# 987921   https://rdf.metanetx.org/chem/MNXM725413
# 987922   https://rdf.metanetx.org/chem/MNXM725413
# 987923    https://rdf.metanetx.org/chem/MNXM44853
# 987924    https://rdf.metanetx.org/chem/MNXM44853
#
#                                       primary_mnx  \
# 6         https://rdf.metanetx.org/chem/MNXM73492
# 7         https://rdf.metanetx.org/chem/MNXM73492
# 14      https://rdf.metanetx.org/chem/MNXM1584689
# 15      https://rdf.metanetx.org/chem/MNXM1584689
# 16      https://rdf.metanetx.org/chem/MNXM1584689
# ...                                           ...
# 987910   https://rdf.metanetx.org/chem/MNXM172519
# 987921   https://rdf.metanetx.org/chem/MNXM725413
# 987922   https://rdf.metanetx.org/chem/MNXM725413
# 987923    https://rdf.metanetx.org/chem/MNXM44853
# 987924    https://rdf.metanetx.org/chem/MNXM44853
#
#                                         mnx_minus_cluster cluster_minus_mnx  \
# 6                                           SLM:000042967
# 7                                 lipidmapsM:LMGP04010069
# 14      chebi:13012|chebi:17994|chebi:21079|chebi:4234...
# 15      chebi:13012|chebi:21079|chebi:4234|chebi:58345...
# 16      chebi:13012|chebi:17994|chebi:21079|chebi:4234...
# ...                                                   ...               ...
# 987910                                   hmdb:HMDB0248915
# 987921                         chebi:64514|seedM:cpd22804
# 987922                                        chebi:64493
# 987923             chebi:3197|keggC:C08754|seedM:cpd05659
# 987924                                   hmdb:HMDB0243532
#
#         support_count  cluster_size  support_fraction
# 6                   1             1               1.0
# 7                   1             1               1.0
# 14                  1             1               1.0
# 15                  1             1               1.0
# 16                  3             3               1.0
# ...               ...           ...               ...
# 987910              1             1               1.0
# 987921              1             1               1.0
# 987922              2             2               1.0
# 987923              1             1               1.0
# 987924              3             3               1.0
#
# [64548 rows x 11 columns]

# %% [markdown]
# Now lets get the reason for disagreement in each. Fit into the classes from stereomapper. This will give an indication as to the most common difference causing the disagreements in mapping. The most efficient method to give a good estimate of the reasons, is to generate inchikeys for each cluster, and mnx_minus_cluster and compare them. We could potentially use the relationships table, but it would be difficult as some of the identifiers in mnx_minus_cluster can still be secondary identifiers, causing potential errors. It also may take quite a while to run stereomapper over these again.

# %%
# open new connecton to the sqlite db
conn = sqlite3.connect(db_path)
# lets get the relationships table
query = "SELECT * FROM relationships;"
df_rels = pd.read_sql_query(query, conn)
df_rels.head()
# Out:
#    cluster_a  cluster_b           cluster_a_members      cluster_b_members  \
# 0          2          3          ["slm:SLM:496071"]     ["slm:SLM:491467"]
# 1          7          8  ["lipidmaps:LMGP04010069"]     ["slm:SLM:042967"]
# 2         11         12          ["slm:SLM:213588"]     ["slm:SLM:213725"]
# 3         13         14          ["slm:SLM:452819"]     ["slm:SLM:433625"]
# 4         15         16      ["local:sabiork_1470"]  ["chebi:CHEBI:17994"]
#
#    cluster_a_size  cluster_b_size classification  score  \
# 0               1               1  Diastereomers  100.0
# 1               1               1      Protomers   95.0
# 2               1               1    Enantiomers  100.0
# 3               1               1  Diastereomers  100.0
# 4               1               1   Parent-child  100.0
#
#                score_details extra_info version_tag
# 0  {"confidence_bin":"high"}       None        v1.0
# 1  {"confidence_bin":"high"}       None        v1.0
# 2  {"confidence_bin":"high"}       None        v1.0
# 3  {"confidence_bin":"high"}       None        v1.0
# 4  {"confidence_bin":"high"}       None        v1.0

# %%
# replace 'Planar vs stereo defined structures' with 'Parent-child' for consistency with manuscript
df_rels['classification'] = df_rels['classification'].replace({'Planar vs stereo defined structures': 'Parent-child'})
df_rels
# Out:
#         cluster_a  cluster_b  \
# 0               2          3
# 1               7          8
# 2              11         12
# 3              13         14
# 4              15         16
# ...           ...        ...
# 339453     987901     987902
# 339454     987905     987906
# 339455     987910     987911
# 339456     987922     987923
# 339457     987924     987925
#
#                                         cluster_a_members  \
# 0                                      ["slm:SLM:496071"]
# 1                              ["lipidmaps:LMGP04010069"]
# 2                                      ["slm:SLM:213588"]
# 3                                      ["slm:SLM:452819"]
# 4                                  ["local:sabiork_1470"]
# ...                                                   ...
# 339453  ["chebi:CHEBI:8342", "hmdb:HMDB0304685", "kegg...
# 339454       ["lipidmaps:LMGL03012341", "slm:SLM:263813"]
# 339455                               ["hmdb:HMDB0248915"]
# 339456                              ["chebi:CHEBI:64493"]
# 339457                               ["hmdb:HMDB0243532"]
#
#                                         cluster_b_members  cluster_a_size  \
# 0                                      ["slm:SLM:491467"]               1
# 1                                      ["slm:SLM:042967"]               1
# 2                                      ["slm:SLM:213725"]               1
# 3                                      ["slm:SLM:433625"]               1
# 4                                   ["chebi:CHEBI:17994"]               1
# ...                                                   ...             ...
# 339453                             ["modelseed:cpd05473"]               3
# 339454                                 ["slm:SLM:263829"]               2
# 339455                              ["chebi:CHEBI:94378"]               1
# 339456        ["chebi:CHEBI:64514", "modelseed:cpd22804"]               1
# 339457  ["chebi:CHEBI:3197", "kegg.compound:C08754", "...               1
#
#         cluster_b_size classification  score                score_details  \
# 0                    1  Diastereomers  100.0    {"confidence_bin":"high"}
# 1                    1      Protomers   95.0    {"confidence_bin":"high"}
# 2                    1    Enantiomers  100.0    {"confidence_bin":"high"}
# 3                    1  Diastereomers  100.0    {"confidence_bin":"high"}
# 4                    1   Parent-child  100.0    {"confidence_bin":"high"}
# ...                ...            ...    ...                          ...
# 339453               1      Protomers   81.0  {"confidence_bin":"medium"}
# 339454               1    Enantiomers  100.0    {"confidence_bin":"high"}
# 339455               1   Parent-child  100.0    {"confidence_bin":"high"}
# 339456               2      Protomers   95.0    {"confidence_bin":"high"}
# 339457               3   Parent-child  100.0    {"confidence_bin":"high"}
#
#        extra_info version_tag
# 0            None        v1.0
# 1            None        v1.0
# 2            None        v1.0
# 3            None        v1.0
# 4            None        v1.0
# ...           ...         ...
# 339453       None        v1.0
# 339454       None        v1.0
# 339455       None        v1.0
# 339456       None        v1.0
# 339457       None        v1.0
#
# [339458 rows x 11 columns]

# %%
# need to do the same cleaning as before
df_rels['cluster_a_members'] = df_rels['cluster_a_members'].apply(json.loads)
df_rels['cluster_b_members'] = df_rels['cluster_b_members'].apply(json.loads)

# now clean them 
df_rels['cleaned_cluster_a'] = df_rels['cluster_a_members'].apply(lambda members: [clean_member_id(m) for m in members])
df_rels['cleaned_cluster_b'] = df_rels['cluster_b_members'].apply(lambda members: [clean_member_id(m) for m in members])
# drop the old columns
df_rels = df_rels.drop(columns=['cluster_a_members', 'cluster_b_members'])
df_rels.head()
# Out:
#    cluster_a  cluster_b  cluster_a_size  cluster_b_size classification  score  \
# 0          2          3               1               1  Diastereomers  100.0
# 1          7          8               1               1      Protomers   95.0
# 2         11         12               1               1    Enantiomers  100.0
# 3         13         14               1               1  Diastereomers  100.0
# 4         15         16               1               1   Parent-child  100.0
#
#                score_details extra_info version_tag  \
# 0  {"confidence_bin":"high"}       None        v1.0
# 1  {"confidence_bin":"high"}       None        v1.0
# 2  {"confidence_bin":"high"}       None        v1.0
# 3  {"confidence_bin":"high"}       None        v1.0
# 4  {"confidence_bin":"high"}       None        v1.0
#
#            cleaned_cluster_a cleaned_cluster_b
# 0               [SLM:496071]      [SLM:491467]
# 1  [lipidmapsM:LMGP04010069]      [SLM:042967]
# 2               [SLM:213588]      [SLM:213725]
# 3               [SLM:452819]      [SLM:433625]
# 4       [local:sabiork_1470]     [chebi:17994]

# %%
# now replace the local prefixes
df_rels['final_cluster_a'] = df_rels['cleaned_cluster_a'].apply(lambda members: [replace_local_prefix(m) for m in members])
df_rels['final_cluster_b'] = df_rels['cleaned_cluster_b'].apply(lambda members: [replace_local_prefix(m) for m in members])
# drop the cleaned columns
df_rels = df_rels.drop(columns=['cleaned_cluster_a', 'cleaned_cluster_b'])
df_rels.head()
# Out:
#    cluster_a  cluster_b  cluster_a_size  cluster_b_size classification  score  \
# 0          2          3               1               1  Diastereomers  100.0
# 1          7          8               1               1      Protomers   95.0
# 2         11         12               1               1    Enantiomers  100.0
# 3         13         14               1               1  Diastereomers  100.0
# 4         15         16               1               1   Parent-child  100.0
#
#                score_details extra_info version_tag  \
# 0  {"confidence_bin":"high"}       None        v1.0
# 1  {"confidence_bin":"high"}       None        v1.0
# 2  {"confidence_bin":"high"}       None        v1.0
# 3  {"confidence_bin":"high"}       None        v1.0
# 4  {"confidence_bin":"high"}       None        v1.0
#
#              final_cluster_a final_cluster_b
# 0               [SLM:496071]    [SLM:491467]
# 1  [lipidmapsM:LMGP04010069]    [SLM:042967]
# 2               [SLM:213588]    [SLM:213725]
# 3               [SLM:452819]    [SLM:433625]
# 4            [sabiorkM:1470]   [chebi:17994]

# %%
# finally, fix the SLM ids
df_rels['final_cluster_a'] = df_rels['final_cluster_a'].apply(lambda members: [fix_slm_id(m) for m in members])
df_rels['final_cluster_b'] = df_rels['final_cluster_b'].apply(lambda members: [fix_slm_id(m) for m in members])
df_rels.head(20)
# Out:
#     cluster_a  cluster_b  cluster_a_size  cluster_b_size classification  \
# 0           2          3               1               1  Diastereomers
# 1           7          8               1               1      Protomers
# 2          11         12               1               1    Enantiomers
# 3          13         14               1               1  Diastereomers
# 4          15         16               1               1   Parent-child
# 5          15         17               1               3   Parent-child
# 6          15         18               1               1      Protomers
# 7          15         19               1               1   Unclassified
# 8          15         20               1               2   Unclassified
# 9          16         17               1               3   Parent-child
# 10         16         18               1               1   Unclassified
# 11         16         19               1               1      Protomers
# 12         16         20               1               2   Unclassified
# 13         17         18               3               1   Unclassified
# 14         17         19               3               1   Unclassified
# 15         17         20               3               2      Protomers
# 16         18         19               1               1   Parent-child
# 17         18         20               1               2   Parent-child
# 18         19         20               1               2   Parent-child
# 19         25         26               1               1  Diastereomers
#
#     score              score_details  \
# 0   100.0  {"confidence_bin":"high"}
# 1    95.0  {"confidence_bin":"high"}
# 2   100.0  {"confidence_bin":"high"}
# 3   100.0  {"confidence_bin":"high"}
# 4   100.0  {"confidence_bin":"high"}
# 5   100.0  {"confidence_bin":"high"}
# 6    91.0  {"confidence_bin":"high"}
# 7     NaN    {"confidence_bin":null}
# 8     NaN    {"confidence_bin":null}
# 9   100.0  {"confidence_bin":"high"}
# 10    NaN    {"confidence_bin":null}
# 11   91.0  {"confidence_bin":"high"}
# 12    NaN    {"confidence_bin":null}
# 13    NaN    {"confidence_bin":null}
# 14    NaN    {"confidence_bin":null}
# 15   91.0  {"confidence_bin":"high"}
# 16  100.0  {"confidence_bin":"high"}
# 17  100.0  {"confidence_bin":"high"}
# 18  100.0  {"confidence_bin":"high"}
# 19  100.0  {"confidence_bin":"high"}
#
#                                            extra_info version_tag  \
# 0                                                None        v1.0
# 1                                                None        v1.0
# 2                                                None        v1.0
# 3                                                None        v1.0
# 4                                                None        v1.0
# 5                                                None        v1.0
# 6                                                None        v1.0
# 7   Parent-child stereochemical relationships must...        v1.0
# 8   Parent-child stereochemical relationships must...        v1.0
# 9                                                None        v1.0
# 10  Parent-child stereochemical relationships must...        v1.0
# 11                                               None        v1.0
# 12  Parent-child stereochemical relationships must...        v1.0
# 13  Parent-child stereochemical relationships must...        v1.0
# 14  Parent-child stereochemical relationships must...        v1.0
# 15                                               None        v1.0
# 16                                               None        v1.0
# 17                                               None        v1.0
# 18                                               None        v1.0
# 19                                               None        v1.0
#
#                                   final_cluster_a  \
# 0                                 [SLM:000496071]
# 1                       [lipidmapsM:LMGP04010069]
# 2                                 [SLM:000213588]
# 3                                 [SLM:000452819]
# 4                                 [sabiorkM:1470]
# 5                                 [sabiorkM:1470]
# 6                                 [sabiorkM:1470]
# 7                                 [sabiorkM:1470]
# 8                                 [sabiorkM:1470]
# 9                                   [chebi:17994]
# 10                                  [chebi:17994]
# 11                                  [chebi:17994]
# 12                                  [chebi:17994]
# 13  [chebi:68819, hmdb:HMDB0011688, keggC:C01151]
# 14  [chebi:68819, hmdb:HMDB0011688, keggC:C01151]
# 15  [chebi:68819, hmdb:HMDB0011688, keggC:C01151]
# 16                                   [vmhM:r15bp]
# 17                                   [vmhM:r15bp]
# 18                                  [chebi:58345]
# 19                                 [chebi:124608]
#
#                                   final_cluster_b
# 0                                 [SLM:000491467]
# 1                                 [SLM:000042967]
# 2                                 [SLM:000213725]
# 3                                 [SLM:000433625]
# 4                                   [chebi:17994]
# 5   [chebi:68819, hmdb:HMDB0011688, keggC:C01151]
# 6                                    [vmhM:r15bp]
# 7                                   [chebi:58345]
# 8                   [chebi:68688, seedM:cpd00847]
# 9   [chebi:68819, hmdb:HMDB0011688, keggC:C01151]
# 10                                   [vmhM:r15bp]
# 11                                  [chebi:58345]
# 12                  [chebi:68688, seedM:cpd00847]
# 13                                   [vmhM:r15bp]
# 14                                  [chebi:58345]
# 15                  [chebi:68688, seedM:cpd00847]
# 16                                  [chebi:58345]
# 17                  [chebi:68688, seedM:cpd00847]
# 18                  [chebi:68688, seedM:cpd00847]
# 19                                 [chebi:124583]

# %% [markdown]
# Now that we have the identifiers for each cluster in the correct format, lets extract only the variables we need to avoid confusion.

# %%
df_req = df_rels[['final_cluster_a', 'final_cluster_b', 'classification', 'extra_info']]
df_req.head(20)
# Out:
#                                   final_cluster_a  \
# 0                                 [SLM:000496071]
# 1                       [lipidmapsM:LMGP04010069]
# 2                                 [SLM:000213588]
# 3                                 [SLM:000452819]
# 4                                 [sabiorkM:1470]
# 5                                 [sabiorkM:1470]
# 6                                 [sabiorkM:1470]
# 7                                 [sabiorkM:1470]
# 8                                 [sabiorkM:1470]
# 9                                   [chebi:17994]
# 10                                  [chebi:17994]
# 11                                  [chebi:17994]
# 12                                  [chebi:17994]
# 13  [chebi:68819, hmdb:HMDB0011688, keggC:C01151]
# 14  [chebi:68819, hmdb:HMDB0011688, keggC:C01151]
# 15  [chebi:68819, hmdb:HMDB0011688, keggC:C01151]
# 16                                   [vmhM:r15bp]
# 17                                   [vmhM:r15bp]
# 18                                  [chebi:58345]
# 19                                 [chebi:124608]
#
#                                   final_cluster_b classification  \
# 0                                 [SLM:000491467]  Diastereomers
# 1                                 [SLM:000042967]      Protomers
# 2                                 [SLM:000213725]    Enantiomers
# 3                                 [SLM:000433625]  Diastereomers
# 4                                   [chebi:17994]   Parent-child
# 5   [chebi:68819, hmdb:HMDB0011688, keggC:C01151]   Parent-child
# 6                                    [vmhM:r15bp]      Protomers
# 7                                   [chebi:58345]   Unclassified
# 8                   [chebi:68688, seedM:cpd00847]   Unclassified
# 9   [chebi:68819, hmdb:HMDB0011688, keggC:C01151]   Parent-child
# 10                                   [vmhM:r15bp]   Unclassified
# 11                                  [chebi:58345]      Protomers
# 12                  [chebi:68688, seedM:cpd00847]   Unclassified
# 13                                   [vmhM:r15bp]   Unclassified
# 14                                  [chebi:58345]   Unclassified
# 15                  [chebi:68688, seedM:cpd00847]      Protomers
# 16                                  [chebi:58345]   Parent-child
# 17                  [chebi:68688, seedM:cpd00847]   Parent-child
# 18                  [chebi:68688, seedM:cpd00847]   Parent-child
# 19                                 [chebi:124583]  Diastereomers
#
#                                            extra_info
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7   Parent-child stereochemical relationships must...
# 8   Parent-child stereochemical relationships must...
# 9                                                None
# 10  Parent-child stereochemical relationships must...
# 11                                               None
# 12  Parent-child stereochemical relationships must...
# 13  Parent-child stereochemical relationships must...
# 14  Parent-child stereochemical relationships must...
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None

# %%
df_req['classification'] = df_req['classification'].replace({'Parent-child': 'Stereo-resolution pairs'})
df_req
# Out:
# /tmp/ipykernel_150171/2139423580.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_req['classification'] = df_req['classification'].replace({'Parent-child': 'Stereo-resolution pairs'})
#                                      final_cluster_a  \
# 0                                    [SLM:000496071]
# 1                          [lipidmapsM:LMGP04010069]
# 2                                    [SLM:000213588]
# 3                                    [SLM:000452819]
# 4                                    [sabiorkM:1470]
# ...                                              ...
# 339453  [chebi:8342, hmdb:HMDB0304685, keggC:C08566]
# 339454      [lipidmapsM:LMGL03012341, SLM:000263813]
# 339455                            [hmdb:HMDB0248915]
# 339456                                 [chebi:64493]
# 339457                            [hmdb:HMDB0243532]
#
#                                    final_cluster_b           classification  \
# 0                                  [SLM:000491467]            Diastereomers
# 1                                  [SLM:000042967]                Protomers
# 2                                  [SLM:000213725]              Enantiomers
# 3                                  [SLM:000433625]            Diastereomers
# 4                                    [chebi:17994]  Stereo-resolution pairs
# ...                                            ...                      ...
# 339453                            [seedM:cpd05473]                Protomers
# 339454                             [SLM:000263829]              Enantiomers
# 339455                               [chebi:94378]  Stereo-resolution pairs
# 339456               [chebi:64514, seedM:cpd22804]                Protomers
# 339457  [chebi:3197, keggC:C08754, seedM:cpd05659]  Stereo-resolution pairs
#
#        extra_info
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None
# ...           ...
# 339453       None
# 339454       None
# 339455       None
# 339456       None
# 339457       None
#
# [339458 rows x 4 columns]

# %%
def _to_set(val):
    """Accept list or 'a|b|c' string → set of non-empty, stripped tokens."""
    if isinstance(val, list):
        return set(val)
    if pd.isna(val):
        return set()
    return set(t.strip() for t in str(val).split("|") if t.strip())

def _canon(s):
    """Canonical key for a cluster set: frozenset of labels."""
    return frozenset(s)

def _pair_key(a_set, b_set):
    """Unordered pair key: frozenset of the two canonical sets."""
    return frozenset(( _canon(a_set), _canon(b_set) ))

def assign_relationships(df_disagree: pd.DataFrame, df_rels: pd.DataFrame) -> pd.DataFrame:
    """
    df_rels must have columns:
      - final_cluster_a (list or 'a|b|c')
      - final_cluster_b (list or 'a|b|c')
      - classification (string, e.g., 'Protomers')
      - extra_info (string)

    df_disagree must have columns:
      - cluster (list or 'a|b|c')
      - mnx_minus_cluster (list or 'a|b|c')  # may NOT correspond to any stereomapper cluster
    """
    df_out = df_disagree.copy()
    df_out["relationship"] = pd.NA
    df_out["rel_reason"] = pd.NA  # small breadcrumb for why it failed
    df_out["extra_info"] = pd.NA  # new column to carry through extra_info from df_rels

    # 1) Build lookup of known stereomapper clusters from df_rels
    #    (so we only assign when mnx_minus_cluster matches an actual cluster)
    rel_rows = df_rels.copy()

    # Normalize sides A/B to sets
    rel_rows["_A"] = rel_rows["final_cluster_a"].apply(_to_set)
    rel_rows["_B"] = rel_rows["final_cluster_b"].apply(_to_set)

    # add in extra_info if needed later
    rel_rows["_extra"] = rel_rows["extra_info"]

    # Map each known cluster set → a canonical handle (its frozenset)
    known_clusters = set()
    for s in pd.concat([rel_rows["_A"], rel_rows["_B"]]):
        known_clusters.add(_canon(s))

    # 2) Build pair → (classification, extra_info) index (unordered)
    pair_to_meta = {}
    for _, r in rel_rows.iterrows():
        a_set, b_set = r["_A"], r["_B"]
        key = _pair_key(a_set, b_set)
        pair_to_meta[key] = (r["classification"], r["_extra"])

    # 3) Iterate df_disagree rows and try an exact mapping
    for idx, row in df_out.iterrows():
        c_set = _to_set(row["cluster"])
        d_set = _to_set(row["mnx_minus_cluster"])

        if not c_set:
            df_out.at[idx, "rel_reason"] = "empty_cluster"
            continue
        if not d_set:
            # nothing on the other side → cannot map to a relationship
            df_out.at[idx, "rel_reason"] = "mnx_minus_empty_or_unusable"
            continue

        c_key = _canon(c_set)
        d_key = _canon(d_set)

        # Only proceed if both sides are **known stereomapper clusters** (exact match)
        if c_key not in known_clusters:
            df_out.at[idx, "rel_reason"] = "cluster_not_in_known_pairs"
            continue
        if d_key not in known_clusters:
            df_out.at[idx, "rel_reason"] = "mnx_minus_not_a_known_cluster"
            continue

        key = frozenset((c_key, d_key))
        meta = pair_to_meta.get(key)
        if meta is not None:
            cls, extra = meta
            df_out.at[idx, "relationship"] = cls
            df_out.at[idx, "extra_info"] = extra
            df_out.at[idx, "rel_reason"] = "exact_pair_match"
        else:
            df_out.at[idx, "rel_reason"] = "pair_not_in_rels"

    return df_out

# %%
df_disagree_with_rels = assign_relationships(df_disagree, df_req)

# %%
df_disagree_with_rels
# Out:
#               strict_bucket  strict_disagreement_reason  \
# 6       strict_disagreement  masked_split_fragmentation
# 7       strict_disagreement  masked_split_fragmentation
# 14      strict_disagreement  masked_split_fragmentation
# 15      strict_disagreement  masked_split_fragmentation
# 16      strict_disagreement  masked_split_fragmentation
# ...                     ...                         ...
# 987910  strict_disagreement  masked_split_fragmentation
# 987921  strict_disagreement  masked_split_fragmentation
# 987922  strict_disagreement  masked_split_fragmentation
# 987923  strict_disagreement  masked_split_fragmentation
# 987924  strict_disagreement  masked_split_fragmentation
#
#                 classification                                    cluster  \
# 6       mnx_superset_agreement                    lipidmapsM:LMGP04010069
# 7       mnx_superset_agreement                              SLM:000042967
# 14      mnx_superset_agreement                              sabiorkM:1470
# 15      mnx_superset_agreement                                chebi:17994
# 16      mnx_superset_agreement  chebi:68819|hmdb:HMDB0011688|keggC:C01151
# ...                        ...                                        ...
# 987910  mnx_superset_agreement                                chebi:94378
# 987921  mnx_superset_agreement                                chebi:64493
# 987922  mnx_superset_agreement                 chebi:64514|seedM:cpd22804
# 987923  mnx_superset_agreement                           hmdb:HMDB0243532
# 987924  mnx_superset_agreement     chebi:3197|keggC:C08754|seedM:cpd05659
#
#                                       mnx_ids_hit  \
# 6         https://rdf.metanetx.org/chem/MNXM73492
# 7         https://rdf.metanetx.org/chem/MNXM73492
# 14      https://rdf.metanetx.org/chem/MNXM1584689
# 15      https://rdf.metanetx.org/chem/MNXM1584689
# 16      https://rdf.metanetx.org/chem/MNXM1584689
# ...                                           ...
# 987910   https://rdf.metanetx.org/chem/MNXM172519
# 987921   https://rdf.metanetx.org/chem/MNXM725413
# 987922   https://rdf.metanetx.org/chem/MNXM725413
# 987923    https://rdf.metanetx.org/chem/MNXM44853
# 987924    https://rdf.metanetx.org/chem/MNXM44853
#
#                                       primary_mnx  \
# 6         https://rdf.metanetx.org/chem/MNXM73492
# 7         https://rdf.metanetx.org/chem/MNXM73492
# 14      https://rdf.metanetx.org/chem/MNXM1584689
# 15      https://rdf.metanetx.org/chem/MNXM1584689
# 16      https://rdf.metanetx.org/chem/MNXM1584689
# ...                                           ...
# 987910   https://rdf.metanetx.org/chem/MNXM172519
# 987921   https://rdf.metanetx.org/chem/MNXM725413
# 987922   https://rdf.metanetx.org/chem/MNXM725413
# 987923    https://rdf.metanetx.org/chem/MNXM44853
# 987924    https://rdf.metanetx.org/chem/MNXM44853
#
#                                         mnx_minus_cluster cluster_minus_mnx  \
# 6                                           SLM:000042967
# 7                                 lipidmapsM:LMGP04010069
# 14      chebi:13012|chebi:17994|chebi:21079|chebi:4234...
# 15      chebi:13012|chebi:21079|chebi:4234|chebi:58345...
# 16      chebi:13012|chebi:17994|chebi:21079|chebi:4234...
# ...                                                   ...               ...
# 987910                                   hmdb:HMDB0248915
# 987921                         chebi:64514|seedM:cpd22804
# 987922                                        chebi:64493
# 987923             chebi:3197|keggC:C08754|seedM:cpd05659
# 987924                                   hmdb:HMDB0243532
#
#         support_count  cluster_size  support_fraction  \
# 6                   1             1               1.0
# 7                   1             1               1.0
# 14                  1             1               1.0
# 15                  1             1               1.0
# 16                  3             3               1.0
# ...               ...           ...               ...
# 987910              1             1               1.0
# 987921              1             1               1.0
# 987922              2             2               1.0
# 987923              1             1               1.0
# 987924              3             3               1.0
#
#                    relationship                     rel_reason extra_info
# 6                     Protomers               exact_pair_match       None
# 7                     Protomers               exact_pair_match       None
# 14                         <NA>  mnx_minus_not_a_known_cluster       <NA>
# 15                         <NA>  mnx_minus_not_a_known_cluster       <NA>
# 16                         <NA>  mnx_minus_not_a_known_cluster       <NA>
# ...                         ...                            ...        ...
# 987910  Stereo-resolution pairs               exact_pair_match       None
# 987921                Protomers               exact_pair_match       None
# 987922                Protomers               exact_pair_match       None
# 987923  Stereo-resolution pairs               exact_pair_match       None
# 987924  Stereo-resolution pairs               exact_pair_match       None
#
# [64548 rows x 14 columns]

# %%
df_disagree_with_rels['relationship'].value_counts(dropna=False)
# Out:
# relationship
# <NA>                       32082
# Protomers                  19624
# Stereo-resolution pairs    12010
# Unclassified                 730
# Diastereomers                100
# Enantiomers                    2
# Name: count, dtype: int64

# %% [markdown]
# Still have 31 thousand left to classify, stereomapper relationship table mapping accounted for approximately half of the relationships. The low number for enantiomers and diastereomers is likely due to those clusters being compared having extra identifiers from mnx_minus_clusters, that cause issues with mapping.
#
# The next step, is either to attempt to remove these secondary identifiers, and reattempt mapping, or to use inchikey based analysis. I would prefer the former, as using inchikeys alone will not tell us whether structures are enantiomers or diastereomers, it will only tell us that they are potential stereoisomers. It is aos possible that each cluster is duplicated, which is not incorrect, as each cluster is likely split into two.
#
# Therefore, it would make most sense to attempt to remove those secondary identifiers, and reattempt mapping stereomapper relationships back onto those entries missing a value for `relationship`.

# %%
# extract rows where relationship is null 
df_disagree_no_rels = df_disagree_with_rels[df_disagree_with_rels['relationship'].isnull()]
df_disagree_no_rels
# Out:
#               strict_bucket  strict_disagreement_reason  \
# 14      strict_disagreement  masked_split_fragmentation
# 15      strict_disagreement  masked_split_fragmentation
# 16      strict_disagreement  masked_split_fragmentation
# 18      strict_disagreement  masked_split_fragmentation
# 19      strict_disagreement  masked_split_fragmentation
# ...                     ...                         ...
# 987868  strict_disagreement  masked_split_fragmentation
# 987869  strict_disagreement         mnx_id_disagreement
# 987872  strict_disagreement  masked_split_fragmentation
# 987873  strict_disagreement  masked_split_fragmentation
# 987883  strict_disagreement  masked_split_fragmentation
#
#                 classification                                    cluster  \
# 14      mnx_superset_agreement                              sabiorkM:1470
# 15      mnx_superset_agreement                                chebi:17994
# 16      mnx_superset_agreement  chebi:68819|hmdb:HMDB0011688|keggC:C01151
# 18      mnx_superset_agreement                                chebi:58345
# 19      mnx_superset_agreement                 chebi:68688|seedM:cpd00847
# ...                        ...                                        ...
# 987868  mnx_superset_agreement                   chebi:17803|keggC:C06316
# 987869     mnx_id_disagreement                 chebi:58277|seedM:cpd16322
# 987872  mnx_superset_agreement                           hmdb:HMDB0034658
# 987873  mnx_superset_agreement                               chebi:172143
# 987883  mnx_superset_agreement                           hmdb:HMDB0001349
#
#                                               mnx_ids_hit  \
# 14              https://rdf.metanetx.org/chem/MNXM1584689
# 15              https://rdf.metanetx.org/chem/MNXM1584689
# 16              https://rdf.metanetx.org/chem/MNXM1584689
# 18              https://rdf.metanetx.org/chem/MNXM1584689
# 19              https://rdf.metanetx.org/chem/MNXM1584689
# ...                                                   ...
# 987868          https://rdf.metanetx.org/chem/MNXM1371330
# 987869  https://rdf.metanetx.org/chem/MNXM1371330|http...
# 987872           https://rdf.metanetx.org/chem/MNXM118683
# 987873           https://rdf.metanetx.org/chem/MNXM118683
# 987883           https://rdf.metanetx.org/chem/MNXM740170
#
#                                       primary_mnx  \
# 14      https://rdf.metanetx.org/chem/MNXM1584689
# 15      https://rdf.metanetx.org/chem/MNXM1584689
# 16      https://rdf.metanetx.org/chem/MNXM1584689
# 18      https://rdf.metanetx.org/chem/MNXM1584689
# 19      https://rdf.metanetx.org/chem/MNXM1584689
# ...                                           ...
# 987868  https://rdf.metanetx.org/chem/MNXM1371330
# 987869
# 987872   https://rdf.metanetx.org/chem/MNXM118683
# 987873   https://rdf.metanetx.org/chem/MNXM118683
# 987883   https://rdf.metanetx.org/chem/MNXM740170
#
#                                         mnx_minus_cluster cluster_minus_mnx  \
# 14      chebi:13012|chebi:17994|chebi:21079|chebi:4234...
# 15      chebi:13012|chebi:21079|chebi:4234|chebi:58345...
# 16      chebi:13012|chebi:17994|chebi:21079|chebi:4234...
# 18      chebi:13012|chebi:17994|chebi:21079|chebi:4234...
# 19      chebi:13012|chebi:17994|chebi:21079|chebi:4234...
# ...                                                   ...               ...
# 987868     chebi:12889|chebi:20925|chebi:4272|chebi:58277
# 987869
# 987872                        chebi:172143|hmdb:HMDB34658
# 987873                    hmdb:HMDB0034658|hmdb:HMDB34658
# 987883                         chebi:60871|hmdb:HMDB01349
#
#         support_count  cluster_size  support_fraction relationship  \
# 14                  1             1               1.0         <NA>
# 15                  1             1               1.0         <NA>
# 16                  3             3               1.0         <NA>
# 18                  1             1               1.0         <NA>
# 19                  2             2               1.0         <NA>
# ...               ...           ...               ...          ...
# 987868              2             2               1.0         <NA>
# 987869              2             2               1.0         <NA>
# 987872              1             1               1.0         <NA>
# 987873              1             1               1.0         <NA>
# 987883              1             1               1.0         <NA>
#
#                            rel_reason extra_info
# 14      mnx_minus_not_a_known_cluster       <NA>
# 15      mnx_minus_not_a_known_cluster       <NA>
# 16      mnx_minus_not_a_known_cluster       <NA>
# 18      mnx_minus_not_a_known_cluster       <NA>
# 19      mnx_minus_not_a_known_cluster       <NA>
# ...                               ...        ...
# 987868  mnx_minus_not_a_known_cluster       <NA>
# 987869    mnx_minus_empty_or_unusable       <NA>
# 987872  mnx_minus_not_a_known_cluster       <NA>
# 987873  mnx_minus_not_a_known_cluster       <NA>
# 987883     cluster_not_in_known_pairs       <NA>
#
# [32082 rows x 14 columns]

# %%
df_disagree_no_rels['classification'].value_counts()
# Out:
# classification
# mnx_superset_agreement    30009
# mnx_id_disagreement        2073
# Name: count, dtype: int64

# %%
def _to_set(x):
    if isinstance(x, list): return set(x)
    if pd.isna(x): return set()
    return set(t.strip() for t in str(x).split("|") if t.strip())

def _canon_set(x): return frozenset(_to_set(x))
def _pair_key(a, b): return frozenset((a, b))

def _first_label(labels):
    if isinstance(labels, list) and labels: return labels[0]
    if isinstance(labels, str) and labels:
        parts = [t for t in labels.split("|") if t]
        return parts[0] if parts else ""
    return ""

def build_label_to_cluster_index(results):
    """label -> cluster_key; also keep idx->cluster_key and rep label."""
    label_to_cluster = {}
    idx_to_key, idx_to_rep = [], []
    for i, r in enumerate(results):
        ckey = _canon_set(r.get("cluster", []))
        idx_to_key.append(ckey)
        rep = _first_label(r.get("cluster", []))
        idx_to_rep.append(rep)
        for lbl in ckey:
            label_to_cluster[lbl] = ckey
    return label_to_cluster, idx_to_key, idx_to_rep

def build_pair_lookup(df_rels: pd.DataFrame):
    """unordered pair of cluster keys -> (relationship class, extra_info)"""
    A = df_rels["final_cluster_a"].apply(_canon_set)
    B = df_rels["final_cluster_b"].apply(_canon_set)
    reasons = df_rels["classification"].astype(str)
    extras = df_rels["extra_info"].astype(str)
    pair_to_class = {}
    for a, b, r, e in zip(A, B, reasons, extras):
        # store both classification and extra_info
        pair_to_class[_pair_key(a, b)] = (r, e)
    return pair_to_class

def relationships_wrt_mnx_labels(results: list[dict], df_rels: pd.DataFrame) -> tuple[pd.DataFrame, pd.DataFrame]:
    """
    Returns:
      long_df: one row per (source_cluster_idx, mnx_label mapped to target_cluster, relationship, extra_info)
      summary_df: one row per source_cluster with set/counts of relationship types
    """
    pair_to_class = build_pair_lookup(df_rels)
    label_to_cluster, idx_to_key, idx_to_rep = build_label_to_cluster_index(results)

    long_rows = []
    for i, r in enumerate(results):
        src_key = idx_to_key[i]
        src_rep = idx_to_rep[i]
        pmnx = r.get("primary_mnx", "")
        mnx_labels = list(_to_set(r.get("all_related_labels_union", [])))

        for lab in mnx_labels:
            t_key = label_to_cluster.get(lab)  # only if that MNX label actually appears in some stereomapper cluster
            if t_key is None:
                # label not present in any stereomapper cluster -> can’t form a pair
                long_rows.append({
                    "src_idx": i, "src_rep": src_rep, "primary_mnx": pmnx,
                    "mnx_label": lab, "tgt_idx": None, "tgt_rep": None,
                    "relationship": None, "reason": "mnx_label_not_in_any_cluster",
                    "extra_info": ""
                })
                continue

            if t_key == src_key:
                # self; optionally keep or skip. Here we skip self-relations.
                continue

            rel_entry = pair_to_class.get(_pair_key(src_key, t_key))
            if rel_entry is not None:
                rel, extra = rel_entry
            else:
                rel, extra = None, ""

            # find a representative label for target cluster
            tgt_rep = next(iter(t_key)) if t_key else None

            long_rows.append({
                "src_idx": i, "src_rep": src_rep, "primary_mnx": pmnx,
                "mnx_label": lab, "tgt_idx": None,
                "tgt_rep": tgt_rep,
                "relationship": rel,
                "reason": "ok" if rel is not None else "pair_missing_in_relationships",
                "extra_info": extra
            })

    long_df = pd.DataFrame(long_rows)

    # Per-cluster summary of relationship types (ignoring None)
    def _types_set(s):
        vals = [x for x in s if pd.notna(x)]
        return sorted(set(vals))

    def _types_counts(s):
        d = {}
        for x in s:
            if pd.isna(x): continue
            d[x] = d.get(x, 0) + 1
        return d

    if not long_df.empty:
        summary_df = (
            long_df.groupby(["src_idx","src_rep","primary_mnx"], as_index=False)
                   .agg(
                       total_links=("relationship","size"),
                       known_pairs=("relationship", lambda s: sum(pd.notna(s))),
                       relationship_types=("relationship", _types_set),
                       relationship_type_counts=("relationship", _types_counts),
                   )
        )
    else:
        summary_df = pd.DataFrame(columns=["src_idx","src_rep","primary_mnx","total_links","known_pairs","relationship_types","relationship_type_counts"])

    return long_df, summary_df

# %%
long_df, summary_df = relationships_wrt_mnx_labels(results, df_req)

# %%
long_df
# Out:
#         src_idx                  src_rep  \
# 0             6  lipidmapsM:LMGP04010069
# 1             7            SLM:000042967
# 2            14            sabiorkM:1470
# 3            14            sabiorkM:1470
# 4            14            sabiorkM:1470
# ...         ...                      ...
# 256339   987922              chebi:64514
# 256340   987923         hmdb:HMDB0243532
# 256341   987923         hmdb:HMDB0243532
# 256342   987923         hmdb:HMDB0243532
# 256343   987924               chebi:3197
#
#                                       primary_mnx                mnx_label  \
# 0         https://rdf.metanetx.org/chem/MNXM73492            SLM:000042967
# 1         https://rdf.metanetx.org/chem/MNXM73492  lipidmapsM:LMGP04010069
# 2       https://rdf.metanetx.org/chem/MNXM1584689              chebi:17994
# 3       https://rdf.metanetx.org/chem/MNXM1584689              chebi:58345
# 4       https://rdf.metanetx.org/chem/MNXM1584689              chebi:68819
# ...                                           ...                      ...
# 256339   https://rdf.metanetx.org/chem/MNXM725413              chebi:64493
# 256340    https://rdf.metanetx.org/chem/MNXM44853           seedM:cpd05659
# 256341    https://rdf.metanetx.org/chem/MNXM44853               chebi:3197
# 256342    https://rdf.metanetx.org/chem/MNXM44853             keggC:C08754
# 256343    https://rdf.metanetx.org/chem/MNXM44853         hmdb:HMDB0243532
#
#        tgt_idx                  tgt_rep             relationship reason  \
# 0         None            SLM:000042967                Protomers     ok
# 1         None  lipidmapsM:LMGP04010069                Protomers     ok
# 2         None              chebi:17994  Stereo-resolution pairs     ok
# 3         None              chebi:58345             Unclassified     ok
# 4         None             keggC:C01151  Stereo-resolution pairs     ok
# ...        ...                      ...                      ...    ...
# 256339    None              chebi:64493                Protomers     ok
# 256340    None           seedM:cpd05659  Stereo-resolution pairs     ok
# 256341    None           seedM:cpd05659  Stereo-resolution pairs     ok
# 256342    None           seedM:cpd05659  Stereo-resolution pairs     ok
# 256343    None         hmdb:HMDB0243532  Stereo-resolution pairs     ok
#
#                                                extra_info
# 0                                                    None
# 1                                                    None
# 2                                                    None
# 3       Parent-child stereochemical relationships must...
# 4                                                    None
# ...                                                   ...
# 256339                                               None
# 256340                                               None
# 256341                                               None
# 256342                                               None
# 256343                                               None
#
# [256344 rows x 9 columns]

# %%
summary_df
# Out:
#         src_idx                  src_rep  \
# 0             6  lipidmapsM:LMGP04010069
# 1             7            SLM:000042967
# 2            14            sabiorkM:1470
# 3            15              chebi:17994
# 4            16              chebi:68819
# ...         ...                      ...
# 135903   987910              chebi:94378
# 135904   987921              chebi:64493
# 135905   987922              chebi:64514
# 135906   987923         hmdb:HMDB0243532
# 135907   987924               chebi:3197
#
#                                       primary_mnx  total_links  known_pairs  \
# 0         https://rdf.metanetx.org/chem/MNXM73492            1            1
# 1         https://rdf.metanetx.org/chem/MNXM73492            1            1
# 2       https://rdf.metanetx.org/chem/MNXM1584689           11            7
# 3       https://rdf.metanetx.org/chem/MNXM1584689           11            7
# 4       https://rdf.metanetx.org/chem/MNXM1584689            9            5
# ...                                           ...          ...          ...
# 135903   https://rdf.metanetx.org/chem/MNXM172519            1            1
# 135904   https://rdf.metanetx.org/chem/MNXM725413            2            2
# 135905   https://rdf.metanetx.org/chem/MNXM725413            1            1
# 135906    https://rdf.metanetx.org/chem/MNXM44853            3            3
# 135907    https://rdf.metanetx.org/chem/MNXM44853            1            1
#
#                                        relationship_types  \
# 0                                             [Protomers]
# 1                                             [Protomers]
# 2                 [Stereo-resolution pairs, Unclassified]
# 3       [Protomers, Stereo-resolution pairs, Unclassif...
# 4       [Protomers, Stereo-resolution pairs, Unclassif...
# ...                                                   ...
# 135903                          [Stereo-resolution pairs]
# 135904                                        [Protomers]
# 135905                                        [Protomers]
# 135906                          [Stereo-resolution pairs]
# 135907                          [Stereo-resolution pairs]
#
#                                  relationship_type_counts
# 0                                        {'Protomers': 1}
# 1                                        {'Protomers': 1}
# 2       {'Stereo-resolution pairs': 4, 'Unclassified': 3}
# 3       {'Protomers': 1, 'Stereo-resolution pairs': 4,...
# 4       {'Stereo-resolution pairs': 2, 'Unclassified':...
# ...                                                   ...
# 135903                     {'Stereo-resolution pairs': 1}
# 135904                                   {'Protomers': 2}
# 135905                                   {'Protomers': 1}
# 135906                     {'Stereo-resolution pairs': 3}
# 135907                     {'Stereo-resolution pairs': 1}
#
# [135908 rows x 7 columns]

# %%
def to_pair_view(long_df):
    # keep rows that resolved to a target cluster
    df = long_df.dropna(subset=["tgt_rep"]).copy()

    # collapse to one row per (src, tgt); keep the relationship and summarize MNX labels that led to this pair
    pair_df = (
        df.groupby(["src_idx","src_rep","primary_mnx","tgt_rep"], as_index=False)
          .agg(
              # if multiple rows disagree on relationship, pick the most frequent
              relationship=("relationship", lambda s: s.mode().iat[0] if not s.mode().empty else None),
              n_mnx_labels=("mnx_label", lambda s: s.dropna().nunique()),
              mnx_labels_used=("mnx_label", lambda s: sorted(set(x for x in s if pd.notna(x)))),
              extra_info =("extra_info", lambda s: "; ".join(sorted(set(x for x in s if pd.notna(x))))),
          )
          .sort_values(["src_idx","n_mnx_labels"], ascending=[True, False])
    )
    return pair_df

# %%
pairwise_view_df = to_pair_view(long_df)
pairwise_view_df
# Out:
#        src_idx                  src_rep  \
# 0            6  lipidmapsM:LMGP04010069
# 1            7            SLM:000042967
# 5           14            sabiorkM:1470
# 4           14            sabiorkM:1470
# 2           14            sabiorkM:1470
# ...        ...                      ...
# 80369   987910              chebi:94378
# 80370   987921              chebi:64493
# 80371   987922              chebi:64514
# 80372   987923         hmdb:HMDB0243532
# 80373   987924               chebi:3197
#
#                                      primary_mnx                  tgt_rep  \
# 0        https://rdf.metanetx.org/chem/MNXM73492            SLM:000042967
# 1        https://rdf.metanetx.org/chem/MNXM73492  lipidmapsM:LMGP04010069
# 5      https://rdf.metanetx.org/chem/MNXM1584689             keggC:C01151
# 4      https://rdf.metanetx.org/chem/MNXM1584689              chebi:68688
# 2      https://rdf.metanetx.org/chem/MNXM1584689              chebi:17994
# ...                                          ...                      ...
# 80369   https://rdf.metanetx.org/chem/MNXM172519         hmdb:HMDB0248915
# 80370   https://rdf.metanetx.org/chem/MNXM725413           seedM:cpd22804
# 80371   https://rdf.metanetx.org/chem/MNXM725413              chebi:64493
# 80372    https://rdf.metanetx.org/chem/MNXM44853           seedM:cpd05659
# 80373    https://rdf.metanetx.org/chem/MNXM44853         hmdb:HMDB0243532
#
#                   relationship  n_mnx_labels  \
# 0                    Protomers             1
# 1                    Protomers             1
# 5      Stereo-resolution pairs             3
# 4                 Unclassified             2
# 2      Stereo-resolution pairs             1
# ...                        ...           ...
# 80369  Stereo-resolution pairs             1
# 80370                Protomers             2
# 80371                Protomers             1
# 80372  Stereo-resolution pairs             3
# 80373  Stereo-resolution pairs             1
#
#                                      mnx_labels_used  \
# 0                                    [SLM:000042967]
# 1                          [lipidmapsM:LMGP04010069]
# 5      [chebi:68819, hmdb:HMDB0011688, keggC:C01151]
# 4                      [chebi:68688, seedM:cpd00847]
# 2                                      [chebi:17994]
# ...                                              ...
# 80369                             [hmdb:HMDB0248915]
# 80370                  [chebi:64514, seedM:cpd22804]
# 80371                                  [chebi:64493]
# 80372     [chebi:3197, keggC:C08754, seedM:cpd05659]
# 80373                             [hmdb:HMDB0243532]
#
#                                               extra_info
# 0                                                   None
# 1                                                   None
# 5                                                   None
# 4      Parent-child stereochemical relationships must...
# 2                                                   None
# ...                                                  ...
# 80369                                               None
# 80370                                               None
# 80371                                               None
# 80372                                               None
# 80373                                               None
#
# [80374 rows x 8 columns]

# %%
pairwise_view_df['relationship'].value_counts(dropna=False)
# Out:
# relationship
# Protomers                  34974
# Stereo-resolution pairs    25910
# Unclassified               16750
# None                        2208
# Diastereomers                466
# Enantiomers                   48
# Unresolved                    18
# Name: count, dtype: int64

# %%
# add up the total counts for relationships 
pairwise_view_df['relationship'].value_counts().sum()
# Out:
# 78166

# %%
# change 'Planar vs stereo defined structures' to 'Parent-child' for readability and consistency with manuscript
## will need to change source code to account for this later
pairwise_view_df['relationship'] = pairwise_view_df['relationship'].replace({'Parent-child': 'Stereo-resolution pairs'})
pairwise_view_df['relationship'] = pairwise_view_df['relationship'].replace({'No classification': 'Unclassified'})
pairwise_view_df['relationship'] = pairwise_view_df['relationship'].replace({'Unresolved (Possible Pipeline Error)': 'Unresolved'})
pairwise_view_df
# Out:
#        src_idx                  src_rep  \
# 0            6  lipidmapsM:LMGP04010069
# 1            7            SLM:000042967
# 5           14            sabiorkM:1470
# 4           14            sabiorkM:1470
# 2           14            sabiorkM:1470
# ...        ...                      ...
# 80369   987910              chebi:94378
# 80370   987921              chebi:64493
# 80371   987922              chebi:64514
# 80372   987923         hmdb:HMDB0243532
# 80373   987924               chebi:3197
#
#                                      primary_mnx                  tgt_rep  \
# 0        https://rdf.metanetx.org/chem/MNXM73492            SLM:000042967
# 1        https://rdf.metanetx.org/chem/MNXM73492  lipidmapsM:LMGP04010069
# 5      https://rdf.metanetx.org/chem/MNXM1584689             keggC:C01151
# 4      https://rdf.metanetx.org/chem/MNXM1584689              chebi:68688
# 2      https://rdf.metanetx.org/chem/MNXM1584689              chebi:17994
# ...                                          ...                      ...
# 80369   https://rdf.metanetx.org/chem/MNXM172519         hmdb:HMDB0248915
# 80370   https://rdf.metanetx.org/chem/MNXM725413           seedM:cpd22804
# 80371   https://rdf.metanetx.org/chem/MNXM725413              chebi:64493
# 80372    https://rdf.metanetx.org/chem/MNXM44853           seedM:cpd05659
# 80373    https://rdf.metanetx.org/chem/MNXM44853         hmdb:HMDB0243532
#
#                   relationship  n_mnx_labels  \
# 0                    Protomers             1
# 1                    Protomers             1
# 5      Stereo-resolution pairs             3
# 4                 Unclassified             2
# 2      Stereo-resolution pairs             1
# ...                        ...           ...
# 80369  Stereo-resolution pairs             1
# 80370                Protomers             2
# 80371                Protomers             1
# 80372  Stereo-resolution pairs             3
# 80373  Stereo-resolution pairs             1
#
#                                      mnx_labels_used  \
# 0                                    [SLM:000042967]
# 1                          [lipidmapsM:LMGP04010069]
# 5      [chebi:68819, hmdb:HMDB0011688, keggC:C01151]
# 4                      [chebi:68688, seedM:cpd00847]
# 2                                      [chebi:17994]
# ...                                              ...
# 80369                             [hmdb:HMDB0248915]
# 80370                  [chebi:64514, seedM:cpd22804]
# 80371                                  [chebi:64493]
# 80372     [chebi:3197, keggC:C08754, seedM:cpd05659]
# 80373                             [hmdb:HMDB0243532]
#
#                                               extra_info
# 0                                                   None
# 1                                                   None
# 5                                                   None
# 4      Parent-child stereochemical relationships must...
# 2                                                   None
# ...                                                  ...
# 80369                                               None
# 80370                                               None
# 80371                                               None
# 80372                                               None
# 80373                                               None
#
# [80374 rows x 8 columns]

# %%
# from: labelled_res, strict_summary, strict_views = derive_strict_view(results, frag)
disagree_idx = {i for i, r in enumerate(labelled_res) if r["strict_bucket"] == "strict_disagreement"}

# Filter per-cluster summary to just disagreements
summary_dis = summary_df[summary_df["src_idx"].isin(disagree_idx)].copy()

n_clusters = len(summary_dis)
print("Disagreement clusters in summary:", n_clusters)  # should be <= len(df_disagree)
# Out:
# Disagreement clusters in summary: 63942

# %%
summary_dis
# Out:
#         src_idx                  src_rep  \
# 0             6  lipidmapsM:LMGP04010069
# 1             7            SLM:000042967
# 2            14            sabiorkM:1470
# 3            15              chebi:17994
# 4            16              chebi:68819
# ...         ...                      ...
# 135903   987910              chebi:94378
# 135904   987921              chebi:64493
# 135905   987922              chebi:64514
# 135906   987923         hmdb:HMDB0243532
# 135907   987924               chebi:3197
#
#                                       primary_mnx  total_links  known_pairs  \
# 0         https://rdf.metanetx.org/chem/MNXM73492            1            1
# 1         https://rdf.metanetx.org/chem/MNXM73492            1            1
# 2       https://rdf.metanetx.org/chem/MNXM1584689           11            7
# 3       https://rdf.metanetx.org/chem/MNXM1584689           11            7
# 4       https://rdf.metanetx.org/chem/MNXM1584689            9            5
# ...                                           ...          ...          ...
# 135903   https://rdf.metanetx.org/chem/MNXM172519            1            1
# 135904   https://rdf.metanetx.org/chem/MNXM725413            2            2
# 135905   https://rdf.metanetx.org/chem/MNXM725413            1            1
# 135906    https://rdf.metanetx.org/chem/MNXM44853            3            3
# 135907    https://rdf.metanetx.org/chem/MNXM44853            1            1
#
#                                        relationship_types  \
# 0                                             [Protomers]
# 1                                             [Protomers]
# 2                 [Stereo-resolution pairs, Unclassified]
# 3       [Protomers, Stereo-resolution pairs, Unclassif...
# 4       [Protomers, Stereo-resolution pairs, Unclassif...
# ...                                                   ...
# 135903                          [Stereo-resolution pairs]
# 135904                                        [Protomers]
# 135905                                        [Protomers]
# 135906                          [Stereo-resolution pairs]
# 135907                          [Stereo-resolution pairs]
#
#                                  relationship_type_counts
# 0                                        {'Protomers': 1}
# 1                                        {'Protomers': 1}
# 2       {'Stereo-resolution pairs': 4, 'Unclassified': 3}
# 3       {'Protomers': 1, 'Stereo-resolution pairs': 4,...
# 4       {'Stereo-resolution pairs': 2, 'Unclassified':...
# ...                                                   ...
# 135903                     {'Stereo-resolution pairs': 1}
# 135904                                   {'Protomers': 2}
# 135905                                   {'Protomers': 1}
# 135906                     {'Stereo-resolution pairs': 3}
# 135907                     {'Stereo-resolution pairs': 1}
#
# [63942 rows x 7 columns]

# %%
# ------------------------
# Data
# ------------------------

# Define replacements
replacements = {
    "No classification": "Unclassified",
    "Unresolved (Possible Pipeline Error)": "Unresolved"
}

# Apply transformation
cluster_types = summary_dis["relationship_types"].apply(
    lambda xs: sorted({
        replacements.get(str(t).strip(), str(t).strip())
        for t in (xs or [])
        if pd.notna(t)
    })
)

# disagreement-only, cluster-weighted presence
n_clusters = len(summary_dis)

present_counts = cluster_types.explode().value_counts().sort_values(ascending=False)
assert present_counts.max() <= n_clusters, (present_counts.max(), n_clusters)
present_pct = present_counts / n_clusters * 100

# use these for plotting
rel_counts = present_counts
rel_percentages = present_pct

labels_all = rel_counts.index.tolist()
sizes_all = rel_counts.values
percentages_all = rel_percentages  # Series keyed by label

threshold_pct = 1.0
explicit_rare = {"Enantiomers", "Diastereomers", "Unresolved"}

major_labels = [lbl for lbl in labels_all if percentages_all[lbl] >= threshold_pct]
major_sizes = np.array([rel_counts[lbl] for lbl in major_labels], dtype=float)

rare_labels = [lbl for lbl in labels_all if lbl not in major_labels and lbl in explicit_rare]
rare_count = rel_counts[rare_labels].sum() if rare_labels else 0
rare_pct = rare_count / rel_counts.sum() * 100 if rel_counts.sum() > 0 else 0.0

palette = {
    "Enantiomers": "#009E73",
    "Diastereomers": "#0072B2",
    "Protomers": "#E69F00",
    "Stereo-resolution pairs": "#CC79A7",
    "Unclassified": "#D55E00",
    "Unresolved": "#F0E442",
}
default_colour = "#999999"

major_colours = [palette.get(lbl, default_colour) for lbl in major_labels]

plt.rcParams.update({
    "font.family": "sans-serif",
    "font.sans-serif": ["DejaVu Sans"],
    "font.size": 12,
    "figure.dpi": 300,
    "pdf.fonttype": 42,
    "ps.fonttype": 42,
})

fig, ax = plt.subplots(figsize=(5, 5))

def autopct_fmt(pct):
    total = rel_percentages.sum()
    count = int(round(pct / 100.0 * total))
    return f"{pct:.1f}%"

wedges, texts, autotexts = ax.pie(
    major_sizes,
    labels=None,
    colors=major_colours,
    startangle=90,
    counterclock=False,
    autopct=lambda pct: "",
    pctdistance=0.5,
    wedgeprops=dict(edgecolor="black", linewidth=1.0),
    textprops=dict(fontsize=10),
)

for lbl, autotext in zip(major_labels, autotexts):
    pct_true = rel_percentages[lbl]      # your correct percentage
    autotext.set_text(f"{pct_true:.1f}%")


ax.set_aspect("equal")

# Legend: same layout choices as the other pie
ax.legend(
    wedges,
    major_labels,
    loc="lower center",
    bbox_to_anchor=(0.5, -0.15),
    ncol=1,
    frameon=False,
    fontsize=10,
)

# Use the same margins for both pies
plt.subplots_adjust(left=0.15, right=0.85, top=0.95, bottom=0.25)

plt.show()
