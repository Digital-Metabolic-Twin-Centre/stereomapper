# %% [markdown]
# # Benchmarking Experiments
#
# This notebook provides a detailed overview of the benchmarking experiments and illustrates how the StereoMapper tool is applied to each dataset to generate the corresponding relationship-assignment results.
#
# Note: As the pipeline’s source code is subject to ongoing development, minor variations in results may occur between different versions of StereoMapper.

# %%
import os
import pandas as pd
from pathlib import Path
import json
import re
import sqlite3
import subprocess
import pandas as pd
import sqlite3
from pathlib import Path
import logging
import os
import subprocess
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# %%
## some functions for use in the notebook

def norm_chebi(x: str) -> str:
    """Return a canonical CHEBI_###### string from inputs like 'chebi:123', 'CHEBI_123', '123'."""
    s = str(x).strip()
    m = re.search(r'(\d+)$', s)  # grab trailing digits
    if not m:
        return s.upper()  # fallback: just uppercase unknowns
    return f"CHEBI_{m.group(1)}"

def safe_load_members(x):
    if isinstance(x, (list, tuple)):
        return x
    try:
        return json.loads(x)
    except Exception:
        return x  # already a string or malformed

def canonical_chebi_id(members):
    # members may be a list of strings or a single string; return canonical ID like "CHEBI_12345"
    if not members:
        return ""
    # if a list, pick canonical representative (sorted deterministically)
    if isinstance(members, (list, tuple)):
        candidates = []
        for m in members:
            if not isinstance(m, str):
                continue
            s = m.replace("chebi:CHEBI:", "CHEBI_").replace("chebi:CHEBI", "CHEBI_")
            s = s.replace("chebi:", "")
            candidates.append(s.strip())
        return sorted(candidates)[0] if candidates else ""
    # single string
    s = members
    s = s.replace("chebi:CHEBI:", "CHEBI_").replace("chebi:CHEBI", "CHEBI_")
    s = s.replace("chebi:", "").strip()
    return s

def canonical_pairkey(a, b):
    # a,b are identifiers or lists; normalise to strings then sort lexicographically
    ka = canonical_chebi_id(a)
    kb = canonical_chebi_id(b)
    if not ka and not kb:
        return ""
    # sort so order doesn't matter
    left, right = sorted([ka, kb])
    return f"{left}__{right}"

# %% [markdown]
# ## Enantiomer benchmarking

# %%
# import csv with control pairings
control_pairs = pd.read_csv('data/enantiomer_control_set.csv')
control_pairs
# Out:
#                id1           id2        label
# 0      CHEBI_43796   CHEBI_30314  Enantiomers
# 1      CHEBI_30314   CHEBI_43796  Enantiomers
# 2      CHEBI_15570   CHEBI_16977  Enantiomers
# 3      CHEBI_16977   CHEBI_15570  Enantiomers
# 4      CHEBI_32433   CHEBI_32437  Enantiomers
# ...            ...           ...          ...
# 2809  CHEBI_235379  CHEBI_235380  Enantiomers
# 2810   CHEBI_76640  CHEBI_195630  Enantiomers
# 2811  CHEBI_195630   CHEBI_76640  Enantiomers
# 2812  CHEBI_235487   CHEBI_76457  Enantiomers
# 2813   CHEBI_76457  CHEBI_235487  Enantiomers
#
# [2814 rows x 3 columns]

# %%
# 1) Canonicalize + dedupe control set
dfc = control_pairs.copy()
dfc["id1_c"] = dfc["id1"].map(norm_chebi)
dfc["id2_c"] = dfc["id2"].map(norm_chebi)
# order-invariant canonical pair (tuple sorted)
dfc["pair_key"] = dfc.apply(lambda r: tuple(sorted((r["id1_c"], r["id2_c"]))), axis=1)
# keep one row per unordered pair (optionally verify labels agree before dropping)
dfc_dedup = dfc.drop_duplicates(subset=["pair_key"]).reset_index(drop=True)
control_keys = set(dfc_dedup["pair_key"])

dfc_dedup
# Out:
#                id1           id2        label         id1_c         id2_c  \
# 0      CHEBI_43796   CHEBI_30314  Enantiomers   CHEBI_43796   CHEBI_30314
# 1      CHEBI_15570   CHEBI_16977  Enantiomers   CHEBI_15570   CHEBI_16977
# 2      CHEBI_32433   CHEBI_32437  Enantiomers   CHEBI_32433   CHEBI_32437
# 3      CHEBI_32447   CHEBI_32452  Enantiomers   CHEBI_32447   CHEBI_32452
# 4      CHEBI_17561   CHEBI_16375  Enantiomers   CHEBI_17561   CHEBI_16375
# ...            ...           ...          ...           ...           ...
# 1402  CHEBI_234521  CHEBI_234520  Enantiomers  CHEBI_234521  CHEBI_234520
# 1403  CHEBI_234547  CHEBI_234545  Enantiomers  CHEBI_234547  CHEBI_234545
# 1404  CHEBI_235380  CHEBI_235379  Enantiomers  CHEBI_235380  CHEBI_235379
# 1405   CHEBI_76640  CHEBI_195630  Enantiomers   CHEBI_76640  CHEBI_195630
# 1406  CHEBI_235487   CHEBI_76457  Enantiomers  CHEBI_235487   CHEBI_76457
#
#                           pair_key
# 0       (CHEBI_30314, CHEBI_43796)
# 1       (CHEBI_15570, CHEBI_16977)
# 2       (CHEBI_32433, CHEBI_32437)
# 3       (CHEBI_32447, CHEBI_32452)
# 4       (CHEBI_16375, CHEBI_17561)
# ...                            ...
# 1402  (CHEBI_234520, CHEBI_234521)
# 1403  (CHEBI_234545, CHEBI_234547)
# 1404  (CHEBI_235379, CHEBI_235380)
# 1405   (CHEBI_195630, CHEBI_76640)
# 1406   (CHEBI_235487, CHEBI_76457)
#
# [1407 rows x 6 columns]

# %%
# run stereomapper as a subprocess
enantiomers = Path('/home/jackmcgoldrick/Downloads/benchmarking_data/enantiomer_benchmark_data') # downloadable from Zenodo (DOI: 10.5281/zenodo.17831412)
results = Path('enantiomer_benchmark_results.sqlite') 
cache_path = Path('enantiomer_benchmark_cache.sqlite')

# %%
cmd =[
    "stereomapper",
    "run",
    "-d", enantiomers.as_posix(),
    "-o", results.as_posix(),
    "-p", cache_path.as_posix(),
    "--fresh-cache"
]

subprocess.run(cmd)
# Out:
# INFO    Logging initialised. File: logs/stereomapper_20251215_103704.log
# Pipeline: 100%|██████████████████████████████████████████████████████████| , Complete! [00:11<00:00]
# ✅ Pipeline completed in 11.6s
# 📦 Inputs attempted: 2,504 (skipped 0)
# 📊 Successes: 2,502 | Failures: 2
# 🔗 Inchikey groups — processed 931, skipped 0, failed 0
# 🧮 Relationship rows: 3,618
# 🧾 Unique inchikeys observed: 931
# 💾 Cache hit rate: 0.0%
# Pipeline: 100%|██████████████████████████████████████████████████████████| , Complete! [00:12<00:00]
# CompletedProcess(args=['stereomapper', 'run', '-d', '/home/jackmcgoldrick/Downloads/benchmarking_data/enantiomer_benchmark_data', '-o', 'enantiomer_benchmark_results.sqlite', '-p', 'enantiomer_benchmark_cache.sqlite', '--fresh-cache'], returncode=0)

# %%
conn = sqlite3.connect(results)
merged_df_q = """ 
SELECT * from relationships;
"""
df_merged = pd.read_sql_query(merged_df_q, conn)
df_merged
# Out:
#       cluster_a  cluster_b cluster_a_members cluster_b_members  \
# 0             1          2   ["chebi:17521"]   ["chebi:36124"]
# 1             3          4  ["chebi:137507"]  ["chebi:137513"]
# 2             5          6  ["chebi:134198"]  ["chebi:134199"]
# 3             7          8   ["chebi:28651"]   ["chebi:27702"]
# 4             9         10  ["chebi:145480"]  ["chebi:145483"]
# ...         ...        ...               ...               ...
# 3613       2456       2458  ["chebi:133313"]  ["chebi:133312"]
# 3614       2457       2458  ["chebi:133311"]  ["chebi:133312"]
# 3615       2459       2460  ["chebi:233960"]  ["chebi:233959"]
# 3616       2461       2462  ["chebi:142550"]    ["chebi:9399"]
# 3617       2463       2464  ["chebi:138363"]  ["chebi:138362"]
#
#       cluster_a_size  cluster_b_size classification  score  \
# 0                  1               1  Diastereomers  100.0
# 1                  1               1    Enantiomers  100.0
# 2                  1               1    Enantiomers  100.0
# 3                  1               1    Enantiomers  100.0
# 4                  1               1    Enantiomers  100.0
# ...              ...             ...            ...    ...
# 3613               1               1  Diastereomers  100.0
# 3614               1               1  Diastereomers  100.0
# 3615               1               1    Enantiomers  100.0
# 3616               1               1    Enantiomers  100.0
# 3617               1               1    Enantiomers  100.0
#
#                   score_details extra_info version_tag
# 0     {"confidence_bin":"high"}       None        v1.0
# 1     {"confidence_bin":"high"}       None        v1.0
# 2     {"confidence_bin":"high"}       None        v1.0
# 3     {"confidence_bin":"high"}       None        v1.0
# 4     {"confidence_bin":"high"}       None        v1.0
# ...                         ...        ...         ...
# 3613  {"confidence_bin":"high"}       None        v1.0
# 3614  {"confidence_bin":"high"}       None        v1.0
# 3615  {"confidence_bin":"high"}       None        v1.0
# 3616  {"confidence_bin":"high"}       None        v1.0
# 3617  {"confidence_bin":"high"}       None        v1.0
#
# [3618 rows x 11 columns]

# %%
expanded_keys = set()
for _, row in df_merged.iterrows():
    if not row["cluster_a_members"] or not row["cluster_b_members"]:
        continue
    m1s = [norm_chebi(x) for x in json.loads(row["cluster_a_members"])]
    m2s = [norm_chebi(x) for x in json.loads(row["cluster_b_members"])]
    for a in m1s:
        for b in m2s:
            if a == b:
                continue
            expanded_keys.add(tuple(sorted((a, b))))

# --- Overlap ---
tp = control_keys & expanded_keys
fp = expanded_keys - control_keys
fn = control_keys - expanded_keys

print(f"True Positives: {len(tp)}")
print(f"False Positives: {len(fp)}")
print(f"False Negatives: {len(fn)}")
# Out:
# True Positives: 1243
# False Positives: 2494
# False Negatives: 164

# %% [markdown]
# Not a true representation of the results, contains 2384 false positives majority of which are off target relationships. Therefore, the dataset needs to be remapped back onto the original pairs stored in the control dataset.

# %%
valid_pairs = control_keys

df_pred_filtered = []
for _, row in df_merged.iterrows():
    members_1 = [norm_chebi(x) for x in json.loads(row["cluster_a_members"])]
    members_2 = [norm_chebi(x) for x in json.loads(row["cluster_b_members"])]
    for a in members_1:
        for b in members_2:
            pair = tuple(sorted((a, b)))
            if pair in valid_pairs:
                df_pred_filtered.append({"id1": a, "id2": b, **row.to_dict()})

df_pred_filtered = pd.DataFrame(df_pred_filtered)

# %%
df_pred_filtered = df_pred_filtered.copy()
df_pred_filtered["pair_key"] = df_pred_filtered.apply(
    lambda r: tuple(sorted([norm_chebi(r["id1"]), norm_chebi(r["id2"])])), axis=1
)

# %%
df_eval = pd.merge(
    df_pred_filtered,
    dfc_dedup[["pair_key", "label"]],
    on="pair_key",
    how="left"
)

# %% [markdown]
# Dataframe `df_eval` now contains the original pairs of identifiers with their predicitions from stereomapper. This dataframe will be used to accurately calculate the precision, recall and F1 score on the enantiomer control dataset.

# %%
# only rows where we have a prediction - removing FN, ensure to state in results section
df_with_pred = df_eval.dropna(subset=["classification"])

tp = ((df_eval["classification"] == df_eval["label"]).sum())
fp = ((df_eval["classification"] != df_eval["label"]).sum())
fn = df_eval["classification"].isna().sum()

print(f"TP: {tp}, FP: {fp}, FN: {fn}")
# Out:
# TP: 1184, FP: 59, FN: 0

# %%
enantiomer_precision = tp / (tp + fp) if (tp + fp) > 0 else 0
enantiomer_recall = tp / (tp + fn) if (tp + fn) > 0 else 0
enantiomer_f1 = 2 * enantiomer_precision * enantiomer_recall / (enantiomer_precision + enantiomer_recall) if (enantiomer_precision + enantiomer_recall) > 0 else 0

print(f"Precision: {enantiomer_precision:.3f}")
print(f"Recall:    {enantiomer_recall:.3f}")
print(f"F1 score:  {enantiomer_f1:.3f}")
# Out:
# Precision: 0.953
# Recall:    1.000
# F1 score:  0.976

# %% [markdown]
# Great results, lets investigate the false positive results to see what went wrong and if the pipeline can be improved.

# %%
df_fp = df_with_pred[df_with_pred["classification"] != df_with_pred["label"]]
df_fp
# Out:
#                id1           id2  cluster_a  cluster_b cluster_a_members  \
# 0      CHEBI_17521   CHEBI_36124          1          2   ["chebi:17521"]
# 117    CHEBI_27374   CHEBI_27372        232        233   ["chebi:27374"]
# 184   CHEBI_140637  CHEBI_136698        364        365  ["chebi:140637"]
# 202    CHEBI_28548   CHEBI_37209        400        401   ["chebi:28548"]
# 203    CHEBI_16002   CHEBI_47537        402        404   ["chebi:16002"]
# 206    CHEBI_21101   CHEBI_21398        406        409   ["chebi:21101"]
# 209    CHEBI_37546   CHEBI_37547        412        416   ["chebi:37546"]
# 210    CHEBI_21100   CHEBI_21397        413        417   ["chebi:21100"]
# 230    CHEBI_17924   CHEBI_28789        456        457   ["chebi:17924"]
# 232   CHEBI_134311  CHEBI_192698        459        461  ["chebi:134311"]
# 252    CHEBI_37465   CHEBI_15386        501        503   ["chebi:37465"]
# 275    CHEBI_37477   CHEBI_37476        547        549   ["chebi:37477"]
# 312    CHEBI_38969    CHEBI_3332        621        622   ["chebi:38969"]
# 333   CHEBI_229701   CHEBI_57906        663        664  ["chebi:229701"]
# 379   CHEBI_167675  CHEBI_167676        754        755  ["chebi:167675"]
# 387    CHEBI_90389   CHEBI_90391        771        772   ["chebi:90389"]
# 388    CHEBI_90394   CHEBI_90395        773        774   ["chebi:90394"]
# 392    CHEBI_76864  CHEBI_232288        781        782   ["chebi:76864"]
# 394   CHEBI_138619  CHEBI_144940        785        786  ["chebi:138619"]
# 402   CHEBI_189872  CHEBI_189871        801        802  ["chebi:189872"]
# 406    CHEBI_17426  CHEBI_137932        809        810   ["chebi:17426"]
# 413    CHEBI_88304   CHEBI_88303        824        825   ["chebi:88304"]
# 414    CHEBI_90386   CHEBI_90387        826        827   ["chebi:90386"]
# 456   CHEBI_132914  CHEBI_132913        910        911  ["chebi:132914"]
# 467    CHEBI_39336   CHEBI_39335        931        932   ["chebi:39336"]
# 484    CHEBI_64020   CHEBI_64021        966        968   ["chebi:64020"]
# 485   CHEBI_132915  CHEBI_132916        967        969  ["chebi:132915"]
# 579    CHEBI_18481   CHEBI_15387       1152       1153   ["chebi:18481"]
# 580   CHEBI_156255   CHEBI_15414       1154       1155  ["chebi:156255"]
# 689    CHEBI_63698   CHEBI_63695       1370       1373   ["chebi:63698"]
# 690    CHEBI_63705   CHEBI_63700       1371       1372   ["chebi:63705"]
# 696   CHEBI_167910  CHEBI_167901       1384       1385  ["chebi:167910"]
# 717   CHEBI_195630   CHEBI_76640       1426       1427  ["chebi:195630"]
# 786    CHEBI_38139   CHEBI_44343       1564       1566   ["chebi:38139"]
# 789    CHEBI_39309   CHEBI_39313       1569       1570   ["chebi:39309"]
# 793    CHEBI_38154   CHEBI_38153       1578       1579   ["chebi:38154"]
# 837   CHEBI_194352  CHEBI_194351       1665       1666  ["chebi:194352"]
# 841   CHEBI_195225  CHEBI_195223       1673       1674  ["chebi:195225"]
# 845    CHEBI_72758  CHEBI_157606       1681       1682   ["chebi:72758"]
# 851    CHEBI_50146   CHEBI_50147       1693       1694   ["chebi:50146"]
# 859    CHEBI_76557  CHEBI_232532       1709       1710   ["chebi:76557"]
# 892    CHEBI_46987   CHEBI_46995       1775       1781   ["chebi:46987"]
# 894    CHEBI_47012   CHEBI_27476       1777       1779   ["chebi:47012"]
# 895    CHEBI_47008   CHEBI_47011       1778       1780   ["chebi:47008"]
# 898    CHEBI_77599   CHEBI_77604       1787       1788   ["chebi:77599"]
# 924   CHEBI_144384  CHEBI_144379       1839       1840  ["chebi:144384"]
# 926   CHEBI_183806   CHEBI_81467       1843       1844  ["chebi:183806"]
# 931   CHEBI_193571   CHEBI_57463       1853       1854  ["chebi:193571"]
# 939   CHEBI_167883  CHEBI_167882       1867       1868  ["chebi:167883"]
# 940    CHEBI_32922   CHEBI_35440       1869       1870   ["chebi:32922"]
# 972    CHEBI_70980  CHEBI_231528       1931       1932   ["chebi:70980"]
# 1058   CHEBI_50931   CHEBI_50932       2102       2103   ["chebi:50931"]
# 1062  CHEBI_140638  CHEBI_140636       2108       2109  ["chebi:140638"]
# 1119   CHEBI_83132   CHEBI_83130       2218       2219   ["chebi:83132"]
# 1120   CHEBI_83131   CHEBI_83129       2220       2221   ["chebi:83131"]
# 1124  CHEBI_231949  CHEBI_231950       2228       2229  ["chebi:231949"]
# 1208   CHEBI_67234   CHEBI_67233       2395       2396   ["chebi:67234"]
# 1218  CHEBI_138601  CHEBI_138641       2415       2416  ["chebi:138601"]
# 1236   CHEBI_27669   CHEBI_38200       2451       2452   ["chebi:27669"]
#
#      cluster_b_members  cluster_a_size  cluster_b_size  \
# 0      ["chebi:36124"]               1               1
# 117    ["chebi:27372"]               1               1
# 184   ["chebi:136698"]               1               1
# 202    ["chebi:37209"]               1               1
# 203    ["chebi:47537"]               1               1
# 206    ["chebi:21398"]               1               1
# 209    ["chebi:37547"]               1               1
# 210    ["chebi:21397"]               1               1
# 230    ["chebi:28789"]               1               1
# 232   ["chebi:192698"]               1               1
# 252    ["chebi:15386"]               1               1
# 275    ["chebi:37476"]               1               1
# 312     ["chebi:3332"]               1               1
# 333    ["chebi:57906"]               1               1
# 379   ["chebi:167676"]               1               1
# 387    ["chebi:90391"]               1               1
# 388    ["chebi:90395"]               1               1
# 392   ["chebi:232288"]               1               1
# 394   ["chebi:144940"]               1               1
# 402   ["chebi:189871"]               1               1
# 406   ["chebi:137932"]               1               1
# 413    ["chebi:88303"]               1               1
# 414    ["chebi:90387"]               1               1
# 456   ["chebi:132913"]               1               1
# 467    ["chebi:39335"]               1               1
# 484    ["chebi:64021"]               1               1
# 485   ["chebi:132916"]               1               1
# 579    ["chebi:15387"]               1               1
# 580    ["chebi:15414"]               1               1
# 689    ["chebi:63695"]               1               1
# 690    ["chebi:63700"]               1               1
# 696   ["chebi:167901"]               1               1
# 717    ["chebi:76640"]               1               1
# 786    ["chebi:44343"]               1               1
# 789    ["chebi:39313"]               1               1
# 793    ["chebi:38153"]               1               1
# 837   ["chebi:194351"]               1               1
# 841   ["chebi:195223"]               1               1
# 845   ["chebi:157606"]               1               1
# 851    ["chebi:50147"]               1               1
# 859   ["chebi:232532"]               1               1
# 892    ["chebi:46995"]               1               1
# 894    ["chebi:27476"]               1               1
# 895    ["chebi:47011"]               1               1
# 898    ["chebi:77604"]               1               1
# 924   ["chebi:144379"]               1               1
# 926    ["chebi:81467"]               1               1
# 931    ["chebi:57463"]               1               1
# 939   ["chebi:167882"]               1               1
# 940    ["chebi:35440"]               1               1
# 972   ["chebi:231528"]               1               1
# 1058   ["chebi:50932"]               1               1
# 1062  ["chebi:140636"]               1               1
# 1119   ["chebi:83130"]               1               1
# 1120   ["chebi:83129"]               1               1
# 1124  ["chebi:231950"]               1               1
# 1208   ["chebi:67233"]               1               1
# 1218  ["chebi:138641"]               1               1
# 1236   ["chebi:38200"]               1               1
#
#                classification  score                score_details  \
# 0               Diastereomers  100.0    {"confidence_bin":"high"}
# 117             Diastereomers  100.0    {"confidence_bin":"high"}
# 184             Diastereomers  100.0    {"confidence_bin":"high"}
# 202             Diastereomers  100.0    {"confidence_bin":"high"}
# 203             Diastereomers  100.0    {"confidence_bin":"high"}
# 206             Diastereomers  100.0    {"confidence_bin":"high"}
# 209             Diastereomers  100.0    {"confidence_bin":"high"}
# 210             Diastereomers  100.0    {"confidence_bin":"high"}
# 230             Diastereomers  100.0    {"confidence_bin":"high"}
# 232             Diastereomers  100.0    {"confidence_bin":"high"}
# 252                Unresolved  100.0    {"confidence_bin":"high"}
# 275   Stereo-resolution pairs  100.0    {"confidence_bin":"high"}
# 312   Stereo-resolution pairs  100.0    {"confidence_bin":"high"}
# 333             Diastereomers  100.0    {"confidence_bin":"high"}
# 379             Diastereomers  100.0    {"confidence_bin":"high"}
# 387   Stereo-resolution pairs   75.0  {"confidence_bin":"medium"}
# 388   Stereo-resolution pairs   75.0  {"confidence_bin":"medium"}
# 392             Diastereomers  100.0    {"confidence_bin":"high"}
# 394             Diastereomers  100.0    {"confidence_bin":"high"}
# 402   Stereo-resolution pairs  100.0    {"confidence_bin":"high"}
# 406   Stereo-resolution pairs  100.0    {"confidence_bin":"high"}
# 413              Unclassified    NaN      {"confidence_bin":null}
# 414   Stereo-resolution pairs   75.0  {"confidence_bin":"medium"}
# 456             Diastereomers  100.0    {"confidence_bin":"high"}
# 467   Stereo-resolution pairs   76.0  {"confidence_bin":"medium"}
# 484             Diastereomers  100.0    {"confidence_bin":"high"}
# 485             Diastereomers  100.0    {"confidence_bin":"high"}
# 579             Diastereomers  100.0    {"confidence_bin":"high"}
# 580             Diastereomers  100.0    {"confidence_bin":"high"}
# 689   Stereo-resolution pairs   77.0  {"confidence_bin":"medium"}
# 690   Stereo-resolution pairs   77.0  {"confidence_bin":"medium"}
# 696             Diastereomers  100.0    {"confidence_bin":"high"}
# 717   Stereo-resolution pairs  100.0    {"confidence_bin":"high"}
# 786                Unresolved  100.0    {"confidence_bin":"high"}
# 789   Stereo-resolution pairs   76.0  {"confidence_bin":"medium"}
# 793   Stereo-resolution pairs   76.0  {"confidence_bin":"medium"}
# 837             Diastereomers  100.0    {"confidence_bin":"high"}
# 841             Diastereomers  100.0    {"confidence_bin":"high"}
# 845             Diastereomers   77.0  {"confidence_bin":"medium"}
# 851             Diastereomers  100.0    {"confidence_bin":"high"}
# 859             Diastereomers  100.0    {"confidence_bin":"high"}
# 892             Diastereomers  100.0    {"confidence_bin":"high"}
# 894             Diastereomers  100.0    {"confidence_bin":"high"}
# 895                Unresolved  100.0    {"confidence_bin":"high"}
# 898   Stereo-resolution pairs   94.0    {"confidence_bin":"high"}
# 924   Stereo-resolution pairs  100.0    {"confidence_bin":"high"}
# 926             Diastereomers  100.0    {"confidence_bin":"high"}
# 931             Diastereomers  100.0    {"confidence_bin":"high"}
# 939             Diastereomers  100.0    {"confidence_bin":"high"}
# 940   Stereo-resolution pairs   79.0  {"confidence_bin":"medium"}
# 972             Diastereomers  100.0    {"confidence_bin":"high"}
# 1058            Diastereomers   77.0  {"confidence_bin":"medium"}
# 1062            Diastereomers  100.0    {"confidence_bin":"high"}
# 1119               Unresolved   75.0  {"confidence_bin":"medium"}
# 1120               Unresolved   75.0  {"confidence_bin":"medium"}
# 1124            Diastereomers  100.0    {"confidence_bin":"high"}
# 1208            Diastereomers  100.0    {"confidence_bin":"high"}
# 1218            Diastereomers  100.0    {"confidence_bin":"high"}
# 1236            Diastereomers  100.0    {"confidence_bin":"high"}
#
#                                              extra_info version_tag  \
# 0                                                  None        v1.0
# 117                                                None        v1.0
# 184                                                None        v1.0
# 202                                                None        v1.0
# 203                                                None        v1.0
# 206                                                None        v1.0
# 209                                                None        v1.0
# 210                                                None        v1.0
# 230                                                None        v1.0
# 232                                                None        v1.0
# 252   Possible pipeline error - should be no identic...        v1.0
# 275                                                None        v1.0
# 312                                                None        v1.0
# 333                                                None        v1.0
# 379                                                None        v1.0
# 387                                                None        v1.0
# 388                                                None        v1.0
# 392                                                None        v1.0
# 394                                                None        v1.0
# 402                                                None        v1.0
# 406                                                None        v1.0
# 413   Enantiomers must share protonation/charge; no ...        v1.0
# 414                                                None        v1.0
# 456                                                None        v1.0
# 467                                                None        v1.0
# 484                                                None        v1.0
# 485                                                None        v1.0
# 579                                                None        v1.0
# 580                                                None        v1.0
# 689                                                None        v1.0
# 690                                                None        v1.0
# 696                                                None        v1.0
# 717                                                None        v1.0
# 786   Possible pipeline error - should be no identic...        v1.0
# 789                                                None        v1.0
# 793                                                None        v1.0
# 837                                                None        v1.0
# 841                                                None        v1.0
# 845                                                None        v1.0
# 851                                                None        v1.0
# 859                                                None        v1.0
# 892                                                None        v1.0
# 894                                                None        v1.0
# 895   Possible pipeline error - should be no identic...        v1.0
# 898                                                None        v1.0
# 924                                                None        v1.0
# 926                                                None        v1.0
# 931                                                None        v1.0
# 939                                                None        v1.0
# 940                                                None        v1.0
# 972                                                None        v1.0
# 1058                                               None        v1.0
# 1062                                               None        v1.0
# 1119  Possible pipeline error - should be no identic...        v1.0
# 1120  Possible pipeline error - should be no identic...        v1.0
# 1124                                               None        v1.0
# 1208                                               None        v1.0
# 1218                                               None        v1.0
# 1236                                               None        v1.0
#
#                           pair_key        label
# 0       (CHEBI_17521, CHEBI_36124)  Enantiomers
# 117     (CHEBI_27372, CHEBI_27374)  Enantiomers
# 184   (CHEBI_136698, CHEBI_140637)  Enantiomers
# 202     (CHEBI_28548, CHEBI_37209)  Enantiomers
# 203     (CHEBI_16002, CHEBI_47537)  Enantiomers
# 206     (CHEBI_21101, CHEBI_21398)  Enantiomers
# 209     (CHEBI_37546, CHEBI_37547)  Enantiomers
# 210     (CHEBI_21100, CHEBI_21397)  Enantiomers
# 230     (CHEBI_17924, CHEBI_28789)  Enantiomers
# 232   (CHEBI_134311, CHEBI_192698)  Enantiomers
# 252     (CHEBI_15386, CHEBI_37465)  Enantiomers
# 275     (CHEBI_37476, CHEBI_37477)  Enantiomers
# 312      (CHEBI_3332, CHEBI_38969)  Enantiomers
# 333    (CHEBI_229701, CHEBI_57906)  Enantiomers
# 379   (CHEBI_167675, CHEBI_167676)  Enantiomers
# 387     (CHEBI_90389, CHEBI_90391)  Enantiomers
# 388     (CHEBI_90394, CHEBI_90395)  Enantiomers
# 392    (CHEBI_232288, CHEBI_76864)  Enantiomers
# 394   (CHEBI_138619, CHEBI_144940)  Enantiomers
# 402   (CHEBI_189871, CHEBI_189872)  Enantiomers
# 406    (CHEBI_137932, CHEBI_17426)  Enantiomers
# 413     (CHEBI_88303, CHEBI_88304)  Enantiomers
# 414     (CHEBI_90386, CHEBI_90387)  Enantiomers
# 456   (CHEBI_132913, CHEBI_132914)  Enantiomers
# 467     (CHEBI_39335, CHEBI_39336)  Enantiomers
# 484     (CHEBI_64020, CHEBI_64021)  Enantiomers
# 485   (CHEBI_132915, CHEBI_132916)  Enantiomers
# 579     (CHEBI_15387, CHEBI_18481)  Enantiomers
# 580    (CHEBI_15414, CHEBI_156255)  Enantiomers
# 689     (CHEBI_63695, CHEBI_63698)  Enantiomers
# 690     (CHEBI_63700, CHEBI_63705)  Enantiomers
# 696   (CHEBI_167901, CHEBI_167910)  Enantiomers
# 717    (CHEBI_195630, CHEBI_76640)  Enantiomers
# 786     (CHEBI_38139, CHEBI_44343)  Enantiomers
# 789     (CHEBI_39309, CHEBI_39313)  Enantiomers
# 793     (CHEBI_38153, CHEBI_38154)  Enantiomers
# 837   (CHEBI_194351, CHEBI_194352)  Enantiomers
# 841   (CHEBI_195223, CHEBI_195225)  Enantiomers
# 845    (CHEBI_157606, CHEBI_72758)  Enantiomers
# 851     (CHEBI_50146, CHEBI_50147)  Enantiomers
# 859    (CHEBI_232532, CHEBI_76557)  Enantiomers
# 892     (CHEBI_46987, CHEBI_46995)  Enantiomers
# 894     (CHEBI_27476, CHEBI_47012)  Enantiomers
# 895     (CHEBI_47008, CHEBI_47011)  Enantiomers
# 898     (CHEBI_77599, CHEBI_77604)  Enantiomers
# 924   (CHEBI_144379, CHEBI_144384)  Enantiomers
# 926    (CHEBI_183806, CHEBI_81467)  Enantiomers
# 931    (CHEBI_193571, CHEBI_57463)  Enantiomers
# 939   (CHEBI_167882, CHEBI_167883)  Enantiomers
# 940     (CHEBI_32922, CHEBI_35440)  Enantiomers
# 972    (CHEBI_231528, CHEBI_70980)  Enantiomers
# 1058    (CHEBI_50931, CHEBI_50932)  Enantiomers
# 1062  (CHEBI_140636, CHEBI_140638)  Enantiomers
# 1119    (CHEBI_83130, CHEBI_83132)  Enantiomers
# 1120    (CHEBI_83129, CHEBI_83131)  Enantiomers
# 1124  (CHEBI_231949, CHEBI_231950)  Enantiomers
# 1208    (CHEBI_67233, CHEBI_67234)  Enantiomers
# 1218  (CHEBI_138601, CHEBI_138641)  Enantiomers
# 1236    (CHEBI_27669, CHEBI_38200)  Enantiomers

# %%
df_fp['classification'].value_counts()
# Out:
# classification
# Diastereomers              37
# Stereo-resolution pairs    16
# Unresolved                  5
# Unclassified                1
# Name: count, dtype: int64

# %%
df_fp_dia = df_fp[df_fp['classification'] == "Diastereomers"]
df_fp_dia
# Out:
#                id1           id2  cluster_a  cluster_b cluster_a_members  \
# 0      CHEBI_17521   CHEBI_36124          1          2   ["chebi:17521"]
# 117    CHEBI_27374   CHEBI_27372        232        233   ["chebi:27374"]
# 184   CHEBI_140637  CHEBI_136698        364        365  ["chebi:140637"]
# 202    CHEBI_28548   CHEBI_37209        400        401   ["chebi:28548"]
# 203    CHEBI_16002   CHEBI_47537        402        404   ["chebi:16002"]
# 206    CHEBI_21101   CHEBI_21398        406        409   ["chebi:21101"]
# 209    CHEBI_37546   CHEBI_37547        412        416   ["chebi:37546"]
# 210    CHEBI_21100   CHEBI_21397        413        417   ["chebi:21100"]
# 230    CHEBI_17924   CHEBI_28789        456        457   ["chebi:17924"]
# 232   CHEBI_134311  CHEBI_192698        459        461  ["chebi:134311"]
# 333   CHEBI_229701   CHEBI_57906        663        664  ["chebi:229701"]
# 379   CHEBI_167675  CHEBI_167676        754        755  ["chebi:167675"]
# 392    CHEBI_76864  CHEBI_232288        781        782   ["chebi:76864"]
# 394   CHEBI_138619  CHEBI_144940        785        786  ["chebi:138619"]
# 456   CHEBI_132914  CHEBI_132913        910        911  ["chebi:132914"]
# 484    CHEBI_64020   CHEBI_64021        966        968   ["chebi:64020"]
# 485   CHEBI_132915  CHEBI_132916        967        969  ["chebi:132915"]
# 579    CHEBI_18481   CHEBI_15387       1152       1153   ["chebi:18481"]
# 580   CHEBI_156255   CHEBI_15414       1154       1155  ["chebi:156255"]
# 696   CHEBI_167910  CHEBI_167901       1384       1385  ["chebi:167910"]
# 837   CHEBI_194352  CHEBI_194351       1665       1666  ["chebi:194352"]
# 841   CHEBI_195225  CHEBI_195223       1673       1674  ["chebi:195225"]
# 845    CHEBI_72758  CHEBI_157606       1681       1682   ["chebi:72758"]
# 851    CHEBI_50146   CHEBI_50147       1693       1694   ["chebi:50146"]
# 859    CHEBI_76557  CHEBI_232532       1709       1710   ["chebi:76557"]
# 892    CHEBI_46987   CHEBI_46995       1775       1781   ["chebi:46987"]
# 894    CHEBI_47012   CHEBI_27476       1777       1779   ["chebi:47012"]
# 926   CHEBI_183806   CHEBI_81467       1843       1844  ["chebi:183806"]
# 931   CHEBI_193571   CHEBI_57463       1853       1854  ["chebi:193571"]
# 939   CHEBI_167883  CHEBI_167882       1867       1868  ["chebi:167883"]
# 972    CHEBI_70980  CHEBI_231528       1931       1932   ["chebi:70980"]
# 1058   CHEBI_50931   CHEBI_50932       2102       2103   ["chebi:50931"]
# 1062  CHEBI_140638  CHEBI_140636       2108       2109  ["chebi:140638"]
# 1124  CHEBI_231949  CHEBI_231950       2228       2229  ["chebi:231949"]
# 1208   CHEBI_67234   CHEBI_67233       2395       2396   ["chebi:67234"]
# 1218  CHEBI_138601  CHEBI_138641       2415       2416  ["chebi:138601"]
# 1236   CHEBI_27669   CHEBI_38200       2451       2452   ["chebi:27669"]
#
#      cluster_b_members  cluster_a_size  cluster_b_size classification  score  \
# 0      ["chebi:36124"]               1               1  Diastereomers  100.0
# 117    ["chebi:27372"]               1               1  Diastereomers  100.0
# 184   ["chebi:136698"]               1               1  Diastereomers  100.0
# 202    ["chebi:37209"]               1               1  Diastereomers  100.0
# 203    ["chebi:47537"]               1               1  Diastereomers  100.0
# 206    ["chebi:21398"]               1               1  Diastereomers  100.0
# 209    ["chebi:37547"]               1               1  Diastereomers  100.0
# 210    ["chebi:21397"]               1               1  Diastereomers  100.0
# 230    ["chebi:28789"]               1               1  Diastereomers  100.0
# 232   ["chebi:192698"]               1               1  Diastereomers  100.0
# 333    ["chebi:57906"]               1               1  Diastereomers  100.0
# 379   ["chebi:167676"]               1               1  Diastereomers  100.0
# 392   ["chebi:232288"]               1               1  Diastereomers  100.0
# 394   ["chebi:144940"]               1               1  Diastereomers  100.0
# 456   ["chebi:132913"]               1               1  Diastereomers  100.0
# 484    ["chebi:64021"]               1               1  Diastereomers  100.0
# 485   ["chebi:132916"]               1               1  Diastereomers  100.0
# 579    ["chebi:15387"]               1               1  Diastereomers  100.0
# 580    ["chebi:15414"]               1               1  Diastereomers  100.0
# 696   ["chebi:167901"]               1               1  Diastereomers  100.0
# 837   ["chebi:194351"]               1               1  Diastereomers  100.0
# 841   ["chebi:195223"]               1               1  Diastereomers  100.0
# 845   ["chebi:157606"]               1               1  Diastereomers   77.0
# 851    ["chebi:50147"]               1               1  Diastereomers  100.0
# 859   ["chebi:232532"]               1               1  Diastereomers  100.0
# 892    ["chebi:46995"]               1               1  Diastereomers  100.0
# 894    ["chebi:27476"]               1               1  Diastereomers  100.0
# 926    ["chebi:81467"]               1               1  Diastereomers  100.0
# 931    ["chebi:57463"]               1               1  Diastereomers  100.0
# 939   ["chebi:167882"]               1               1  Diastereomers  100.0
# 972   ["chebi:231528"]               1               1  Diastereomers  100.0
# 1058   ["chebi:50932"]               1               1  Diastereomers   77.0
# 1062  ["chebi:140636"]               1               1  Diastereomers  100.0
# 1124  ["chebi:231950"]               1               1  Diastereomers  100.0
# 1208   ["chebi:67233"]               1               1  Diastereomers  100.0
# 1218  ["chebi:138641"]               1               1  Diastereomers  100.0
# 1236   ["chebi:38200"]               1               1  Diastereomers  100.0
#
#                     score_details extra_info version_tag  \
# 0       {"confidence_bin":"high"}       None        v1.0
# 117     {"confidence_bin":"high"}       None        v1.0
# 184     {"confidence_bin":"high"}       None        v1.0
# 202     {"confidence_bin":"high"}       None        v1.0
# 203     {"confidence_bin":"high"}       None        v1.0
# 206     {"confidence_bin":"high"}       None        v1.0
# 209     {"confidence_bin":"high"}       None        v1.0
# 210     {"confidence_bin":"high"}       None        v1.0
# 230     {"confidence_bin":"high"}       None        v1.0
# 232     {"confidence_bin":"high"}       None        v1.0
# 333     {"confidence_bin":"high"}       None        v1.0
# 379     {"confidence_bin":"high"}       None        v1.0
# 392     {"confidence_bin":"high"}       None        v1.0
# 394     {"confidence_bin":"high"}       None        v1.0
# 456     {"confidence_bin":"high"}       None        v1.0
# 484     {"confidence_bin":"high"}       None        v1.0
# 485     {"confidence_bin":"high"}       None        v1.0
# 579     {"confidence_bin":"high"}       None        v1.0
# 580     {"confidence_bin":"high"}       None        v1.0
# 696     {"confidence_bin":"high"}       None        v1.0
# 837     {"confidence_bin":"high"}       None        v1.0
# 841     {"confidence_bin":"high"}       None        v1.0
# 845   {"confidence_bin":"medium"}       None        v1.0
# 851     {"confidence_bin":"high"}       None        v1.0
# 859     {"confidence_bin":"high"}       None        v1.0
# 892     {"confidence_bin":"high"}       None        v1.0
# 894     {"confidence_bin":"high"}       None        v1.0
# 926     {"confidence_bin":"high"}       None        v1.0
# 931     {"confidence_bin":"high"}       None        v1.0
# 939     {"confidence_bin":"high"}       None        v1.0
# 972     {"confidence_bin":"high"}       None        v1.0
# 1058  {"confidence_bin":"medium"}       None        v1.0
# 1062    {"confidence_bin":"high"}       None        v1.0
# 1124    {"confidence_bin":"high"}       None        v1.0
# 1208    {"confidence_bin":"high"}       None        v1.0
# 1218    {"confidence_bin":"high"}       None        v1.0
# 1236    {"confidence_bin":"high"}       None        v1.0
#
#                           pair_key        label
# 0       (CHEBI_17521, CHEBI_36124)  Enantiomers
# 117     (CHEBI_27372, CHEBI_27374)  Enantiomers
# 184   (CHEBI_136698, CHEBI_140637)  Enantiomers
# 202     (CHEBI_28548, CHEBI_37209)  Enantiomers
# 203     (CHEBI_16002, CHEBI_47537)  Enantiomers
# 206     (CHEBI_21101, CHEBI_21398)  Enantiomers
# 209     (CHEBI_37546, CHEBI_37547)  Enantiomers
# 210     (CHEBI_21100, CHEBI_21397)  Enantiomers
# 230     (CHEBI_17924, CHEBI_28789)  Enantiomers
# 232   (CHEBI_134311, CHEBI_192698)  Enantiomers
# 333    (CHEBI_229701, CHEBI_57906)  Enantiomers
# 379   (CHEBI_167675, CHEBI_167676)  Enantiomers
# 392    (CHEBI_232288, CHEBI_76864)  Enantiomers
# 394   (CHEBI_138619, CHEBI_144940)  Enantiomers
# 456   (CHEBI_132913, CHEBI_132914)  Enantiomers
# 484     (CHEBI_64020, CHEBI_64021)  Enantiomers
# 485   (CHEBI_132915, CHEBI_132916)  Enantiomers
# 579     (CHEBI_15387, CHEBI_18481)  Enantiomers
# 580    (CHEBI_15414, CHEBI_156255)  Enantiomers
# 696   (CHEBI_167901, CHEBI_167910)  Enantiomers
# 837   (CHEBI_194351, CHEBI_194352)  Enantiomers
# 841   (CHEBI_195223, CHEBI_195225)  Enantiomers
# 845    (CHEBI_157606, CHEBI_72758)  Enantiomers
# 851     (CHEBI_50146, CHEBI_50147)  Enantiomers
# 859    (CHEBI_232532, CHEBI_76557)  Enantiomers
# 892     (CHEBI_46987, CHEBI_46995)  Enantiomers
# 894     (CHEBI_27476, CHEBI_47012)  Enantiomers
# 926    (CHEBI_183806, CHEBI_81467)  Enantiomers
# 931    (CHEBI_193571, CHEBI_57463)  Enantiomers
# 939   (CHEBI_167882, CHEBI_167883)  Enantiomers
# 972    (CHEBI_231528, CHEBI_70980)  Enantiomers
# 1058    (CHEBI_50931, CHEBI_50932)  Enantiomers
# 1062  (CHEBI_140636, CHEBI_140638)  Enantiomers
# 1124  (CHEBI_231949, CHEBI_231950)  Enantiomers
# 1208    (CHEBI_67233, CHEBI_67234)  Enantiomers
# 1218  (CHEBI_138601, CHEBI_138641)  Enantiomers
# 1236    (CHEBI_27669, CHEBI_38200)  Enantiomers

# %% [markdown]
# Lets investigate these cases manually to determine what went wrong.

# %% [markdown]
# Upon manual review, it has been determined that 23 out of the 37 pairs are deemed to be actual correct predictions by the stereomapper pipeline. An the 23 cases, each has been identified to be a mistake in assignment by ChEBI. Most of these relationships are indeed diastereomers, whilst others contain missing stereochemistry, which is picked up by the stereomapper pipeline. In one case, two structures are indeed enantiomers, but the two structures actually share different formal charges meaning they are not deemed enantiomers by the pipeline.
#
# In reality, when accounting for these disagreements, stereomapper has the actual precision, recall and F1 score accounted for below:

# %%
df_fp_parent_child = df_fp[df_fp['classification'] == "Stereo-resolution pairs"]
df_fp_parent_child
# Out:
#               id1           id2  cluster_a  cluster_b cluster_a_members  \
# 275   CHEBI_37477   CHEBI_37476        547        549   ["chebi:37477"]
# 312   CHEBI_38969    CHEBI_3332        621        622   ["chebi:38969"]
# 387   CHEBI_90389   CHEBI_90391        771        772   ["chebi:90389"]
# 388   CHEBI_90394   CHEBI_90395        773        774   ["chebi:90394"]
# 402  CHEBI_189872  CHEBI_189871        801        802  ["chebi:189872"]
# 406   CHEBI_17426  CHEBI_137932        809        810   ["chebi:17426"]
# 414   CHEBI_90386   CHEBI_90387        826        827   ["chebi:90386"]
# 467   CHEBI_39336   CHEBI_39335        931        932   ["chebi:39336"]
# 689   CHEBI_63698   CHEBI_63695       1370       1373   ["chebi:63698"]
# 690   CHEBI_63705   CHEBI_63700       1371       1372   ["chebi:63705"]
# 717  CHEBI_195630   CHEBI_76640       1426       1427  ["chebi:195630"]
# 789   CHEBI_39309   CHEBI_39313       1569       1570   ["chebi:39309"]
# 793   CHEBI_38154   CHEBI_38153       1578       1579   ["chebi:38154"]
# 898   CHEBI_77599   CHEBI_77604       1787       1788   ["chebi:77599"]
# 924  CHEBI_144384  CHEBI_144379       1839       1840  ["chebi:144384"]
# 940   CHEBI_32922   CHEBI_35440       1869       1870   ["chebi:32922"]
#
#     cluster_b_members  cluster_a_size  cluster_b_size  \
# 275   ["chebi:37476"]               1               1
# 312    ["chebi:3332"]               1               1
# 387   ["chebi:90391"]               1               1
# 388   ["chebi:90395"]               1               1
# 402  ["chebi:189871"]               1               1
# 406  ["chebi:137932"]               1               1
# 414   ["chebi:90387"]               1               1
# 467   ["chebi:39335"]               1               1
# 689   ["chebi:63695"]               1               1
# 690   ["chebi:63700"]               1               1
# 717   ["chebi:76640"]               1               1
# 789   ["chebi:39313"]               1               1
# 793   ["chebi:38153"]               1               1
# 898   ["chebi:77604"]               1               1
# 924  ["chebi:144379"]               1               1
# 940   ["chebi:35440"]               1               1
#
#               classification  score                score_details extra_info  \
# 275  Stereo-resolution pairs  100.0    {"confidence_bin":"high"}       None
# 312  Stereo-resolution pairs  100.0    {"confidence_bin":"high"}       None
# 387  Stereo-resolution pairs   75.0  {"confidence_bin":"medium"}       None
# 388  Stereo-resolution pairs   75.0  {"confidence_bin":"medium"}       None
# 402  Stereo-resolution pairs  100.0    {"confidence_bin":"high"}       None
# 406  Stereo-resolution pairs  100.0    {"confidence_bin":"high"}       None
# 414  Stereo-resolution pairs   75.0  {"confidence_bin":"medium"}       None
# 467  Stereo-resolution pairs   76.0  {"confidence_bin":"medium"}       None
# 689  Stereo-resolution pairs   77.0  {"confidence_bin":"medium"}       None
# 690  Stereo-resolution pairs   77.0  {"confidence_bin":"medium"}       None
# 717  Stereo-resolution pairs  100.0    {"confidence_bin":"high"}       None
# 789  Stereo-resolution pairs   76.0  {"confidence_bin":"medium"}       None
# 793  Stereo-resolution pairs   76.0  {"confidence_bin":"medium"}       None
# 898  Stereo-resolution pairs   94.0    {"confidence_bin":"high"}       None
# 924  Stereo-resolution pairs  100.0    {"confidence_bin":"high"}       None
# 940  Stereo-resolution pairs   79.0  {"confidence_bin":"medium"}       None
#
#     version_tag                      pair_key        label
# 275        v1.0    (CHEBI_37476, CHEBI_37477)  Enantiomers
# 312        v1.0     (CHEBI_3332, CHEBI_38969)  Enantiomers
# 387        v1.0    (CHEBI_90389, CHEBI_90391)  Enantiomers
# 388        v1.0    (CHEBI_90394, CHEBI_90395)  Enantiomers
# 402        v1.0  (CHEBI_189871, CHEBI_189872)  Enantiomers
# 406        v1.0   (CHEBI_137932, CHEBI_17426)  Enantiomers
# 414        v1.0    (CHEBI_90386, CHEBI_90387)  Enantiomers
# 467        v1.0    (CHEBI_39335, CHEBI_39336)  Enantiomers
# 689        v1.0    (CHEBI_63695, CHEBI_63698)  Enantiomers
# 690        v1.0    (CHEBI_63700, CHEBI_63705)  Enantiomers
# 717        v1.0   (CHEBI_195630, CHEBI_76640)  Enantiomers
# 789        v1.0    (CHEBI_39309, CHEBI_39313)  Enantiomers
# 793        v1.0    (CHEBI_38153, CHEBI_38154)  Enantiomers
# 898        v1.0    (CHEBI_77599, CHEBI_77604)  Enantiomers
# 924        v1.0  (CHEBI_144379, CHEBI_144384)  Enantiomers
# 940        v1.0    (CHEBI_32922, CHEBI_35440)  Enantiomers

# %% [markdown]
# All are incorrect predictions by StereoMapper.

# %%
df_fp_unresolved = df_fp[df_fp['classification'] == "Unresolved"]
df_fp_unresolved
# Out:
#               id1          id2  cluster_a  cluster_b cluster_a_members  \
# 252   CHEBI_37465  CHEBI_15386        501        503   ["chebi:37465"]
# 786   CHEBI_38139  CHEBI_44343       1564       1566   ["chebi:38139"]
# 895   CHEBI_47008  CHEBI_47011       1778       1780   ["chebi:47008"]
# 1119  CHEBI_83132  CHEBI_83130       2218       2219   ["chebi:83132"]
# 1120  CHEBI_83131  CHEBI_83129       2220       2221   ["chebi:83131"]
#
#      cluster_b_members  cluster_a_size  cluster_b_size classification  score  \
# 252    ["chebi:15386"]               1               1     Unresolved  100.0
# 786    ["chebi:44343"]               1               1     Unresolved  100.0
# 895    ["chebi:47011"]               1               1     Unresolved  100.0
# 1119   ["chebi:83130"]               1               1     Unresolved   75.0
# 1120   ["chebi:83129"]               1               1     Unresolved   75.0
#
#                     score_details  \
# 252     {"confidence_bin":"high"}
# 786     {"confidence_bin":"high"}
# 895     {"confidence_bin":"high"}
# 1119  {"confidence_bin":"medium"}
# 1120  {"confidence_bin":"medium"}
#
#                                              extra_info version_tag  \
# 252   Possible pipeline error - should be no identic...        v1.0
# 786   Possible pipeline error - should be no identic...        v1.0
# 895   Possible pipeline error - should be no identic...        v1.0
# 1119  Possible pipeline error - should be no identic...        v1.0
# 1120  Possible pipeline error - should be no identic...        v1.0
#
#                         pair_key        label
# 252   (CHEBI_15386, CHEBI_37465)  Enantiomers
# 786   (CHEBI_38139, CHEBI_44343)  Enantiomers
# 895   (CHEBI_47008, CHEBI_47011)  Enantiomers
# 1119  (CHEBI_83130, CHEBI_83132)  Enantiomers
# 1120  (CHEBI_83129, CHEBI_83131)  Enantiomers

# %% [markdown]
# all incorrect by StereoMapper. the single unclassified case is a complex case where stereochemistry differs, but so does protonation states.

# %%
# 23 for corrected FP in diastereomers, 1 for corrected FP in unclassified
tp_act = tp + 24
fp_act = fp - 24

enantiomer_actual_precision = tp_act / (tp_act + fp_act) if (tp_act + fp_act) > 0 else 0
enantiomer_actual_recall = tp_act / (tp_act + fn) if (tp_act + fn) > 0 else 0
enantiomer_actual_f1 = 2 * enantiomer_actual_precision * enantiomer_actual_recall / (enantiomer_actual_precision + enantiomer_actual_recall) if (enantiomer_actual_precision + enantiomer_actual_recall) > 0 else 0

print(f"Adjusted Precision: {enantiomer_actual_precision:.3f}")
print(f"Adjusted Recall:    {enantiomer_actual_recall:.3f}")
print(f"Adjusted F1 score:  {enantiomer_actual_f1:.3f}")
# Out:
# Adjusted Precision: 0.972
# Adjusted Recall:    1.000
# Adjusted F1 score:  0.986

# %% [markdown]
# ## Diastereomer benchmarking

# %%
control_pairs_dia =  'data/diastereomer_control_set.csv'
df_dia = pd.read_csv(control_pairs_dia)
df_dia
# Out:
#                id1           id2          label
# 0     CHEBI_122389  CHEBI_122317  Diastereomers
# 1     CHEBI_216464  CHEBI_215732  Diastereomers
# 2     CHEBI_120133  CHEBI_120171  Diastereomers
# 3      CHEBI_96557   CHEBI_96022  Diastereomers
# 4     CHEBI_112617  CHEBI_112586  Diastereomers
# ...            ...           ...            ...
# 3092  CHEBI_199087  CHEBI_203717  Diastereomers
# 3093  CHEBI_207142  CHEBI_215860  Diastereomers
# 3094   CHEBI_18809   CHEBI_18624  Diastereomers
# 3095  CHEBI_195839  CHEBI_195840  Diastereomers
# 3096  CHEBI_140655  CHEBI_138945  Diastereomers
#
# [3097 rows x 3 columns]

# %%
# 1) Canonicalize + dedupe control set
dfc_dia = df_dia.copy()
dfc_dia["id1_c"] = dfc_dia["id1"].map(norm_chebi)
dfc_dia["id2_c"] = dfc_dia["id2"].map(norm_chebi)
# order-invariant canonical pair (tuple sorted)
dfc_dia["pair_key"] = dfc_dia.apply(lambda r: tuple(sorted((r["id1_c"], r["id2_c"]))), axis=1)
# keep one row per unordered pair (optionally verify labels agree before dropping)
dfc_dedup_dia = dfc_dia.drop_duplicates(subset=["pair_key"]).reset_index(drop=True)

control_keys_dia = set(dfc_dedup_dia["pair_key"])

dfc_dedup_dia
# Out:
#                id1           id2          label         id1_c         id2_c  \
# 0     CHEBI_122389  CHEBI_122317  Diastereomers  CHEBI_122389  CHEBI_122317
# 1     CHEBI_216464  CHEBI_215732  Diastereomers  CHEBI_216464  CHEBI_215732
# 2     CHEBI_120133  CHEBI_120171  Diastereomers  CHEBI_120133  CHEBI_120171
# 3      CHEBI_96557   CHEBI_96022  Diastereomers   CHEBI_96557   CHEBI_96022
# 4     CHEBI_112617  CHEBI_112586  Diastereomers  CHEBI_112617  CHEBI_112586
# ...            ...           ...            ...           ...           ...
# 3092  CHEBI_199087  CHEBI_203717  Diastereomers  CHEBI_199087  CHEBI_203717
# 3093  CHEBI_207142  CHEBI_215860  Diastereomers  CHEBI_207142  CHEBI_215860
# 3094   CHEBI_18809   CHEBI_18624  Diastereomers   CHEBI_18809   CHEBI_18624
# 3095  CHEBI_195839  CHEBI_195840  Diastereomers  CHEBI_195839  CHEBI_195840
# 3096  CHEBI_140655  CHEBI_138945  Diastereomers  CHEBI_140655  CHEBI_138945
#
#                           pair_key
# 0     (CHEBI_122317, CHEBI_122389)
# 1     (CHEBI_215732, CHEBI_216464)
# 2     (CHEBI_120133, CHEBI_120171)
# 3       (CHEBI_96022, CHEBI_96557)
# 4     (CHEBI_112586, CHEBI_112617)
# ...                            ...
# 3092  (CHEBI_199087, CHEBI_203717)
# 3093  (CHEBI_207142, CHEBI_215860)
# 3094    (CHEBI_18624, CHEBI_18809)
# 3095  (CHEBI_195839, CHEBI_195840)
# 3096  (CHEBI_138945, CHEBI_140655)
#
# [3097 rows x 6 columns]

# %%
# run stereomapper as a subprocess
diastereomers = Path('/home/jackmcgoldrick/Downloads/benchmarking_data/diastereomer_benchmark_data') # downloadable from Zenodo (DOI: 10.5281/zenodo.17831412)
results = Path('diastereomer_benchmark_results.sqlite') 
cache_path = Path('diastereomer_benchmark_cache.sqlite')

# %%
cmd =[
    "stereomapper",
    "run",
    "-d", diastereomers.as_posix(),
    "-o", results.as_posix(),
    "-p", cache_path.as_posix(),
    "--fresh-cache"
]

subprocess.run(cmd)
# Out:
# INFO    Logging initialised. File: logs/stereomapper_20251215_103717.log
# Pipeline: 100%|██████████████████████████████████████████████████████████| , Complete! [00:31<00:00]
# ✅ Pipeline completed in 31.8s
# 📦 Inputs attempted: 6,192 (skipped 0)
# 📊 Successes: 6,192 | Failures: 0
# 🔗 Inchikey groups — processed 3,071, skipped 0, failed 0
# 🧮 Relationship rows: 3,187
# 🧾 Unique inchikeys observed: 3,071
# 💾 Cache hit rate: 0.0%
# Pipeline: 100%|██████████████████████████████████████████████████████████| , Complete! [00:32<00:00]
# CompletedProcess(args=['stereomapper', 'run', '-d', '/home/jackmcgoldrick/Downloads/benchmarking_data/diastereomer_benchmark_data', '-o', 'diastereomer_benchmark_results.sqlite', '-p', 'diastereomer_benchmark_cache.sqlite', '--fresh-cache'], returncode=0)

# %%
conn = sqlite3.connect(results)
merged_df_q = """ 
SELECT * from relationships;
"""
df_merged_dia = pd.read_sql_query(merged_df_q, conn)
df_merged_dia
# Out:
#       cluster_a  cluster_b cluster_a_members cluster_b_members  \
# 0             1          2  ["chebi:224674"]  ["chebi:219347"]
# 1             3          4    ["chebi:3829"]   ["chebi:81144"]
# 2             5          6   ["chebi:69288"]   ["chebi:69289"]
# 3             7          8  ["chebi:117326"]  ["chebi:117283"]
# 4             9         10   ["chebi:81326"]   ["chebi:81325"]
# ...         ...        ...               ...               ...
# 3182       6178       6179  ["chebi:122230"]  ["chebi:122370"]
# 3183       6180       6181  ["chebi:188987"]  ["chebi:188993"]
# 3184       6182       6183  ["chebi:217768"]  ["chebi:208414"]
# 3185       6184       6185  ["chebi:197905"]  ["chebi:199614"]
# 3186       6186       6187  ["chebi:144780"]  ["chebi:193098"]
#
#       cluster_a_size  cluster_b_size classification  score  \
# 0                  1               1  Diastereomers  100.0
# 1                  1               1  Diastereomers  100.0
# 2                  1               1  Diastereomers  100.0
# 3                  1               1  Diastereomers  100.0
# 4                  1               1  Diastereomers  100.0
# ...              ...             ...            ...    ...
# 3182               1               1  Diastereomers  100.0
# 3183               1               1  Diastereomers  100.0
# 3184               1               1  Diastereomers  100.0
# 3185               1               1  Diastereomers  100.0
# 3186               1               1  Diastereomers  100.0
#
#                   score_details extra_info version_tag
# 0     {"confidence_bin":"high"}       None        v1.0
# 1     {"confidence_bin":"high"}       None        v1.0
# 2     {"confidence_bin":"high"}       None        v1.0
# 3     {"confidence_bin":"high"}       None        v1.0
# 4     {"confidence_bin":"high"}       None        v1.0
# ...                         ...        ...         ...
# 3182  {"confidence_bin":"high"}       None        v1.0
# 3183  {"confidence_bin":"high"}       None        v1.0
# 3184  {"confidence_bin":"high"}       None        v1.0
# 3185  {"confidence_bin":"high"}       None        v1.0
# 3186  {"confidence_bin":"high"}       None        v1.0
#
# [3187 rows x 11 columns]

# %%
# compare back to original df, to permit calculation of accuracy
expanded_keys = set()
for _, row in df_merged_dia.iterrows():
    if not row["cluster_a_members"] or not row["cluster_b_members"]:
        continue
    m1s = [norm_chebi(x) for x in json.loads(row["cluster_a_members"])]
    m2s = [norm_chebi(x) for x in json.loads(row["cluster_b_members"])]
    for a in m1s:
        for b in m2s:
            if a == b:
                continue
            expanded_keys.add(tuple(sorted((a, b))))

# --- Overlap ---
tp = control_keys_dia & expanded_keys
fp = expanded_keys - control_keys_dia
fn = control_keys_dia - expanded_keys

print(f"True Positives: {len(tp)}")
print(f"False Positives: {len(fp)}")
print(f"False Negatives: {len(fn)}")
# Out:
# True Positives: 3096
# False Positives: 99
# False Negatives: 1

# %%
# extract the rows that correspond to the control set only
# valid pairs are those in the control set

valid_pairs = control_keys_dia

df_pred_filtered = []
for _, row in df_merged_dia.iterrows():
    members_1 = [norm_chebi(x) for x in json.loads(row["cluster_a_members"])]
    members_2 = [norm_chebi(x) for x in json.loads(row["cluster_b_members"])]
    for a in members_1:
        for b in members_2:
            pair = tuple(sorted((a, b)))
            if pair in valid_pairs:
                df_pred_filtered.append({"id1": a, "id2": b, **row.to_dict()})

df_pred_filtered = pd.DataFrame(df_pred_filtered)

# %%
df_pred_filtered = df_pred_filtered.copy()
df_pred_filtered["pair_key"] = df_pred_filtered.apply(
    lambda r: tuple(sorted([norm_chebi(r["id1"]), norm_chebi(r["id2"])])), axis=1
)

df_eval = dfc_dia.merge(
    df_pred_filtered[["pair_key", "classification", "score"]],
    on="pair_key",
    how="left",
    suffixes=("_true", "_pred")
)

df_eval
# Out:
#                id1           id2          label         id1_c         id2_c  \
# 0     CHEBI_122389  CHEBI_122317  Diastereomers  CHEBI_122389  CHEBI_122317
# 1     CHEBI_216464  CHEBI_215732  Diastereomers  CHEBI_216464  CHEBI_215732
# 2     CHEBI_120133  CHEBI_120171  Diastereomers  CHEBI_120133  CHEBI_120171
# 3      CHEBI_96557   CHEBI_96022  Diastereomers   CHEBI_96557   CHEBI_96022
# 4     CHEBI_112617  CHEBI_112586  Diastereomers  CHEBI_112617  CHEBI_112586
# ...            ...           ...            ...           ...           ...
# 3092  CHEBI_199087  CHEBI_203717  Diastereomers  CHEBI_199087  CHEBI_203717
# 3093  CHEBI_207142  CHEBI_215860  Diastereomers  CHEBI_207142  CHEBI_215860
# 3094   CHEBI_18809   CHEBI_18624  Diastereomers   CHEBI_18809   CHEBI_18624
# 3095  CHEBI_195839  CHEBI_195840  Diastereomers  CHEBI_195839  CHEBI_195840
# 3096  CHEBI_140655  CHEBI_138945  Diastereomers  CHEBI_140655  CHEBI_138945
#
#                           pair_key           classification  score
# 0     (CHEBI_122317, CHEBI_122389)            Diastereomers  100.0
# 1     (CHEBI_215732, CHEBI_216464)            Diastereomers  100.0
# 2     (CHEBI_120133, CHEBI_120171)            Diastereomers  100.0
# 3       (CHEBI_96022, CHEBI_96557)            Diastereomers  100.0
# 4     (CHEBI_112586, CHEBI_112617)  Stereo-resolution pairs   82.0
# ...                            ...                      ...    ...
# 3092  (CHEBI_199087, CHEBI_203717)            Diastereomers  100.0
# 3093  (CHEBI_207142, CHEBI_215860)            Diastereomers   79.0
# 3094    (CHEBI_18624, CHEBI_18809)            Diastereomers   84.0
# 3095  (CHEBI_195839, CHEBI_195840)            Diastereomers   79.0
# 3096  (CHEBI_138945, CHEBI_140655)            Diastereomers  100.0
#
# [3097 rows x 8 columns]

# %%
# only rows where we have a prediction - false negatives are those with no prediction - due to missing /unprocessed files
df_with_pred_dia = df_eval.dropna(subset=["classification"])

tp = ((df_with_pred_dia["classification"] == df_with_pred_dia["label"]).sum())
fp = ((df_with_pred_dia["classification"] != df_with_pred_dia["label"]).sum())
fn = df_eval["classification"].isna().sum()

print(f"TP: {tp}, FP: {fp}, FN: {fn}")
# Out:
# TP: 2902, FP: 194, FN: 1

# %%
# get apparent precision, recall, f1
diastereomer_precision = tp / (tp + fp) if (tp + fp) > 0 else 0
diastereomer_recall = tp / (tp + fn) if (tp + fn) > 0 else 0
diastereomer_f1 = 2 * diastereomer_precision * diastereomer_recall / (diastereomer_precision + diastereomer_recall) if (diastereomer_precision +  
diastereomer_recall) > 0 else 0 

print(f"Precision: {diastereomer_precision:.3f}")
print(f"Recall:    {diastereomer_recall:.4f}")
print(f"F1 score:  {diastereomer_f1:.3f}")
# Out:
# Precision: 0.937
# Recall:    0.9997
# F1 score:  0.967

# %%
df_with_pred_dia[df_with_pred_dia['classification'] != df_with_pred_dia['label']]#.value_counts('classification')b
# Out:
#                id1           id2          label         id1_c         id2_c  \
# 4     CHEBI_112617  CHEBI_112586  Diastereomers  CHEBI_112617  CHEBI_112586
# 11     CHEBI_95659   CHEBI_96178  Diastereomers   CHEBI_95659   CHEBI_96178
# 30    CHEBI_113375   CHEBI_96931  Diastereomers  CHEBI_113375   CHEBI_96931
# 46     CHEBI_95653   CHEBI_96183  Diastereomers   CHEBI_95653   CHEBI_96183
# 51    CHEBI_128319  CHEBI_130426  Diastereomers  CHEBI_128319  CHEBI_130426
# ...            ...           ...            ...           ...           ...
# 2959   CHEBI_70040   CHEBI_70041  Diastereomers   CHEBI_70040   CHEBI_70041
# 2982    CHEBI_2318    CHEBI_5965  Diastereomers    CHEBI_2318    CHEBI_5965
# 2991  CHEBI_217503  CHEBI_203761  Diastereomers  CHEBI_217503  CHEBI_203761
# 3030  CHEBI_230185   CHEBI_31683  Diastereomers  CHEBI_230185   CHEBI_31683
# 3065  CHEBI_130831  CHEBI_127674  Diastereomers  CHEBI_130831  CHEBI_127674
#
#                           pair_key           classification  score
# 4     (CHEBI_112586, CHEBI_112617)  Stereo-resolution pairs   82.0
# 11      (CHEBI_95659, CHEBI_96178)  Stereo-resolution pairs   79.0
# 30     (CHEBI_113375, CHEBI_96931)  Stereo-resolution pairs   85.0
# 46      (CHEBI_95653, CHEBI_96183)  Stereo-resolution pairs   79.0
# 51    (CHEBI_128319, CHEBI_130426)  Stereo-resolution pairs   75.0
# ...                            ...                      ...    ...
# 2959    (CHEBI_70040, CHEBI_70041)  Stereo-resolution pairs   76.0
# 2982      (CHEBI_2318, CHEBI_5965)  Stereo-resolution pairs   76.0
# 2991  (CHEBI_203761, CHEBI_217503)  Stereo-resolution pairs  100.0
# 3030   (CHEBI_230185, CHEBI_31683)             Unclassified    NaN
# 3065  (CHEBI_127674, CHEBI_130831)  Stereo-resolution pairs  100.0
#
# [194 rows x 8 columns]

# %%
# boolean-index the dataframe using pandas Series (use parentheses, not list literals)
df_fp_not_parent_child = df_with_pred_dia[
	(df_with_pred_dia['classification'] != 'Stereo-resolution pairs') &
	(df_with_pred_dia['classification'] != df_with_pred_dia['label'])
]
df_fp_not_parent_child
# Out:
#                id1           id2          label         id1_c         id2_c  \
# 324   CHEBI_196394  CHEBI_187201  Diastereomers  CHEBI_196394  CHEBI_187201
# 338    CHEBI_18237   CHEBI_76051  Diastereomers   CHEBI_18237   CHEBI_76051
# 543   CHEBI_176586   CHEBI_21547  Diastereomers  CHEBI_176586   CHEBI_21547
# 700    CHEBI_16449  CHEBI_132498  Diastereomers   CHEBI_16449  CHEBI_132498
# 701    CHEBI_66916  CHEBI_143534  Diastereomers   CHEBI_66916  CHEBI_143534
# 845   CHEBI_192787  CHEBI_182301  Diastereomers  CHEBI_192787  CHEBI_182301
# 861    CHEBI_16919  CHEBI_231575  Diastereomers   CHEBI_16919  CHEBI_231575
# 902    CHEBI_25017  CHEBI_231582  Diastereomers   CHEBI_25017  CHEBI_231582
# 934     CHEBI_9435  CHEBI_228678  Diastereomers    CHEBI_9435  CHEBI_228678
# 1003   CHEBI_64554  CHEBI_231586  Diastereomers   CHEBI_64554  CHEBI_231586
# 1458  CHEBI_185933   CHEBI_88515  Diastereomers  CHEBI_185933   CHEBI_88515
# 1612  CHEBI_190640  CHEBI_183415  Diastereomers  CHEBI_190640  CHEBI_183415
# 1643  CHEBI_190614  CHEBI_168092  Diastereomers  CHEBI_190614  CHEBI_168092
# 1794   CHEBI_49166   CHEBI_49163  Diastereomers   CHEBI_49166   CHEBI_49163
# 2002  CHEBI_167309  CHEBI_189117  Diastereomers  CHEBI_167309  CHEBI_189117
# 2109  CHEBI_189979  CHEBI_185991  Diastereomers  CHEBI_189979  CHEBI_185991
# 2215   CHEBI_49136   CHEBI_49135  Diastereomers   CHEBI_49136   CHEBI_49135
# 2279  CHEBI_233817   CHEBI_68828  Diastereomers  CHEBI_233817   CHEBI_68828
# 2344   CHEBI_42355  CHEBI_145339  Diastereomers   CHEBI_42355  CHEBI_145339
# 2849  CHEBI_134703  CHEBI_176516  Diastereomers  CHEBI_134703  CHEBI_176516
# 3030  CHEBI_230185   CHEBI_31683  Diastereomers  CHEBI_230185   CHEBI_31683
#
#                           pair_key classification  score
# 324   (CHEBI_187201, CHEBI_196394)   Unclassified    NaN
# 338     (CHEBI_18237, CHEBI_76051)   Unclassified    NaN
# 543    (CHEBI_176586, CHEBI_21547)   Unclassified    NaN
# 700    (CHEBI_132498, CHEBI_16449)   Unclassified    NaN
# 701    (CHEBI_143534, CHEBI_66916)   Unclassified    NaN
# 845   (CHEBI_182301, CHEBI_192787)   Unclassified    NaN
# 861    (CHEBI_16919, CHEBI_231575)   Unclassified    NaN
# 902    (CHEBI_231582, CHEBI_25017)   Unclassified    NaN
# 934     (CHEBI_228678, CHEBI_9435)   Unclassified    NaN
# 1003   (CHEBI_231586, CHEBI_64554)   Unclassified    NaN
# 1458   (CHEBI_185933, CHEBI_88515)   Unclassified    NaN
# 1612  (CHEBI_183415, CHEBI_190640)   Unclassified    NaN
# 1643  (CHEBI_168092, CHEBI_190614)   Unclassified    NaN
# 1794    (CHEBI_49163, CHEBI_49166)   Unclassified    NaN
# 2002  (CHEBI_167309, CHEBI_189117)   Unclassified    NaN
# 2109  (CHEBI_185991, CHEBI_189979)   Unclassified    NaN
# 2215    (CHEBI_49135, CHEBI_49136)   Unclassified    NaN
# 2279   (CHEBI_233817, CHEBI_68828)    Enantiomers  100.0
# 2344   (CHEBI_145339, CHEBI_42355)   Unclassified    NaN
# 2849  (CHEBI_134703, CHEBI_176516)   Unclassified    NaN
# 3030   (CHEBI_230185, CHEBI_31683)   Unclassified    NaN

# %% [markdown]
# 6 mistakenly identified as enantiomers - double check these manually and determine true values.
#
# - CHEBI_2699 and CHEBI_9524 => actual diastereomers
# - CHEBI_50147 and CHEBI_50146 => actual diastereomers
# - CHEBI_48882 and CHEBI_17486 => actual diastereomers
# - CHEBI_15711 and CHEBI_15711 => actual diastereomers
# - CHEBI_85535 and CHEBI_85536 => enantiomers, but wilcard atoms - shouldnt be here
# - CHEBI_233817 and CHEBI_68828 => enantiomers
#
# Therefore, stereomapper incorrectly classifies 4 structures as enantiomers, which are actually diastereomers. Issues likely lie with inchi software, as inchi strings for each pair have the same stereochemical assignments. An obvious limitation of stereomapper is it's reliance on the accuracy of the InChI software.
#
# In terms of the structures containing wildcard atoms, perhaps a more stringent test is required than reliance on rdkit code, maybe a formula check would be sufficient? or a direct check of the molfile?
#
# Lastly, CHEBI_233817 and CHEBI_68828 are indeed enantiomers upon manual review.

# %% [markdown]
# ## Protomer benchmarking

# %%
divese_pairs_df = pd.read_csv('data/protomers_control_set.csv')
divese_pairs_df
# Out:
#            id_left      id_right                     pairkey
# 0      CHEBI_23123   CHEBI_27869    CHEBI_23123__CHEBI_27869
# 1      CHEBI_28240   CHEBI_36386    CHEBI_28240__CHEBI_36386
# 2      CHEBI_27455   CHEBI_30956    CHEBI_27455__CHEBI_30956
# 3      CHEBI_28995   CHEBI_30748    CHEBI_28995__CHEBI_30748
# 4      CHEBI_19984   CHEBI_49410    CHEBI_19984__CHEBI_49410
# ...            ...           ...                         ...
# 3364  CHEBI_234122  CHEBI_234119  CHEBI_234119__CHEBI_234122
# 3365  CHEBI_234323   CHEBI_88950   CHEBI_234323__CHEBI_88950
# 3366  CHEBI_234339  CHEBI_234342  CHEBI_234339__CHEBI_234342
# 3367  CHEBI_234377   CHEBI_32050   CHEBI_234377__CHEBI_32050
# 3368    CHEBI_6506  CHEBI_234341    CHEBI_234341__CHEBI_6506
#
# [3369 rows x 3 columns]

# %%
protomers = Path('/home/jackmcgoldrick/Downloads/benchmarking_data/protomer_benchmark_data')
results = Path('protomer_benchmarking_results.sqlite')
cache = Path('protomer_benchmarking_cache.sqlite')

# %%
cmd =[
    "stereomapper",
    "run",
    "-d", protomers.as_posix(),
    "-o", results.as_posix(),
    "-p", cache_path.as_posix(),
    "--fresh-cache"
]

subprocess.run(cmd)
# Out:
# INFO    Logging initialised. File: logs/stereomapper_20251215_103752.log
# Pipeline: 100%|██████████████████████████████████████████████████████████| , Complete! [00:33<00:00]
# ✅ Pipeline completed in 33.5s
# 📦 Inputs attempted: 6,730 (skipped 0)
# 📊 Successes: 6,728 | Failures: 2
# 🔗 Inchikey groups — processed 3,469, skipped 0, failed 0
# 🧮 Relationship rows: 3,315
# 🧾 Unique inchikeys observed: 3,469
# 💾 Cache hit rate: 0.0%
# Pipeline: 100%|██████████████████████████████████████████████████████████| , Complete! [00:33<00:00]
# CompletedProcess(args=['stereomapper', 'run', '-d', '/home/jackmcgoldrick/Downloads/benchmarking_data/protomer_benchmark_data', '-o', 'protomer_benchmarking_results.sqlite', '-p', 'diastereomer_benchmark_cache.sqlite', '--fresh-cache'], returncode=0)

# %%
conn = sqlite3.connect(results)
merged_df_q = """
SELECT * from relationships;
"""
df_merged_protomer = pd.read_sql_query(merged_df_q, conn)
df_merged_protomer
# Out:
#       cluster_a  cluster_b cluster_a_members cluster_b_members  \
# 0             1          2   ["chebi:52504"]   ["chebi:40617"]
# 1             4          5   ["chebi:17521"]   ["chebi:29751"]
# 2             6          7   ["chebi:18381"]   ["chebi:58467"]
# 3             8          9   ["chebi:33462"]   ["chebi:16215"]
# 4            10         11   ["chebi:64808"]   ["chebi:64790"]
# ...         ...        ...               ...               ...
# 3310       6697       6698   ["chebi:17793"]   ["chebi:77992"]
# 3311       6699       6700  ["chebi:136357"]  ["chebi:133821"]
# 3312       6701       6702   ["chebi:49269"]   ["chebi:58803"]
# 3313       6703       6704   ["chebi:17803"]   ["chebi:58277"]
# 3314       6705       6706   ["chebi:64493"]   ["chebi:64514"]
#
#       cluster_a_size  cluster_b_size classification  score  \
# 0                  1               1      Protomers   74.0
# 1                  1               1      Protomers   91.0
# 2                  1               1      Protomers   96.0
# 3                  1               1      Protomers   89.0
# 4                  1               1      Protomers   93.0
# ...              ...             ...            ...    ...
# 3310               1               1      Protomers   95.0
# 3311               1               1      Protomers   95.0
# 3312               1               1      Protomers   96.0
# 3313               1               1      Protomers   91.0
# 3314               1               1      Protomers   95.0
#
#                     score_details extra_info version_tag
# 0     {"confidence_bin":"medium"}       None        v1.0
# 1       {"confidence_bin":"high"}       None        v1.0
# 2       {"confidence_bin":"high"}       None        v1.0
# 3     {"confidence_bin":"medium"}       None        v1.0
# 4       {"confidence_bin":"high"}       None        v1.0
# ...                           ...        ...         ...
# 3310    {"confidence_bin":"high"}       None        v1.0
# 3311    {"confidence_bin":"high"}       None        v1.0
# 3312    {"confidence_bin":"high"}       None        v1.0
# 3313    {"confidence_bin":"high"}       None        v1.0
# 3314    {"confidence_bin":"high"}       None        v1.0
#
# [3315 rows x 11 columns]

# %%
def norm_protomer_chebi(x):
    if not x:  # empty list or None
        return None
    s = x[0]   # extract from list
    return s.upper().replace(":", "_")


df_merged_protomer["id1_c"] = df_merged_protomer["cluster_a_members"].apply(json.loads).apply(norm_protomer_chebi)
df_merged_protomer["id2_c"] = df_merged_protomer["cluster_b_members"].apply(json.loads).apply(norm_protomer_chebi)

df_merged_protomer["pairkey"] = df_merged_protomer.apply(
    lambda r: "__".join(sorted([r["id1_c"], r["id2_c"]])),
    axis=1
)



df_merged_protomer
# Out:
#       cluster_a  cluster_b cluster_a_members cluster_b_members  \
# 0             1          2   ["chebi:52504"]   ["chebi:40617"]
# 1             4          5   ["chebi:17521"]   ["chebi:29751"]
# 2             6          7   ["chebi:18381"]   ["chebi:58467"]
# 3             8          9   ["chebi:33462"]   ["chebi:16215"]
# 4            10         11   ["chebi:64808"]   ["chebi:64790"]
# ...         ...        ...               ...               ...
# 3310       6697       6698   ["chebi:17793"]   ["chebi:77992"]
# 3311       6699       6700  ["chebi:136357"]  ["chebi:133821"]
# 3312       6701       6702   ["chebi:49269"]   ["chebi:58803"]
# 3313       6703       6704   ["chebi:17803"]   ["chebi:58277"]
# 3314       6705       6706   ["chebi:64493"]   ["chebi:64514"]
#
#       cluster_a_size  cluster_b_size classification  score  \
# 0                  1               1      Protomers   74.0
# 1                  1               1      Protomers   91.0
# 2                  1               1      Protomers   96.0
# 3                  1               1      Protomers   89.0
# 4                  1               1      Protomers   93.0
# ...              ...             ...            ...    ...
# 3310               1               1      Protomers   95.0
# 3311               1               1      Protomers   95.0
# 3312               1               1      Protomers   96.0
# 3313               1               1      Protomers   91.0
# 3314               1               1      Protomers   95.0
#
#                     score_details extra_info version_tag         id1_c  \
# 0     {"confidence_bin":"medium"}       None        v1.0   CHEBI_52504
# 1       {"confidence_bin":"high"}       None        v1.0   CHEBI_17521
# 2       {"confidence_bin":"high"}       None        v1.0   CHEBI_18381
# 3     {"confidence_bin":"medium"}       None        v1.0   CHEBI_33462
# 4       {"confidence_bin":"high"}       None        v1.0   CHEBI_64808
# ...                           ...        ...         ...           ...
# 3310    {"confidence_bin":"high"}       None        v1.0   CHEBI_17793
# 3311    {"confidence_bin":"high"}       None        v1.0  CHEBI_136357
# 3312    {"confidence_bin":"high"}       None        v1.0   CHEBI_49269
# 3313    {"confidence_bin":"high"}       None        v1.0   CHEBI_17803
# 3314    {"confidence_bin":"high"}       None        v1.0   CHEBI_64493
#
#              id2_c                     pairkey
# 0      CHEBI_40617    CHEBI_40617__CHEBI_52504
# 1      CHEBI_29751    CHEBI_17521__CHEBI_29751
# 2      CHEBI_58467    CHEBI_18381__CHEBI_58467
# 3      CHEBI_16215    CHEBI_16215__CHEBI_33462
# 4      CHEBI_64790    CHEBI_64790__CHEBI_64808
# ...            ...                         ...
# 3310   CHEBI_77992    CHEBI_17793__CHEBI_77992
# 3311  CHEBI_133821  CHEBI_133821__CHEBI_136357
# 3312   CHEBI_58803    CHEBI_49269__CHEBI_58803
# 3313   CHEBI_58277    CHEBI_17803__CHEBI_58277
# 3314   CHEBI_64514    CHEBI_64493__CHEBI_64514
#
# [3315 rows x 14 columns]

# %%
merged_protomer = df_merged_protomer.merge(divese_pairs_df[['pairkey']], on='pairkey', how='inner')
merged_protomer
# Out:
#       cluster_a  cluster_b cluster_a_members cluster_b_members  \
# 0             1          2   ["chebi:52504"]   ["chebi:40617"]
# 1             4          5   ["chebi:17521"]   ["chebi:29751"]
# 2             6          7   ["chebi:18381"]   ["chebi:58467"]
# 3             8          9   ["chebi:33462"]   ["chebi:16215"]
# 4            10         11   ["chebi:64808"]   ["chebi:64790"]
# ...         ...        ...               ...               ...
# 3197       6697       6698   ["chebi:17793"]   ["chebi:77992"]
# 3198       6699       6700  ["chebi:136357"]  ["chebi:133821"]
# 3199       6701       6702   ["chebi:49269"]   ["chebi:58803"]
# 3200       6703       6704   ["chebi:17803"]   ["chebi:58277"]
# 3201       6705       6706   ["chebi:64493"]   ["chebi:64514"]
#
#       cluster_a_size  cluster_b_size classification  score  \
# 0                  1               1      Protomers   74.0
# 1                  1               1      Protomers   91.0
# 2                  1               1      Protomers   96.0
# 3                  1               1      Protomers   89.0
# 4                  1               1      Protomers   93.0
# ...              ...             ...            ...    ...
# 3197               1               1      Protomers   95.0
# 3198               1               1      Protomers   95.0
# 3199               1               1      Protomers   96.0
# 3200               1               1      Protomers   91.0
# 3201               1               1      Protomers   95.0
#
#                     score_details extra_info version_tag         id1_c  \
# 0     {"confidence_bin":"medium"}       None        v1.0   CHEBI_52504
# 1       {"confidence_bin":"high"}       None        v1.0   CHEBI_17521
# 2       {"confidence_bin":"high"}       None        v1.0   CHEBI_18381
# 3     {"confidence_bin":"medium"}       None        v1.0   CHEBI_33462
# 4       {"confidence_bin":"high"}       None        v1.0   CHEBI_64808
# ...                           ...        ...         ...           ...
# 3197    {"confidence_bin":"high"}       None        v1.0   CHEBI_17793
# 3198    {"confidence_bin":"high"}       None        v1.0  CHEBI_136357
# 3199    {"confidence_bin":"high"}       None        v1.0   CHEBI_49269
# 3200    {"confidence_bin":"high"}       None        v1.0   CHEBI_17803
# 3201    {"confidence_bin":"high"}       None        v1.0   CHEBI_64493
#
#              id2_c                     pairkey
# 0      CHEBI_40617    CHEBI_40617__CHEBI_52504
# 1      CHEBI_29751    CHEBI_17521__CHEBI_29751
# 2      CHEBI_58467    CHEBI_18381__CHEBI_58467
# 3      CHEBI_16215    CHEBI_16215__CHEBI_33462
# 4      CHEBI_64790    CHEBI_64790__CHEBI_64808
# ...            ...                         ...
# 3197   CHEBI_77992    CHEBI_17793__CHEBI_77992
# 3198  CHEBI_133821  CHEBI_133821__CHEBI_136357
# 3199   CHEBI_58803    CHEBI_49269__CHEBI_58803
# 3200   CHEBI_58277    CHEBI_17803__CHEBI_58277
# 3201   CHEBI_64514    CHEBI_64493__CHEBI_64514
#
# [3202 rows x 14 columns]

# %%
merged_protomer['classification'].value_counts()
# Out:
# classification
# Protomers       3166
# Unclassified      36
# Name: count, dtype: int64

# %%
df_fp_extra_info = merged_protomer[merged_protomer['classification'] != 'Protomers']
df_fp_extra_info
# Out:
#       cluster_a  cluster_b cluster_a_members cluster_b_members  \
# 143         301        302   ["chebi:90408"]   ["chebi:87351"]
# 358         746        747   ["chebi:57438"]   ["chebi:15618"]
# 374         779        780   ["chebi:87636"]   ["chebi:87634"]
# 491        1026       1027    ["chebi:3403"]   ["chebi:59205"]
# 497        1038       1039   ["chebi:60839"]   ["chebi:60830"]
# 634        1326       1327    ["chebi:6506"]  ["chebi:234341"]
# 645        1348       1349   ["chebi:16666"]   ["chebi:29934"]
# 828        1737       1738   ["chebi:77618"]    ["chebi:7621"]
# 889        1863       1864   ["chebi:25682"]  ["chebi:197308"]
# 1021       2142       2143   ["chebi:15827"]   ["chebi:60267"]
# 1120       2349       2350   ["chebi:84508"]   ["chebi:84500"]
# 1216       2546       2547   ["chebi:17800"]   ["chebi:60080"]
# 1263       2644       2645  ["chebi:137400"]  ["chebi:233199"]
# 1503       3154       3155    ["chebi:3713"]  ["chebi:231952"]
# 1587       3333       3334  ["chebi:195549"]  ["chebi:195563"]
# 1647       3458       3459   ["chebi:60822"]   ["chebi:60821"]
# 1753       3685       3686   ["chebi:88734"]  ["chebi:193596"]
# 1912       4016       4017   ["chebi:73675"]   ["chebi:73683"]
# 1916       4025       4026   ["chebi:61533"]   ["chebi:61496"]
# 2022       4246       4247   ["chebi:71420"]   ["chebi:71416"]
# 2097       4400       4401   ["chebi:27898"]   ["chebi:77771"]
# 2104       4418       4419   ["chebi:73024"]   ["chebi:15960"]
# 2125       4460       4461   ["chebi:88320"]   ["chebi:88324"]
# 2176       4565       4566   ["chebi:34970"]  ["chebi:180458"]
# 2327       4883       4884  ["chebi:228356"]  ["chebi:149665"]
# 2336       4903       4904  ["chebi:139267"]  ["chebi:138605"]
# 2403       5042       5043    ["chebi:4752"]  ["chebi:144384"]
# 2406       5048       5049  ["chebi:232974"]  ["chebi:141136"]
# 2416       5068       5069  ["chebi:231746"]  ["chebi:141968"]
# 2445       5129       5130   ["chebi:71584"]   ["chebi:71513"]
# 2572       5392       5393   ["chebi:84711"]  ["chebi:142973"]
# 2637       5529       5530   ["chebi:57293"]   ["chebi:15395"]
# 2769       5797       5798   ["chebi:16329"]   ["chebi:57736"]
# 3080       6455       6456   ["chebi:84779"]   ["chebi:84778"]
# 3109       6516       6517  ["chebi:133440"]  ["chebi:134518"]
# 3117       6533       6534   ["chebi:29512"]  ["chebi:194199"]
#
#       cluster_a_size  cluster_b_size classification  score  \
# 143                1               1   Unclassified    NaN
# 358                1               1   Unclassified    NaN
# 374                1               1   Unclassified    NaN
# 491                1               1   Unclassified    NaN
# 497                1               1   Unclassified    NaN
# 634                1               1   Unclassified    NaN
# 645                1               1   Unclassified    NaN
# 828                1               1   Unclassified    NaN
# 889                1               1   Unclassified    NaN
# 1021               1               1   Unclassified    NaN
# 1120               1               1   Unclassified    NaN
# 1216               1               1   Unclassified    NaN
# 1263               1               1   Unclassified    NaN
# 1503               1               1   Unclassified    NaN
# 1587               1               1   Unclassified    NaN
# 1647               1               1   Unclassified    NaN
# 1753               1               1   Unclassified    NaN
# 1912               1               1   Unclassified    NaN
# 1916               1               1   Unclassified    NaN
# 2022               1               1   Unclassified    NaN
# 2097               1               1   Unclassified    NaN
# 2104               1               1   Unclassified    NaN
# 2125               1               1   Unclassified    NaN
# 2176               1               1   Unclassified    NaN
# 2327               1               1   Unclassified    NaN
# 2336               1               1   Unclassified    NaN
# 2403               1               1   Unclassified    NaN
# 2406               1               1   Unclassified    NaN
# 2416               1               1   Unclassified    NaN
# 2445               1               1   Unclassified    NaN
# 2572               1               1   Unclassified    NaN
# 2637               1               1   Unclassified    NaN
# 2769               1               1   Unclassified    NaN
# 3080               1               1   Unclassified    NaN
# 3109               1               1   Unclassified    NaN
# 3117               1               1   Unclassified    NaN
#
#                 score_details  \
# 143   {"confidence_bin":null}
# 358   {"confidence_bin":null}
# 374   {"confidence_bin":null}
# 491   {"confidence_bin":null}
# 497   {"confidence_bin":null}
# 634   {"confidence_bin":null}
# 645   {"confidence_bin":null}
# 828   {"confidence_bin":null}
# 889   {"confidence_bin":null}
# 1021  {"confidence_bin":null}
# 1120  {"confidence_bin":null}
# 1216  {"confidence_bin":null}
# 1263  {"confidence_bin":null}
# 1503  {"confidence_bin":null}
# 1587  {"confidence_bin":null}
# 1647  {"confidence_bin":null}
# 1753  {"confidence_bin":null}
# 1912  {"confidence_bin":null}
# 1916  {"confidence_bin":null}
# 2022  {"confidence_bin":null}
# 2097  {"confidence_bin":null}
# 2104  {"confidence_bin":null}
# 2125  {"confidence_bin":null}
# 2176  {"confidence_bin":null}
# 2327  {"confidence_bin":null}
# 2336  {"confidence_bin":null}
# 2403  {"confidence_bin":null}
# 2406  {"confidence_bin":null}
# 2416  {"confidence_bin":null}
# 2445  {"confidence_bin":null}
# 2572  {"confidence_bin":null}
# 2637  {"confidence_bin":null}
# 2769  {"confidence_bin":null}
# 3080  {"confidence_bin":null}
# 3109  {"confidence_bin":null}
# 3117  {"confidence_bin":null}
#
#                                              extra_info version_tag  \
# 143   Parent-child stereochemical relationships must...        v1.0
# 358   Parent-child stereochemical relationships must...        v1.0
# 374   Parent-child stereochemical relationships must...        v1.0
# 491   Diastereomers must share protonation/charge; n...        v1.0
# 497   Parent-child stereochemical relationships must...        v1.0
# 634   Parent-child stereochemical relationships must...        v1.0
# 645   Parent-child stereochemical relationships must...        v1.0
# 828   Stereo and charge differ (complex); no classif...        v1.0
# 889   Parent-child stereochemical relationships must...        v1.0
# 1021  Parent-child stereochemical relationships must...        v1.0
# 1120  Stereo and charge differ (complex); no classif...        v1.0
# 1216  Parent-child stereochemical relationships must...        v1.0
# 1263  Parent-child stereochemical relationships must...        v1.0
# 1503  Parent-child stereochemical relationships must...        v1.0
# 1587  Parent-child stereochemical relationships must...        v1.0
# 1647  Parent-child stereochemical relationships must...        v1.0
# 1753  Parent-child stereochemical relationships must...        v1.0
# 1912  Parent-child stereochemical relationships must...        v1.0
# 1916  Parent-child stereochemical relationships must...        v1.0
# 2022  Parent-child stereochemical relationships must...        v1.0
# 2097  Parent-child stereochemical relationships must...        v1.0
# 2104  Parent-child stereochemical relationships must...        v1.0
# 2125  Enantiomers must share protonation/charge; no ...        v1.0
# 2176  Parent-child stereochemical relationships must...        v1.0
# 2327  Parent-child stereochemical relationships must...        v1.0
# 2336  Parent-child stereochemical relationships must...        v1.0
# 2403  Parent-child stereochemical relationships must...        v1.0
# 2406  Diastereomers must share protonation/charge; n...        v1.0
# 2416  Parent-child stereochemical relationships must...        v1.0
# 2445  Parent-child stereochemical relationships must...        v1.0
# 2572  Parent-child stereochemical relationships must...        v1.0
# 2637  Parent-child stereochemical relationships must...        v1.0
# 2769  Parent-child stereochemical relationships must...        v1.0
# 3080  Diastereomers must share protonation/charge; n...        v1.0
# 3109  Diastereomers must share protonation/charge; n...        v1.0
# 3117  Parent-child stereochemical relationships must...        v1.0
#
#              id1_c         id2_c                     pairkey
# 143    CHEBI_90408   CHEBI_87351    CHEBI_87351__CHEBI_90408
# 358    CHEBI_57438   CHEBI_15618    CHEBI_15618__CHEBI_57438
# 374    CHEBI_87636   CHEBI_87634    CHEBI_87634__CHEBI_87636
# 491     CHEBI_3403   CHEBI_59205     CHEBI_3403__CHEBI_59205
# 497    CHEBI_60839   CHEBI_60830    CHEBI_60830__CHEBI_60839
# 634     CHEBI_6506  CHEBI_234341    CHEBI_234341__CHEBI_6506
# 645    CHEBI_16666   CHEBI_29934    CHEBI_16666__CHEBI_29934
# 828    CHEBI_77618    CHEBI_7621     CHEBI_7621__CHEBI_77618
# 889    CHEBI_25682  CHEBI_197308   CHEBI_197308__CHEBI_25682
# 1021   CHEBI_15827   CHEBI_60267    CHEBI_15827__CHEBI_60267
# 1120   CHEBI_84508   CHEBI_84500    CHEBI_84500__CHEBI_84508
# 1216   CHEBI_17800   CHEBI_60080    CHEBI_17800__CHEBI_60080
# 1263  CHEBI_137400  CHEBI_233199  CHEBI_137400__CHEBI_233199
# 1503    CHEBI_3713  CHEBI_231952    CHEBI_231952__CHEBI_3713
# 1587  CHEBI_195549  CHEBI_195563  CHEBI_195549__CHEBI_195563
# 1647   CHEBI_60822   CHEBI_60821    CHEBI_60821__CHEBI_60822
# 1753   CHEBI_88734  CHEBI_193596   CHEBI_193596__CHEBI_88734
# 1912   CHEBI_73675   CHEBI_73683    CHEBI_73675__CHEBI_73683
# 1916   CHEBI_61533   CHEBI_61496    CHEBI_61496__CHEBI_61533
# 2022   CHEBI_71420   CHEBI_71416    CHEBI_71416__CHEBI_71420
# 2097   CHEBI_27898   CHEBI_77771    CHEBI_27898__CHEBI_77771
# 2104   CHEBI_73024   CHEBI_15960    CHEBI_15960__CHEBI_73024
# 2125   CHEBI_88320   CHEBI_88324    CHEBI_88320__CHEBI_88324
# 2176   CHEBI_34970  CHEBI_180458   CHEBI_180458__CHEBI_34970
# 2327  CHEBI_228356  CHEBI_149665  CHEBI_149665__CHEBI_228356
# 2336  CHEBI_139267  CHEBI_138605  CHEBI_138605__CHEBI_139267
# 2403    CHEBI_4752  CHEBI_144384    CHEBI_144384__CHEBI_4752
# 2406  CHEBI_232974  CHEBI_141136  CHEBI_141136__CHEBI_232974
# 2416  CHEBI_231746  CHEBI_141968  CHEBI_141968__CHEBI_231746
# 2445   CHEBI_71584   CHEBI_71513    CHEBI_71513__CHEBI_71584
# 2572   CHEBI_84711  CHEBI_142973   CHEBI_142973__CHEBI_84711
# 2637   CHEBI_57293   CHEBI_15395    CHEBI_15395__CHEBI_57293
# 2769   CHEBI_16329   CHEBI_57736    CHEBI_16329__CHEBI_57736
# 3080   CHEBI_84779   CHEBI_84778    CHEBI_84778__CHEBI_84779
# 3109  CHEBI_133440  CHEBI_134518  CHEBI_133440__CHEBI_134518
# 3117   CHEBI_29512  CHEBI_194199   CHEBI_194199__CHEBI_29512

# %% [markdown]
# 36 rows are cases where StereoMapper cannot handle complex relationships, as described in the manuscript. Note the extra_info column.

# %%
# get tp, fp, fn counts
tp = len(merged_protomer[ merged_protomer['classification'] == 'Protomers' ])
fp = len(merged_protomer[ merged_protomer['classification'] != 'Protomers' ])
fn = divese_pairs_df.shape[0] - tp

print(f"TP: {tp}, FP: {fp}, FN: {fn}")
# Out:
# TP: 3166, FP: 36, FN: 203

# %% [markdown]
# False positives have been accounted for. False negatives are likely due to the structures which are clustered together by StereoMapper, resulting in missing comparisons / mappings, or the identifiers in question have no downloadable structure from chebi. The former is the most likely as these molfiles which have been validated to exist are taken from chebi. Wildcard structures have been removed so it cannot be their influence

# %%
 # calculate precision, recall, f1
protomer_precision = tp / (tp + fp) if (tp + fp) > 0 else 0
protomer_recall = tp / (tp + fn) if (tp + fn) > 0 else 0
protomer_f1 = 2 * (protomer_precision * protomer_recall) / (protomer_precision + protomer_recall) if (protomer_precision + protomer_recall) > 0 else 0 

print(f"Precision: {protomer_precision:.2%}, Recall: {protomer_recall:.2%}, F1 Score: {protomer_f1:.2%}")
# Out:
# Precision: 98.88%, Recall: 93.97%, F1 Score: 96.36%

# %%
# remove false positives which have no classification but have extra_info indicating the diff in scope
df_filtered = merged_protomer[~(
    (merged_protomer['classification'] == 'Unclassified') &
    (merged_protomer['extra_info'].notnull())
)]

# calc tp, fp, fn again
tp_v2 = len(df_filtered[ df_filtered['classification'] == 'Protomers' ])
fp_v2 = len(df_filtered[ df_filtered['classification'] != 'Protomers' ])
fn_v2 = divese_pairs_df.shape[0] - tp_v2

print(f"TP: {tp_v2}, FP: {fp_v2}, FN: {fn_v2}")
# Out:
# TP: 3166, FP: 0, FN: 203

# %%
 # calculate precision, recall, f1
protomer_precision_v2 = tp_v2 / (tp_v2 + fp_v2) if (tp_v2 + fp_v2) > 0 else 0
protomer_recall_v2 = tp_v2 / (tp_v2 + fn_v2) if (tp_v2 + fn_v2) > 0 else 0
protomer_f1_v2 = 2 * (protomer_precision_v2 * protomer_recall_v2) / (protomer_precision_v2 + protomer_recall_v2) if (protomer_precision_v2 + protomer_recall_v2) > 0 else 0

print(f"Precision: {protomer_precision_v2:.2%}, Recall: {protomer_recall_v2:.2%}, F1 Score: {protomer_f1_v2:.2%}")
# Out:
# Precision: 100.00%, Recall: 93.97%, F1 Score: 96.89%

# %% [markdown]
# ## Stereo-resolution pairs

# %%
stereo_resolution_pairs_control = pd.read_csv('data/stereo_resolution_pairs.csv')
stereo_resolution_pairs_control
# Out:
#      mnxparent_label  parent_label mnxchild_label   child_label
# 0         MNXM100051  chebi:187719     MNXM100344  chebi:188242
# 1          MNXM10010   chebi:28254    MNXM1380605  chebi:198196
# 2          MNXM10026   chebi:86041    MNXM1104681   chebi:62616
# 3          MNXM10026   chebi:86041       MNXM9497   chebi:74272
# 4          MNXM10039   chebi:50168      MNXM36497   chebi:50170
# ...              ...           ...            ...           ...
# 5068        MNXM9879  chebi:173438    MNXM1409533  chebi:228257
# 5069        MNXM9987   chebi:27389     MNXM162802   chebi:57731
# 5070        MNXM9987   chebi:27389     MNXM732376   chebi:58655
# 5071       MNXM99960  chebi:186405     MNXM101734  chebi:195754
# 5072       MNXM99960  chebi:186405      MNXM46228    chebi:3570
#
# [5073 rows x 4 columns]

# %%
stereo_resolution_pairs = Path('/home/jackmcgoldrick/Downloads/benchmarking_data/parent_child_benchmark_data')
results = Path('stereo_resolution_benchmarking_results.sqlite')
cache = Path('stereo_resolution_benchmarking_cache.sqlite')

# %%
cmd =[
    "stereomapper",
    "run",
    "-d", stereo_resolution_pairs.as_posix(),
    "-o", results.as_posix(),
    "-p", cache.as_posix(),
    "--fresh-cache"
]

subprocess.run(cmd)
# Out:
# INFO    Logging initialised. File: logs/stereomapper_20251215_103827.log
# Pipeline: 100%|██████████████████████████████████████████████████████████| , Complete! [00:37<00:00]
# ✅ Pipeline completed in 37.4s
# 📦 Inputs attempted: 7,693 (skipped 0)
# 📊 Successes: 7,693 | Failures: 0
# 🔗 Inchikey groups — processed 2,541, skipped 0, failed 0
# 🧮 Relationship rows: 15,272
# 🧾 Unique inchikeys observed: 2,541
# 💾 Cache hit rate: 0.0%
# Pipeline: 100%|██████████████████████████████████████████████████████████| , Complete! [00:37<00:00]
# CompletedProcess(args=['stereomapper', 'run', '-d', '/home/jackmcgoldrick/Downloads/benchmarking_data/parent_child_benchmark_data', '-o', 'stereo_resolution_benchmarking_results.sqlite', '-p', 'stereo_resolution_benchmarking_cache.sqlite', '--fresh-cache'], returncode=0)

# %%
conn = sqlite3.connect(results)
merged_df_q = """ 
SELECT * from relationships;
"""
df_merged_stereo = pd.read_sql_query(merged_df_q, conn)
df_merged_stereo
# Out:
#        cluster_a  cluster_b cluster_a_members cluster_b_members  \
# 0              1          2  ["chebi:184417"]   ["chebi:81326"]
# 1              1          3  ["chebi:184417"]   ["chebi:81325"]
# 2              2          3   ["chebi:81326"]   ["chebi:81325"]
# 3              4          5   ["chebi:20604"]   ["chebi:40617"]
# 4              4          6   ["chebi:20604"]   ["chebi:52505"]
# ...          ...        ...               ...               ...
# 15267       7686       7689  ["chebi:138363"]  ["chebi:138362"]
# 15268       7687       7688  ["chebi:138597"]  ["chebi:138596"]
# 15269       7687       7689  ["chebi:138597"]  ["chebi:138362"]
# 15270       7688       7689  ["chebi:138596"]  ["chebi:138362"]
# 15271       7690       7691  ["chebi:178679"]   ["chebi:58058"]
#
#        cluster_a_size  cluster_b_size           classification  score  \
# 0                   1               1  Stereo-resolution pairs  100.0
# 1                   1               1  Stereo-resolution pairs  100.0
# 2                   1               1            Diastereomers  100.0
# 3                   1               1             Unclassified    NaN
# 4                   1               1  Stereo-resolution pairs  100.0
# ...               ...             ...                      ...    ...
# 15267               1               1              Enantiomers  100.0
# 15268               1               1              Enantiomers  100.0
# 15269               1               1            Diastereomers  100.0
# 15270               1               1            Diastereomers  100.0
# 15271               1               1  Stereo-resolution pairs   81.0
#
#                      score_details  \
# 0        {"confidence_bin":"high"}
# 1        {"confidence_bin":"high"}
# 2        {"confidence_bin":"high"}
# 3          {"confidence_bin":null}
# 4        {"confidence_bin":"high"}
# ...                            ...
# 15267    {"confidence_bin":"high"}
# 15268    {"confidence_bin":"high"}
# 15269    {"confidence_bin":"high"}
# 15270    {"confidence_bin":"high"}
# 15271  {"confidence_bin":"medium"}
#
#                                               extra_info version_tag
# 0                                                   None        v1.0
# 1                                                   None        v1.0
# 2                                                   None        v1.0
# 3      Parent-child stereochemical relationships must...        v1.0
# 4                                                   None        v1.0
# ...                                                  ...         ...
# 15267                                               None        v1.0
# 15268                                               None        v1.0
# 15269                                               None        v1.0
# 15270                                               None        v1.0
# 15271                                               None        v1.0
#
# [15272 rows x 11 columns]

# %%
df_merged_stereo['cluster_a_members'] = df_merged_stereo['cluster_a_members'].apply(json.loads)
df_merged_stereo['cluster_b_members'] = df_merged_stereo['cluster_b_members'].apply(json.loads)

# %%
# now the data fromats match, create unique keys on both dataframes to allow for cross-referencing
stereo_resolution_pairs_control['pair_key'] = stereo_resolution_pairs_control.apply(lambda row: frozenset([row['parent_label'], row['child_label']]), axis=1)
df_merged_stereo['pair_key'] = df_merged_stereo.apply(lambda row: frozenset(row['cluster_a_members'] + row['cluster_b_members']), axis=1)

# now we can cross-reference the results back to the original set of parent-child pairs
merged_df = pd.merge(stereo_resolution_pairs_control, df_merged_stereo, on='pair_key', how='inner', suffixes=('_parent_child', '_results'))
print(f"Number of matched parent-child pairs in results: {merged_df.shape[0]}")
# Out:
# Number of matched parent-child pairs in results: 5029

# %%
frac_found = merged_df.shape[0] / stereo_resolution_pairs_control.shape[0]
print(f"Fraction of parent-child pairs found in results: {frac_found:.2%}")
# Out:
# Fraction of parent-child pairs found in results: 99.13%

# %%
merged_df['classification'].value_counts()
# Out:
# classification
# Stereo-resolution pairs    4332
# Unclassified                695
# Diastereomers                 2
# Name: count, dtype: int64

# %% [markdown]
# Vast majority are as expected.

# %%
df_miss_dia = merged_df[merged_df['classification'] == 'Diastereomers']
df_miss_dia
# Out:
#      mnxparent_label  parent_label mnxchild_label  child_label  \
# 2129     MNXM1374129  chebi:182512     MNXM734257  chebi:31053
# 2220     MNXM1376176  chebi:188778    MNXM1364249  chebi:32903
#
#                          pair_key  cluster_a  cluster_b cluster_a_members  \
# 2129  (chebi:182512, chebi:31053)       7233       7234    [chebi:182512]
# 2220  (chebi:188778, chebi:32903)       5466       5467     [chebi:32903]
#
#      cluster_b_members  cluster_a_size  cluster_b_size classification  score  \
# 2129     [chebi:31053]               1               1  Diastereomers  100.0
# 2220    [chebi:188778]               1               1  Diastereomers  100.0
#
#                   score_details extra_info version_tag
# 2129  {"confidence_bin":"high"}       None        v1.0
# 2220  {"confidence_bin":"high"}       None        v1.0

# %% [markdown]
# In the case of (chebi:182512, chebi:31053) and (chebi:188778, chebi:32903) these are in fact diastereomers. Unclassified cases again represent cases where the pipeline cannot handle complex relationships.

# %%
 # get the stats, false positives, false negatives, true positives
tp = merged_df[merged_df['classification'] == 'Stereo-resolution pairs']
fp = merged_df[merged_df['classification'] != 'Stereo-resolution pairs']
fn = stereo_resolution_pairs_control[~stereo_resolution_pairs_control['pair_key'].isin(merged_df['pair_key'])]

# convert to integers
tp = int(tp.shape[0])
fp = int(fp.shape[0])
fn = int(fn.shape[0])

print(f"True Positives: {tp}")
print(f"False Positives: {fp}")
print(f"False Negatives: {fn}")
# Out:
# True Positives: 4332
# False Positives: 697
# False Negatives: 44

# %% [markdown]
# In the cases of false negatives, two likely causes exist:
#
# (1) The identifier in question has no structural representation on the chebi website / database
#
# (2) stereomapper correctly / incorrectly clusters the structures in the pair together in the identity step, so no relationship can be assigned to them.
#
#  These are the likely causes for the false negatives, as we removed wildcards in a previous step before entry to avoid their influence in this phase.
#
# -----
# In terms of false positives, a few possible cases exist:
#
# (1) The relationship between the structures in question do not fit into any classifications defined by the pipeline e.g., a case where structures A and B have different stereochemistry and protonation states.
#
#
# (2) Misclassifications by MetaNetX / ChEBI , where stereomapper corrects them (in the cases mentioned previously)
#
# (3) Cases where the pipeline assigns the incorrect relationship.

# %%
actual_fp = fp - 2 # remove the 2 diastereomer cases where stereomapper is correct

# %%
# now lets calculate precision, recall and F1 score
## note this is the case where we count all "No classification" as false positives
sr_precision = tp / (tp + actual_fp) if (tp + actual_fp) > 0 else 0
sr_recall = tp / (tp + fn) if (tp + fn) > 0 else 0
sr_f1_score = 2 * (sr_precision * sr_recall) / (sr_precision + sr_recall) if (sr_precision + sr_recall) > 0 else 0

print(f"Precision: {sr_precision:.2%}")
print(f"Recall: {sr_recall:.2%}")
print(f"F1 Score: {sr_f1_score:.2%}")
# Out:
# Precision: 86.17%
# Recall: 98.99%
# F1 Score: 92.14%

# %% [markdown]
# These are the initial set of results, not removing the false positives which we conclude to be due to limitations in the pipeline. Now lets confirm our suspicisions that these are due to not being able to fit into our defined classes due to charge differences. Then recompute stats above!As such, even with inclusion of these false positives, the pipeline performs quite well in these cases.

# %%
# now let's remove those false positives we know are due to complex classification cases
# use extra_info column: drop rows whose extra_info mentions 'charge' or 'Radioactivity'
# cast to str to avoid issues with None / lists and use a regex to match either term
mask = merged_df['extra_info'].astype(str).str.contains(r'charge|Radioactivity', case=False, na=False)
df_filtered_no_class = merged_df[~mask]
df_filtered_no_class
# Out:
#      mnxparent_label  parent_label mnxchild_label   child_label  \
# 0         MNXM100051  chebi:187719     MNXM100344  chebi:188242
# 1          MNXM10010   chebi:28254    MNXM1380605  chebi:198196
# 2          MNXM10026   chebi:86041    MNXM1104681   chebi:62616
# 3          MNXM10026   chebi:86041       MNXM9497   chebi:74272
# 4          MNXM10039   chebi:50168      MNXM36497   chebi:50170
# ...              ...           ...            ...           ...
# 5021        MNXM9859   chebi:48946    MNXM1107135  chebi:145932
# 5025        MNXM9987   chebi:27389     MNXM162802   chebi:57731
# 5026        MNXM9987   chebi:27389     MNXM732376   chebi:58655
# 5027       MNXM99960  chebi:186405     MNXM101734  chebi:195754
# 5028       MNXM99960  chebi:186405      MNXM46228    chebi:3570
#
#                           pair_key  cluster_a  cluster_b cluster_a_members  \
# 0     (chebi:187719, chebi:188242)       6902       6903    [chebi:187719]
# 1      (chebi:28254, chebi:198196)       6795       6796     [chebi:28254]
# 2       (chebi:62616, chebi:86041)       2115       2117     [chebi:86041]
# 3       (chebi:74272, chebi:86041)       2115       2116     [chebi:86041]
# 4       (chebi:50170, chebi:50168)        253        257     [chebi:50168]
# ...                            ...        ...        ...               ...
# 5021   (chebi:48946, chebi:145932)       6518       6520     [chebi:48946]
# 5025    (chebi:57731, chebi:27389)       4825       4827     [chebi:27389]
# 5026    (chebi:58655, chebi:27389)       4825       4826     [chebi:27389]
# 5027  (chebi:195754, chebi:186405)       1058       1059    [chebi:186405]
# 5028    (chebi:3570, chebi:186405)       1058       1060    [chebi:186405]
#
#      cluster_b_members  cluster_a_size  cluster_b_size  \
# 0       [chebi:188242]               1               1
# 1       [chebi:198196]               1               1
# 2        [chebi:62616]               1               1
# 3        [chebi:74272]               1               1
# 4        [chebi:50170]               1               1
# ...                ...             ...             ...
# 5021    [chebi:145932]               1               1
# 5025     [chebi:57731]               1               1
# 5026     [chebi:58655]               1               1
# 5027    [chebi:195754]               1               1
# 5028      [chebi:3570]               1               1
#
#                classification  score                score_details extra_info  \
# 0     Stereo-resolution pairs  100.0    {"confidence_bin":"high"}       None
# 1     Stereo-resolution pairs  100.0    {"confidence_bin":"high"}       None
# 2     Stereo-resolution pairs  100.0    {"confidence_bin":"high"}       None
# 3     Stereo-resolution pairs  100.0    {"confidence_bin":"high"}       None
# 4     Stereo-resolution pairs  100.0    {"confidence_bin":"high"}       None
# ...                       ...    ...                          ...        ...
# 5021  Stereo-resolution pairs  100.0    {"confidence_bin":"high"}       None
# 5025  Stereo-resolution pairs   84.0  {"confidence_bin":"medium"}       None
# 5026  Stereo-resolution pairs   84.0  {"confidence_bin":"medium"}       None
# 5027  Stereo-resolution pairs  100.0    {"confidence_bin":"high"}       None
# 5028  Stereo-resolution pairs  100.0    {"confidence_bin":"high"}       None
#
#      version_tag
# 0           v1.0
# 1           v1.0
# 2           v1.0
# 3           v1.0
# 4           v1.0
# ...          ...
# 5021        v1.0
# 5025        v1.0
# 5026        v1.0
# 5027        v1.0
# 5028        v1.0
#
# [4334 rows x 16 columns]

# %% [markdown]
#  Vast majority of unclassified cases due to complex / ambiguous cases associated with charge diffs that aren't handled in StereoMapper.Remaining are due to differences in isotopically labelled species, which are also not handled.

# %%
df_filtered_no_class['classification'].value_counts()
# Out:
# classification
# Stereo-resolution pairs    4332
# Diastereomers                 2
# Name: count, dtype: int64

# %%
 # get the stats, false positives, false negatives, true positives
tp_v2 = df_filtered_no_class[df_filtered_no_class['classification'] == 'Stereo-resolution pairs']
fp_v2 = df_filtered_no_class[df_filtered_no_class['classification'] != 'Stereo-resolution pairs']
fn_v2 = stereo_resolution_pairs_control[~stereo_resolution_pairs_control['pair_key'].isin(merged_df['pair_key'])] # still use merged df to find fns

# convert to integers
tp_v2 = int(tp_v2.shape[0])
fp_v2 = int(fp_v2.shape[0])
fn_v2 = int(fn_v2.shape[0])

# take away two diastereomer cases from false positives we know to be correct by molD
fp_v2 -= 2

print(f"True Positives: {tp_v2}")
print(f"False Positives: {fp_v2}")
print(f"False Negatives: {fn_v2}")
# Out:
# True Positives: 4332
# False Positives: 0
# False Negatives: 44

# %%
 # now lets calculate precision, recall and F1 score
## note this is the case where we exclude "No classification" from false positives
sr_precision_v2 = tp_v2 / (tp_v2 + fp_v2) if (tp_v2 + fp_v2) > 0 else 0
sr_recall_v2 = tp_v2 / (tp_v2 + fn_v2) if (tp_v2 + fn_v2) > 0 else 0
sr_f1_score_v2 = 2 * (sr_precision_v2 * sr_recall_v2) / (sr_precision_v2 + sr_recall_v2) if (sr_precision_v2 + sr_recall_v2) > 0 else 0

print(f"Precision: {sr_precision_v2:.2%}")
print(f"Recall: {sr_recall_v2:.2%}")
print(f"F1 Score: {sr_f1_score_v2:.2%}")
# Out:
# Precision: 100.00%
# Recall: 98.99%
# F1 Score: 99.49%

# %% [markdown]
# ## Generate Figure

# %%
from matplotlib import pyplot as plt


def add_yaxis_break(ax, y=0.0, size=0.015, linewidth=0.8):
    """Draw a small diagonal break mark on the y-axis at the given
    axes-coordinate y-position."""
    kwargs = dict(transform=ax.transAxes,
                  color="black",          # <- must be 'color'
                  linewidth=linewidth,
                  clip_on=False)

    # left side break
    ax.plot([-0.015, +0.015], [y - size, y + size], **kwargs)

    # right side (optional: uncomment if you want it mirrored)
    # ax.plot([1 - 0.015, 1 + 0.015], [y - size, y + size], **kwargs)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator

# ---- page/layout: A4 article, 2 cm margins => textwidth ≈ 170 mm ----
TEXTWIDTH_MM = 170.0
INCH = 1/25.4
FIG_W = TEXTWIDTH_MM * INCH           # 6.69 in
FIG_H = 3.0                           # keep compact

# ---- fonts & PDF embedding (vector, selectable text) ----
plt.rcParams.update({
    "pdf.fonttype": 42, "ps.fonttype": 42, "svg.fonttype": "none",
    "font.family": "sans-serif", "font.sans-serif": ["DejaVu Sans"],
    "font.size": 9.5, "axes.titlesize": 10.5, "axes.labelsize": 9.5,
    "xtick.labelsize": 8.5, "ytick.labelsize": 8.5,
})

# ---- data ----
rel_types = ["Enantiomers", "Diastereomers", "Stereo-resolution pairs", "Protomers"]
metrics = ["Precision", "Recall", "F1 Score"]

initial = {
    "Enantiomers":  {"Precision": enantiomer_precision, "Recall": enantiomer_recall, "F1 Score": enantiomer_f1},
    "Diastereomers":{"Precision": diastereomer_precision, "Recall": diastereomer_recall, "F1 Score": diastereomer_f1},
    "Stereo-resolution pairs": {"Precision": sr_precision, "Recall": sr_recall, "F1 Score": sr_f1_score},
    "Protomers":    {"Precision": protomer_precision, "Recall": protomer_recall, "F1 Score": protomer_f1},
}
adjusted = {
    "Enantiomers":  {"Precision": enantiomer_actual_precision, "Recall": enantiomer_actual_recall, "F1 Score": enantiomer_actual_f1},
    "Diastereomers":{"Precision": None, "Recall": None, "F1 Score": None},  # N/A
    "Stereo-resolution pairs": {"Precision": sr_precision_v2, "Recall": sr_recall_v2, "F1 Score": sr_f1_score_v2},
    "Protomers":    {"Precision": protomer_precision_v2, "Recall": protomer_recall_v2, "F1 Score": protomer_f1_v2},
}

initial_arr = np.array([[initial[rel][m] for rel in rel_types] for m in metrics], dtype=float)
adjusted_arr = np.array([[
    adjusted[rel][m] if adjusted[rel][m] is not None else np.nan
    for rel in rel_types
] for m in metrics], dtype=float)

# convert to percentages
initial_arr *= 100.0
adjusted_arr *= 100.0

c_init = "#A7A7A7"
c_adj  = "#4C78A8"

fig, axes = plt.subplots(1, 3, figsize=(FIG_W, FIG_H), sharey=True)
bar_w = 0.4
x = np.arange(len(rel_types))

DELTA_THRESHOLD = 0.5
NA_LABEL_Y = 82    # move N/A label into the visible range (>= 80)

# New: define zoomed y-range
YMIN, YMAX = 80, 100

for m_idx, ax in enumerate(axes):
    metric = metrics[m_idx]
    y_init = initial_arr[m_idx]
    y_adj = adjusted_arr[m_idx]

    # bars
    bars_init = ax.bar(x - bar_w/2, y_init, width=bar_w,
                       color=c_init, edgecolor="black", linewidth=0.6, label="Initial")

    mask = ~np.isnan(y_adj)
    bars_adj = ax.bar(x[mask] + bar_w/2, y_adj[mask], width=bar_w,
                      color=c_adj, edgecolor="black", linewidth=0.6, label="Curated")

    # N/A markers
    for xi, missing in zip(x, ~mask):
        if missing:
            ax.text(xi + bar_w/2, NA_LABEL_Y, "N/A",
                    ha="center", va="bottom", rotation=90, fontsize=8, color="#666666")

    # delta labels
    for xi, yi_init, yi_adj in zip(x[mask], y_init[mask], y_adj[mask]):
        delta = yi_adj - yi_init
        if abs(delta) >= DELTA_THRESHOLD:
            ax.text(xi + bar_w/2, yi_adj + 0.2, f"{delta:+.1f}",
                    ha="center", va="bottom", fontsize=8.5, color=c_adj)

    # axes cosmetics
    ax.set_title(metric, pad=14)
    ax.set_xticks(x)
    ax.set_xticklabels(rel_types, rotation=30, ha="right", fontsize=7)

    #  zoomed y-axis
    ax.set_ylim(YMIN, YMAX)
    ax.yaxis.set_major_locator(MultipleLocator(5))

    # add break mark on the y-axis at the truncation point (bottom of axes)
    add_yaxis_break(ax, y=0.0)

    # Optional: dashed line at the truncation point (80 %)
   # ax.axhline(YMIN, linestyle="--", linewidth=0.7, color="black")

    ax.grid(axis="y", linestyle="--", linewidth=0.55, alpha=0.6)
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)

axes[0].set_ylabel("Score (%)")

handles, labels = axes[0].get_legend_handles_labels()
fig.subplots_adjust(left=0.075, right=0.995, bottom=0.2, top=0.8, wspace=0.2)
fig.legend(handles, labels, loc="lower center", ncol=2, frameon=False,
           borderaxespad=0.6, bbox_to_anchor=(0.5, -0.15))

plt.show()

# %%
import numpy as np

# Build arrays as you already do: initial_arr, adjusted_arr  (shape: 3 metrics x 4 rel_types)

# mask for datasets with adjusted values available (True where not NaN in ANY metric you care about)
mask = ~np.isnan(adjusted_arr[0])  # e.g., use Precision row; or combine across rows

# paired macro-averages (Initial vs Adjusted) over the same datasets
paired_initial_precision = np.mean(initial_arr[0, mask])
paired_adjusted_precision = np.mean(adjusted_arr[0, mask])

paired_initial_recall = np.mean(initial_arr[1, mask])
paired_adjusted_recall = np.mean(adjusted_arr[1, mask])

paired_initial_f1 = np.mean(initial_arr[2, mask])
paired_adjusted_f1 = np.mean(adjusted_arr[2, mask])

print("Paired Macro-Averages (Initial vs Adjusted):")
print(f"Precision: Initial = {paired_initial_precision:.2f}, Adjusted = {paired_adjusted_precision:.2f}")
print(f"Recall:    Initial = {paired_initial_recall:.2f}, Adjusted = {paired_adjusted_recall:.2f}")
print(f"F1 Score:  Initial = {paired_initial_f1:.2f}, Adjusted = {paired_adjusted_f1:.2f}")
# Out:
# Paired Macro-Averages (Initial vs Adjusted):
# Precision: Initial = 93.43, Adjusted = 99.06
# Recall:    Initial = 97.66, Adjusted = 97.66
# F1 Score:  Initial = 95.36, Adjusted = 98.32
